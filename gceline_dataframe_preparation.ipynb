# %%
import pandas as pd

# %%
path_train = '/Users/celinegianduzzo/code/theresa-sporn/WorkforceSentimentMonitoring/raw_data/train.csv'

train = pd.read_csv(path_train)

# %%
path_test = '/Users/celinegianduzzo/code/theresa-sporn/WorkforceSentimentMonitoring/raw_data/test.csv'

test = pd.read_csv(path_test)

# %%
train.shape
# Out:
# (30336, 17)

# %%
test.shape
# Out:
# (29272, 16)

# %%
overall_rating = pd.DataFrame(train)

# %%
overall_rating.drop(columns=['score_1', 'score_2', 'score_3', 'score_4', 'score_5', 'score_6'])
# Out:
#           ID      Place           location           date             status  \
# 0          1  startup_1                NaN   Dec 11, 2018  Current Employee
# 1          2  startup_1  Mountain View, CA   Jun 21, 2013   Former Employee
# 2          3  startup_1       New York, NY   May 10, 2014  Current Employee
# 3          4  startup_1  Mountain View, CA    Feb 8, 2015  Current Employee
# 4         10  startup_1                NaN    Dec 9, 2018  Current Employee
# ...      ...        ...                ...            ...                ...
# 30331  67522  startup_6                NaN   Dec 22, 2010   Former Employee
# 30332  67524  startup_6                NaN   Dec 17, 2010   Former Employee
# 30333  67525  startup_6                NaN   Dec 16, 2010   Former Employee
# 30334  67527  startup_6                NaN   Dec 15, 2010  Current Employee
# 30335  67528  startup_6                NaN   Dec 15, 2010  Current Employee
#
#                      job_title  \
# 0           Anonymous Employee
# 1              Program Manager
# 2        Software Engineer III
# 3           Anonymous Employee
# 4           Anonymous Employee
# ...                        ...
# 30331   Senior Project Managet
# 30332   Senior Program Manager
# 30333       Anonymous Employee
# 30334          Account Manager
# 30335         Senior Test Lead
#
#                                                  summary  \
# 0                               Best Company to work for
# 1      Moving at the speed of light, burn out is inev...
# 2      Great balance between big-company security and...
# 3      The best place I've worked and also the most d...
# 4                               Execellent for engineers
# ...                                                  ...
# 30331                         Microsoft Services is bad.
# 30332                                      Good company.
# 30333  Enriching experience for a beginner but bad fo...
# 30334                                 Good Place to Work
# 30335  It's a competitive work place, with overload w...
#
#                                                positives  \
# 0                          People are smart and friendly
# 1      1) Food, food, food. 15+ cafes on main campus ...
# 2      * If you're a software engineer, you're among ...
# 3      You can't find a more well-regarded company th...
# 4                 Impact driven. Best tech in the world.
# ...                                                  ...
# 30331  MS is a good company but hire wrong people. Wo...
# 30332         Good benefits package, huge customer base.
# 30333  -Access to a wide range of technologies, compl...
# 30334  Nice place to work. Good atmosphere with advan...
# 30335       Smart people around you, can learn from them
#
#                                                negatives  \
# 0                     Bureaucracy is slowing things down
# 1      1) Work/life balance. What balance? All those ...
# 2      * It *is* becoming larger, and with it comes g...
# 3      I live in SF so the commute can take between 1...
# 4      Size matters. Engineers are a bit disconnected...
# ...                                                  ...
# 30331  Senior management has no leadership and very o...
# 30332            Politics, very slow, lots of dead wood.
# 30333  -Testers(SDET's ) do not get as many opportuni...
# 30334  Management confusion at times with vision for ...
# 30335              Politics, weak moral, leaning loyalty
#
#                                           advice_to_mgmt  overall
# 0                                                    NaN      5.0
# 1      1) Don't dismiss emotional intelligence and ad...      5.0
# 2      Keep the focus on the user. Everything else wi...      5.0
# 3      Keep on NOT micromanaging - that is a huge ben...      4.0
# 4                                                    NaN      4.0
# ...                                                  ...      ...
# 30331  Major management revamp esp in APAC. It's not ...      2.0
# 30332                                           Move on.      4.0
# 30333  Make the company leaner and Meaner. (which wou...      3.0
# 30334                                                NaN      4.0
# 30335                                                NaN      3.0
#
# [30336 rows x 11 columns]

# %%
train = train.drop(columns=['overall'])

# %%
train
# Out:
#           ID      Place location           date             status  \
# 0          1  startup_1      NaN   Dec 11, 2018  Current Employee
# 6         17  startup_1      NaN   Nov 29, 2018  Current Employee
# 7         18  startup_1      NaN    Dec 2, 2018   Former Employee
# 8         19  startup_1      NaN    Dec 1, 2018   Former Employee
# 9         24  startup_1      NaN   Nov 30, 2018  Current Employee
# ...      ...        ...      ...            ...                ...
# 30331  67522  startup_6      NaN   Dec 22, 2010   Former Employee
# 30332  67524  startup_6      NaN   Dec 17, 2010   Former Employee
# 30333  67525  startup_6      NaN   Dec 16, 2010   Former Employee
# 30334  67527  startup_6      NaN   Dec 15, 2010  Current Employee
# 30335  67528  startup_6      NaN   Dec 15, 2010  Current Employee
#
#                      job_title  \
# 0           Anonymous Employee
# 6           Anonymous Employee
# 7           Anonymous Employee
# 8           Anonymous Employee
# 9           Anonymous Employee
# ...                        ...
# 30331   Senior Project Managet
# 30332   Senior Program Manager
# 30333       Anonymous Employee
# 30334          Account Manager
# 30335         Senior Test Lead
#
#                                                  summary  \
# 0                               Best Company to work for
# 6                                       Review of Google
# 7                                               Analysts
# 8                       Great Company With No Down Sides
# 9                                      Software Engineer
# ...                                                  ...
# 30331                         Microsoft Services is bad.
# 30332                                      Good company.
# 30333  Enriching experience for a beginner but bad fo...
# 30334                                 Good Place to Work
# 30335  It's a competitive work place, with overload w...
#
#                                                positives  \
# 0                          People are smart and friendly
# 6         The people are great to work with, good perks.
# 7      Good managers, benefits , some support, nice a...
# 8               Really fun work environment with startup
# 9                     Awesome job environment to work in
# ...                                                  ...
# 30331  MS is a good company but hire wrong people. Wo...
# 30332         Good benefits package, huge customer base.
# 30333  -Access to a wide range of technologies, compl...
# 30334  Nice place to work. Good atmosphere with advan...
# 30335       Smart people around you, can learn from them
#
#                                                negatives  \
# 0                     Bureaucracy is slowing things down
# 6              Wide variety in experience based on team.
# 7               Long hours, far locations, a lot of work
# 8                       Really no down sides that I saw.
# 9                       Pressure is there for some parts
# ...                                                  ...
# 30331  Senior management has no leadership and very o...
# 30332            Politics, very slow, lots of dead wood.
# 30333  -Testers(SDET's ) do not get as many opportuni...
# 30334  Management confusion at times with vision for ...
# 30335              Politics, weak moral, leaning loyalty
#
#                                           advice_to_mgmt  score_1  score_2  \
# 0                                                    NaN      4.0      5.0
# 6                                                    NaN      4.0      5.0
# 7                                                    NaN      NaN      NaN
# 8                                                    NaN      5.0      5.0
# 9                                                    NaN      NaN      NaN
# ...                                                  ...      ...      ...
# 30331  Major management revamp esp in APAC. It's not ...      3.0      NaN
# 30332                                           Move on.      3.5      NaN
# 30333  Make the company leaner and Meaner. (which wou...      3.0      NaN
# 30334                                                NaN      3.0      NaN
# 30335                                                NaN      2.0      NaN
#
#        score_3  score_4  score_5  score_6
# 0          5.0      4.0      5.0        0
# 6          5.0      5.0      4.0        2
# 7          2.0      NaN      NaN        1
# 8          5.0      5.0      5.0        1
# 9          NaN      NaN      NaN        0
# ...        ...      ...      ...      ...
# 30331      1.5      2.0      1.0        0
# 30332      3.5      4.0      4.0        0
# 30333      4.0      4.0      2.0        0
# 30334      4.0      4.5      3.5        0
# 30335      3.0      3.5      3.0        0
#
# [30331 rows x 16 columns]

# %%
frames = [train, test]

df_categories = pd.concat(frames)

# %%
df_categories.isnull().sum()
# Out:
# ID                    0
# Place                 0
# location          20877
# date                  0
# status                0
# job_title             0
# summary             103
# positives             0
# negatives             1
# advice_to_mgmt    25794
# score_1            3185
# score_2            6049
# score_3            3168
# score_4            3190
# score_5            3484
# score_6               0
# dtype: int64

# %%
df_categories = df_categories.rename(columns={'score_1':'work-balance', 'score_2':'culture-values', 'score_3':'carreer-opportunities', 'score_4':'comp-benefit', 'score_5':'senior-mangemnet', 'score_6':'helpful-count'})

# %%
df_categories.head()
# Out:
#    ID      Place location           date             status  \
# 0   1  startup_1      NaN   Dec 11, 2018  Current Employee
# 6  17  startup_1      NaN   Nov 29, 2018  Current Employee
# 7  18  startup_1      NaN    Dec 2, 2018   Former Employee
# 8  19  startup_1      NaN    Dec 1, 2018   Former Employee
# 9  24  startup_1      NaN   Nov 30, 2018  Current Employee
#
#              job_title                           summary  \
# 0   Anonymous Employee          Best Company to work for
# 6   Anonymous Employee                  Review of Google
# 7   Anonymous Employee                          Analysts
# 8   Anonymous Employee  Great Company With No Down Sides
# 9   Anonymous Employee                 Software Engineer
#
#                                            positives  \
# 0                      People are smart and friendly
# 6     The people are great to work with, good perks.
# 7  Good managers, benefits , some support, nice a...
# 8           Really fun work environment with startup
# 9                 Awesome job environment to work in
#
#                                    negatives advice_to_mgmt  work-balance  \
# 0         Bureaucracy is slowing things down            NaN           4.0
# 6  Wide variety in experience based on team.            NaN           4.0
# 7   Long hours, far locations, a lot of work            NaN           NaN
# 8           Really no down sides that I saw.            NaN           5.0
# 9           Pressure is there for some parts            NaN           NaN
#
#    culture-values  carreer-opportunities  comp-benefit  senior-mangemnet  \
# 0             5.0                    5.0           4.0               5.0
# 6             5.0                    5.0           5.0               4.0
# 7             NaN                    2.0           NaN               NaN
# 8             5.0                    5.0           5.0               5.0
# 9             NaN                    NaN           NaN               NaN
#
#    helpful-count
# 0              0
# 6              2
# 7              1
# 8              1
# 9              0
