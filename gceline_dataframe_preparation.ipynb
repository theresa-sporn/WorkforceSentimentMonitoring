# %%
import pandas as pd

# %%
path_submission = '/Users/celinegianduzzo/code/theresa-sporn/WorkforceSentimentMonitoring/raw_data/sample_submission.csv'

# %%
submission = pd.read_csv(path_submission)

# %%
submission.shape
# Out:
# (29272, 2)

# %%
submission.tail()
# Out:
#           ID  overall
# 29267  66959        4
# 29268  66965        2
# 29269  66968        3
# 29270  66978        1
# 29271  66986        4

# %%
path_train = '/Users/celinegianduzzo/code/theresa-sporn/WorkforceSentimentMonitoring/raw_data/train.csv'

train = pd.read_csv(path_train)

# %%
path_test = '/Users/celinegianduzzo/code/theresa-sporn/WorkforceSentimentMonitoring/raw_data/test.csv'

test = pd.read_csv(path_test)

# %%
train.shape
# Out:
# (30336, 17)

# %%
test.shape
# Out:
# (29272, 16)

# %%
test = pd.merge(test, submission, on=['ID'])

# %%
test
# Out:
#           ID      Place                      location           date  \
# 0          5  startup_1               Los Angeles, CA   Jul 19, 2018
# 1          6  startup_1             Mountain View, CA    Dec 9, 2018
# 2          7  startup_1                  New York, NY   Dec 11, 2018
# 3          8  startup_1                           NaN   Dec 11, 2018
# 4          9  startup_1                  New York, NY   Dec 10, 2018
# 5         11  startup_1             Mountain View, CA    Dec 8, 2018
# 6         12  startup_1                           NaN    Dec 8, 2018
# 7         13  startup_1                           NaN    Dec 4, 2018
# 8         14  startup_1             San Francisco, CA    Dec 3, 2018
# 9         15  startup_1                           NaN    Dec 6, 2018
# 10        20  startup_1                           NaN    Dec 3, 2018
# 11        21  startup_1                  New York, NY   Nov 26, 2018
# 12        22  startup_1                           NaN    Dec 2, 2018
# ...

# %%
train
# Out:
#           ID      Place                      location           date  \
# 0          1  startup_1                           NaN   Dec 11, 2018
# 1          2  startup_1             Mountain View, CA   Jun 21, 2013
# 2          3  startup_1                  New York, NY   May 10, 2014
# 3          4  startup_1             Mountain View, CA    Feb 8, 2015
# 4         10  startup_1                           NaN    Dec 9, 2018
# 5         16  startup_1                           NaN    Dec 6, 2018
# 6         17  startup_1                           NaN   Nov 29, 2018
# 7         18  startup_1                           NaN    Dec 2, 2018
# 8         19  startup_1                           NaN    Dec 1, 2018
# 9         24  startup_1                           NaN   Nov 30, 2018
# 10        25  startup_1               Los Angeles, CA   Nov 29, 2018
# 11        27  startup_1                           NaN   Nov 28, 2018
# 12        29  startup_1                           NaN   Nov 27, 2018
# ...

# %%
frames = [train, test]

df_categories = pd.concat(frames)

# %%
df_categories.isnull().sum()
# Out:
# ID                    0
# Place                 0
# location          20879
# date                  0
# status                0
# job_title             0
# summary             103
# positives             0
# negatives             1
# advice_to_mgmt    25796
# score_1            3186
# score_2            6050
# score_3            3169
# score_4            3191
# score_5            3485
# score_6               0
# overall               0
# dtype: int64

# %%
df_categories = df_categories.rename(columns={'score_1':'work-balance', 'score_2':'culture-values', 'score_3':'carreer-opportunities', 'score_4':'comp-benefit', 'score_5':'senior-mangemnet', 'score_6':'helpful-count'})

# %%
df_categories.head()
# Out:
#    ID      Place           location           date             status  \
# 0   1  startup_1                NaN   Dec 11, 2018  Current Employee
# 1   2  startup_1  Mountain View, CA   Jun 21, 2013   Former Employee
# 2   3  startup_1       New York, NY   May 10, 2014  Current Employee
# 3   4  startup_1  Mountain View, CA    Feb 8, 2015  Current Employee
# 4  10  startup_1                NaN    Dec 9, 2018  Current Employee
#
#                 job_title                                            summary  \
# 0      Anonymous Employee                           Best Company to work for
# 1         Program Manager  Moving at the speed of light, burn out is inev...
# 2   Software Engineer III  Great balance between big-company security and...
# 3      Anonymous Employee  The best place I've worked and also the most d...
# 4      Anonymous Employee                           Execellent for engineers
#
#                                            positives  \
# ...

# %%
df_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59608 entries, 0 to 29271
# Data columns (total 17 columns):
# ID                       59608 non-null int64
# Place                    59608 non-null object
# location                 38729 non-null object
# date                     59608 non-null object
# status                   59608 non-null object
# job_title                59608 non-null object
# summary                  59505 non-null object
# positives                59608 non-null object
# negatives                59607 non-null object
# advice_to_mgmt           33812 non-null object
# work-balance             56422 non-null float64
# culture-values           53558 non-null float64
# carreer-opportunities    56439 non-null float64
# comp-benefit             56417 non-null float64
# senior-mangemnet         56123 non-null float64
# helpful-count            59608 non-null int64
# overall                  59608 non-null float64
# dtypes: float64(6), int64(2), object(9)
# ...
