# %% [markdown]
# # Model Prototype

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Libraries & Packages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from textblob import TextBlob
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("../raw_data/train.csv", nrows=100)

# %%
df = df.drop(columns=['ID', 'Place', 'location', 'date', 'status', 'job_title'])

# %%
df.head()
# Out:
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                           Execellent for engineers
#
#                                            positives  \
# 0                      People are smart and friendly
# 1  1) Food, food, food. 15+ cafes on main campus ...
# 2  * If you're a software engineer, you're among ...
# 3  You can't find a more well-regarded company th...
# 4             Impact driven. Best tech in the world.
#
#                                            negatives  \
# 0                 Bureaucracy is slowing things down
# 1  1) Work/life balance. What balance? All those ...
# 2  * It *is* becoming larger, and with it comes g...
# 3  I live in SF so the commute can take between 1...
# 4  Size matters. Engineers are a bit disconnected...
#
#                                       advice_to_mgmt  score_1  score_2  \
# 0                                                NaN      4.0      5.0
# 1  1) Don't dismiss emotional intelligence and ad...      2.0      3.0
# 2  Keep the focus on the user. Everything else wi...      5.0      4.0
# 3  Keep on NOT micromanaging - that is a huge ben...      2.0      5.0
# 4                                                NaN      5.0      5.0
#
#    score_3  score_4  score_5  score_6  overall
# 0      5.0      4.0      5.0        0      5.0
# 1      3.0      5.0      3.0     2094      5.0
# 2      5.0      5.0      4.0      949      5.0
# 3      5.0      4.0      5.0      498      4.0
# 4      5.0      5.0      5.0        0      4.0

# %% [markdown]
# ## Models

# %% [markdown]
# ### Baseline Model

# %%
text = df.summary + ' ' + df.positives + ' ' + df.negatives

df['text'] = text

df = df.dropna(axis=0)

df = df.drop_duplicates()

df.head()
# Out:
#                                               summary  \
# 1   Moving at the speed of light, burn out is inev...
# 2   Great balance between big-company security and...
# 3   The best place I've worked and also the most d...
# 10                                         Accountant
# 21   Make sure you know what role you're applying for
#
#                                             positives  \
# 1   1) Food, food, food. 15+ cafes on main campus ...
# 2   * If you're a software engineer, you're among ...
# 3   You can't find a more well-regarded company th...
# 10   I like and learned from the beginning accounting
# 21  Employees, food, benefits, perks, shuttle, bas...
#
#                                             negatives  \
# 1   1) Work/life balance. What balance? All those ...
# 2   * It *is* becoming larger, and with it comes g...
# 3   I live in SF so the commute can take between 1...
# 10              High clerical work in the Sane record
# 21  Company has become way too vertical, performan...
#
#                                        advice_to_mgmt  score_1  score_2  \
# 1   1) Don't dismiss emotional intelligence and ad...      2.0      3.0
# 2   Keep the focus on the user. Everything else wi...      5.0      4.0
# 3   Keep on NOT micromanaging - that is a huge ben...      2.0      5.0
# 10  Management and Finance must be close relation ...      5.0      5.0
# 21  Stop putting people on a bell curve, and recog...      4.0      4.0
#
#     score_3  score_4  score_5  score_6  overall  \
# 1       3.0      5.0      3.0     2094      5.0
# 2       5.0      5.0      4.0      949      5.0
# 3       5.0      4.0      5.0      498      4.0
# 10      5.0      5.0      5.0        0      4.0
# 21      5.0      5.0      2.0        0      5.0
#
#                                                  text
# 1   Moving at the speed of light, burn out is inev...
# 2   Great balance between big-company security and...
# 3   The best place I've worked and also the most d...
# 10  Accountant I like and learned from the beginni...
# 21  Make sure you know what role you're applying f...

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df.text).toarray()

y = df.score_1.astype('uint8')

# %%
model = MultinomialNB()
model.fit(X, y)
model.score(X, y)
# baseline score ==> features: 3 parts of texts; target: score_1
# Out:
# 0.6818181818181818

# %% [markdown]
# ### Model

# %%
df = pd.read_csv("../raw_data/train.csv", nrows=100)

df = df.drop(columns=['ID', 'Place', 'location', 'date', 'status', 'job_title', 'score_6'])

# %%
# drop rows with na values in score cols
score_cols = ['score_1', 'score_2', 'score_3', 'score_4', 'score_5', 'overall']
df = df.dropna(axis=0, subset=score_cols)
df = df.drop_duplicates()

# %%
# cast score cols as integers
float_cols = df.select_dtypes(float).columns
df[float_cols] = df[float_cols].astype('uint8')

# %%
df.head()
# Out:
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                           Execellent for engineers
#
#                                            positives  \
# 0                      People are smart and friendly
# 1  1) Food, food, food. 15+ cafes on main campus ...
# 2  * If you're a software engineer, you're among ...
# 3  You can't find a more well-regarded company th...
# 4             Impact driven. Best tech in the world.
#
#                                            negatives  \
# 0                 Bureaucracy is slowing things down
# 1  1) Work/life balance. What balance? All those ...
# 2  * It *is* becoming larger, and with it comes g...
# 3  I live in SF so the commute can take between 1...
# 4  Size matters. Engineers are a bit disconnected...
#
#                                       advice_to_mgmt  score_1  score_2  \
# 0                                                NaN        4        5
# 1  1) Don't dismiss emotional intelligence and ad...        2        3
# 2  Keep the focus on the user. Everything else wi...        5        4
# 3  Keep on NOT micromanaging - that is a huge ben...        2        5
# 4                                                NaN        5        5
#
#    score_3  score_4  score_5  overall
# 0        5        4        5        5
# 1        3        5        3        5
# 2        5        5        4        5
# 3        5        4        5        4
# 4        5        5        5        4

# %%
df.summary.shape
# Out:
# (77,)

# %%
feature_cols = ['summary', 'positives', 'negatives', 'advice_to_mgmt']

# combine all text columns
df['text_combined'] = df[feature_cols].astype('U').agg(' '.join, axis=1)

feature_cols.append('text_combined')

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df.text_combined).toarray()
y = df.score_1

# %%
model = MultinomialNB()
model.fit(X, y)
# append predictions to df
df['text_combined_score_1'] = model.predict(X)

# %%
model.score(X,y)
# baseline score ==> features: 4 parts of texts; target: score_1
# Out:
# 0.6363636363636364

# %% [markdown]
# ### Feature Engineering

# %%
# iterate over features and append results to df as new cols

result_scores = {}

for feature in feature_cols:
    scores_dic = {}
    
    for score in score_cols:
        vectorizer = TfidfVectorizer()
        X = vectorizer.fit_transform(df[feature].astype('U'))
        y = df[score]
        model = MultinomialNB()
        model.fit(X, y)
        df[f'{feature}_{score}'] = model.predict(X)
        scores_dic[f'{score}'] = model.score(X, y)
        
    result_scores[f'{feature}'] = scores_dic

# %%
scores_dic
# Out:
# {'score_1': {'summary': 0.7142857142857143,
#   'positives': 0.6363636363636364,
#   'negatives': 0.6883116883116883,
#   'advice_to_mgmt': 0.5454545454545454,
#   'text_combined': 0.6363636363636364},
#  'score_2': {'summary': 0.7142857142857143,
#   'positives': 0.6103896103896104,
#   'negatives': 0.6103896103896104,
#   'advice_to_mgmt': 0.6103896103896104,
#   'text_combined': 0.6103896103896104},
#  'score_3': {'summary': 0.6623376623376623,
#   'positives': 0.5844155844155844,
#   'negatives': 0.6103896103896104,
#   'advice_to_mgmt': 0.6103896103896104,
#   'text_combined': 0.5714285714285714},
#  'score_4': {'summary': 0.7272727272727273,
#   'positives': 0.7142857142857143,
#   'negatives': 0.7142857142857143,
#   'advice_to_mgmt': 0.7142857142857143,
#   'text_combined': 0.7142857142857143},
#  'score_5': {'summary': 0.7402597402597403,
#   'positives': 0.7402597402597403,
#   'negatives': 0.7402597402597403,
#   'advice_to_mgmt': 0.5064935064935064,
#   'text_combined': 0.7532467532467533},
#  'overall': {'summary': 0.8181818181818182,
#   'positives': 0.8701298701298701,
#   'negatives': 0.8961038961038961,
#   'advice_to_mgmt': 0.5064935064935064,
#   'text_combined': 0.922077922077922}}

# %%
df.head()
# Out:
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                           Execellent for engineers
#
#                                            positives  \
# 0                      People are smart and friendly
# 1  1) Food, food, food. 15+ cafes on main campus ...
# 2  * If you're a software engineer, you're among ...
# 3  You can't find a more well-regarded company th...
# 4             Impact driven. Best tech in the world.
#
#                                            negatives  \
# 0                 Bureaucracy is slowing things down
# 1  1) Work/life balance. What balance? All those ...
# 2  * It *is* becoming larger, and with it comes g...
# 3  I live in SF so the commute can take between 1...
# 4  Size matters. Engineers are a bit disconnected...
#
#                                       advice_to_mgmt  score_1  score_2  \
# 0                                                NaN        4        5
# 1  1) Don't dismiss emotional intelligence and ad...        2        3
# 2  Keep the focus on the user. Everything else wi...        5        4
# 3  Keep on NOT micromanaging - that is a huge ben...        2        5
# 4                                                NaN        5        5
#
#    score_3  score_4  score_5  overall  ... advice_to_mgmt_score_2  \
# 0        5        4        5        5  ...                      5
# 1        3        5        3        5  ...                      5
# 2        5        5        4        5  ...                      5
# 3        5        4        5        4  ...                      5
# 4        5        5        5        4  ...                      5
#
#    advice_to_mgmt_score_3  advice_to_mgmt_score_4  advice_to_mgmt_score_5  \
# 0                       5                       5                       5
# 1                       5                       5                       3
# 2                       5                       5                       4
# 3                       5                       5                       5
# 4                       5                       5                       5
#
#    advice_to_mgmt_overall  text_combined_score_2  text_combined_score_3  \
# 0                       4                      5                      5
# 1                       5                      5                      5
# 2                       5                      5                      5
# 3                       4                      5                      5
# 4                       4                      5                      5
#
#    text_combined_score_4  text_combined_score_5  text_combined_overall
# 0                      5                      5                      5
# 1                      5                      4                      5
# 2                      5                      4                      5
# 3                      5                      4                      4
# 4                      5                      5                      4
#
# [5 rows x 41 columns]

# %%
result_scores
# Out:
# {'summary': {'score_1': 0.7142857142857143,
#   'score_2': 0.7142857142857143,
#   'score_3': 0.6623376623376623,
#   'score_4': 0.7272727272727273,
#   'score_5': 0.7402597402597403,
#   'overall': 0.8181818181818182},
#  'positives': {'score_1': 0.6363636363636364,
#   'score_2': 0.6103896103896104,
#   'score_3': 0.5844155844155844,
#   'score_4': 0.7142857142857143,
#   'score_5': 0.7402597402597403,
#   'overall': 0.8701298701298701},
#  'negatives': {'score_1': 0.6883116883116883,
#   'score_2': 0.6103896103896104,
#   'score_3': 0.6103896103896104,
#   'score_4': 0.7142857142857143,
#   'score_5': 0.7402597402597403,
#   'overall': 0.8961038961038961},
#  'advice_to_mgmt': {'score_1': 0.5454545454545454,
#   'score_2': 0.6103896103896104,
#   'score_3': 0.6103896103896104,
#   'score_4': 0.7142857142857143,
#   'score_5': 0.5064935064935064,
#   'overall': 0.5064935064935064},
#  'text_combined': {'score_1': 0.6363636363636364,
#   'score_2': 0.6103896103896104,
#   'score_3': 0.5714285714285714,
#   'score_4': 0.7142857142857143,
#   'score_5': 0.7532467532467533,
#   'overall': 0.922077922077922}}

# %%
# iterate over features and append results to df as new cols

scores_dic = {}
for score in score_cols:

    result_scores = {}
    for feature in feature_cols:
        vectorizer = TfidfVectorizer()
        X = vectorizer.fit_transform(df[feature].astype('U'))
        y = df[score]
        model = MultinomialNB()
        model.fit(X, y)
        df[f'{feature}_{score}'] = model.predict(X)
        result_scores[f'{feature}'] = model.score(X, y)
        
    scores_dic[f'{score}'] = result_scores

# %%
scores_df = pd.DataFrame(scores_dic).T

# %%
# visualise prediction capability of every text slice

fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(1,1,1)
scores_df.plot(kind='bar', ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
  return TextBlob(text).sentiment.polarity

for feature in feature_cols:
    df[f'subjectivity_{feature}'] = df[feature].astype('U').apply(getSubjectivity)
    df[f'polarity_{feature}'] = df[feature].astype('U').apply(getPolarity)

# %%
# Create a function to get the total length of the reviews
def get_lengths(df):
    '''returns a df with columns with the length of the reviews'''
    func = lambda x: len(x) if type(x) == str else 0
    df['summary_length'] = df['summary'].apply(func)
    df['postives_length'] = df['positives'].apply(func)
    df['negatives_length'] = df['negatives'].apply(func)
    df['advice_length'] = df['advice_to_mgmt'].apply(func)
    df['combined_length'] = df['text_combined'].apply(func)
    return df

df = get_lengths(df)
df
# Out:
#                                               summary  \
# 0                            Best Company to work for
# 1   Moving at the speed of light, burn out is inev...
# 2   Great balance between big-company security and...
# 3   The best place I've worked and also the most d...
# 4                            Execellent for engineers
# ..                                                ...
# 93                               Partnerships Manager
# 94  A company culture build around the millenial s...
# 95   Great company - Long hours depending on position
# 96                                    Product Manager
# 98                                Great Place to work
#
#                                             positives  \
# 0                       People are smart and friendly
# 1   1) Food, food, food. 15+ cafes on main campus ...
# 2   * If you're a software engineer, you're among ...
# 3   You can't find a more well-regarded company th...
# 4              Impact driven. Best tech in the world.
# ..                                                ...
# 93  Tons of opportunity. Great people. Excellent p...
# 94                 Cost or budget is never a concern.
# 95          Great culture, offices, benefits, people.
# 96             Love Marketing so much an have willing
# 98               Compensation, benefits, and autonomy
#
#                                             negatives  \
# 0                  Bureaucracy is slowing things down
# 1   1) Work/life balance. What balance? All those ...
# 2   * It *is* becoming larger, and with it comes g...
# 3   I live in SF so the commute can take between 1...
# 4   Size matters. Engineers are a bit disconnected...
# ..                                                ...
# 93  Corporate hierarchy. Slow-moving HR. Growth bo...
# 94  The company culture is like a millennial perso...
# 95  Working with execs requires long demanding hou...
# 96                    Some stress but will reomove it
# 98                        Siloed environment at times
#
#                                        advice_to_mgmt  score_1  score_2  \
# 0                                                 NaN        4        5
# 1   1) Don't dismiss emotional intelligence and ad...        2        3
# 2   Keep the focus on the user. Everything else wi...        5        4
# 3   Keep on NOT micromanaging - that is a huge ben...        2        5
# 4                                                 NaN        5        5
# ..                                                ...      ...      ...
# 93                                                NaN        4        5
# 94  If a manager has over a dozen reports than cha...        3        2
# 95                                                NaN        5        5
# 96                                           Be Smart        4        5
# 98                                                NaN        5        5
#
#     score_3  score_4  score_5  overall  ... polarity_negatives  \
# 0         5        4        5        5  ...          -0.155556
# 1         3        5        3        5  ...           0.002447
# 2         5        5        4        5  ...           0.051936
# 3         5        4        5        4  ...           0.115871
# 4         5        5        5        4  ...           0.000000
# ..      ...      ...      ...      ...  ...                ...
# 93        4        5        4        3  ...           0.333333
# 94        2        4        4        4  ...           0.056410
# 95        4        5        5        5  ...          -0.075000
# 96        4        4        4        4  ...           0.000000
# 98        5        5        4        4  ...           0.000000
#
#     subjectivity_advice_to_mgmt  polarity_advice_to_mgmt  \
# 0                      0.000000                 0.000000
# 1                      0.523077                 0.500000
# 2                      0.000000                 0.000000
# 3                      0.640000                 0.260000
# 4                      0.000000                 0.000000
# ..                          ...                      ...
# 93                     0.000000                 0.000000
# 94                     0.000000                 0.000000
# 95                     0.000000                 0.000000
# 96                     0.642857                 0.214286
# 98                     0.000000                 0.000000
#
#     subjectivity_text_combined  polarity_text_combined  summary_length  \
# 0                     0.432937                0.358433              24
# 1                     0.595586                0.151979              52
# 2                     0.489631                0.133697              72
# 3                     0.594688                0.172253              55
# 4                     0.300000                1.000000              24
# ..                         ...                     ...             ...
# 93                    0.690000                0.573333              20
# 94                    0.421795                0.056410              54
# 95                    0.540000                0.280000              48
# 96                    0.548214                0.291071              15
# 98                    0.750000                0.800000              19
#
#     postives_length  negatives_length  advice_length  combined_length
# 0                29                34              0               93
# 1              1048              2403           1004             4510
# 2              3634              1064             56             4829
# 3              1572              2614            295             4539
# 4                38                62              0              130
# ..              ...               ...            ...              ...
# 93               78               105              0              209
# 94               34               652             93              836
# 95               41                66              0              161
# 96               38                31              8               95
# 98               36                27              0               88
#
# [77 rows x 56 columns]

# %% [markdown]
# ### Scaling

# %%
# scale new features
length_cols = [col for col in df.columns if 'length' in col]

for col in length_cols:
    scaler = MinMaxScaler()
    df[col] = scaler.fit_transform(df[[col]])

# %%
# select X
X = df.iloc[:, 11:]

# %%
# scale score features
pred_scores_cols = [col for col in X.columns if 'score' in col and not 'reg' in col]

for col in pred_scores_cols:
    scaler = MinMaxScaler()
    X[col] = scaler.fit_transform(X[[col]])

# %%
X.head()
# Out:
#    text_combined_score_1  summary_score_1  summary_score_2  summary_score_3  \
# 0                    1.0              0.5              1.0              1.0
# 1                    1.0              0.5              1.0              1.0
# 2                    1.0              1.0              0.5              1.0
# 3                    1.0              1.0              1.0              1.0
# 4                    1.0              1.0              1.0              1.0
#
#    summary_score_4  summary_score_5  summary_overall  positives_score_1  \
# 0              1.0              1.0                4                0.0
# 1              1.0              0.0                5                1.0
# 2              1.0              0.5                5                1.0
# 3              1.0              1.0                4                1.0
# 4              1.0              1.0                4                1.0
#
#    positives_score_2  positives_score_3  ...  polarity_negatives  \
# 0                0.0                1.0  ...           -0.155556
# 1                0.0                1.0  ...            0.002447
# 2                0.0                1.0  ...            0.051936
# 3                0.0                1.0  ...            0.115871
# 4                0.0                1.0  ...            0.000000
#
#    subjectivity_advice_to_mgmt  polarity_advice_to_mgmt  \
# 0                     0.000000                     0.00
# 1                     0.523077                     0.50
# 2                     0.000000                     0.00
# 3                     0.640000                     0.26
# 4                     0.000000                     0.00
#
#    subjectivity_text_combined  polarity_text_combined  summary_length  \
# 0                    0.432937                0.358433        0.333333
# 1                    0.595586                0.151979        0.722222
# 2                    0.489631                0.133697        1.000000
# 3                    0.594688                0.172253        0.763889
# 4                    0.300000                1.000000        0.333333
#
#    postives_length  negatives_length  advice_length  combined_length
# 0         0.001938          0.005013       0.000000         0.006920
# 1         0.284053          0.918627       1.000000         0.933110
# 2         1.000000          0.402237       0.055777         1.000000
# 3         0.429125          1.000000       0.293825         0.939191
# 4         0.004430          0.015812       0.000000         0.014678
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Linear Regression to engineer numerical features

# %%
# linear regression with just the predictions for each model
for col in score_cols:
    model = LinearRegression()
    model.fit(X, df[col])
    X[f'reg_{col}'] = model.predict(X)
    scaler = MinMaxScaler()
    X[f'reg_{col}'] = scaler.fit_transform(X[[f'reg_{col}']])

# %%
X
# Out:
#     text_combined_score_1  summary_score_1  summary_score_2  summary_score_3  \
# 0                     1.0              0.5              1.0              1.0
# 1                     1.0              0.5              1.0              1.0
# 2                     1.0              1.0              0.5              1.0
# 3                     1.0              1.0              1.0              1.0
# 4                     1.0              1.0              1.0              1.0
# ..                    ...              ...              ...              ...
# 93                    0.0              0.5              1.0              1.0
# 94                    1.0              0.0              1.0              1.0
# 95                    1.0              1.0              1.0              0.0
# 96                    0.0              1.0              1.0              1.0
# 98                    1.0              1.0              1.0              1.0
#
#     summary_score_4  summary_score_5  summary_overall  positives_score_1  \
# 0               1.0              1.0                4                0.0
# 1               1.0              0.0                5                1.0
# 2               1.0              0.5                5                1.0
# 3               1.0              1.0                4                1.0
# 4               1.0              1.0                4                1.0
# ..              ...              ...              ...                ...
# 93              1.0              0.5                3                0.0
# 94              1.0              0.5                4                1.0
# 95              1.0              1.0                5                1.0
# 96              1.0              0.5                4                0.0
# 98              1.0              1.0                4                1.0
#
#     positives_score_2  positives_score_3  ...  postives_length  \
# 0                 0.0                1.0  ...         0.001938
# 1                 0.0                1.0  ...         0.284053
# 2                 0.0                1.0  ...         1.000000
# 3                 0.0                1.0  ...         0.429125
# 4                 0.0                1.0  ...         0.004430
# ..                ...                ...  ...              ...
# 93                0.0                1.0  ...         0.015504
# 94                0.0                1.0  ...         0.003322
# 95                0.0                1.0  ...         0.005260
# 96                0.0                0.0  ...         0.004430
# 98                0.0                1.0  ...         0.003876
#
#     negatives_length  advice_length  combined_length  reg_score_1  \
# 0           0.005013       0.000000         0.006920     0.669600
# 1           0.918627       1.000000         0.933110     0.179659
# 2           0.402237       0.055777         1.000000     0.893823
# 3           1.000000       0.293825         0.939191     0.132008
# 4           0.015812       0.000000         0.014678     0.910894
# ..               ...            ...              ...          ...
# 93          0.032395       0.000000         0.031243     0.525976
# 94          0.243347       0.092629         0.162718     0.454640
# 95          0.017354       0.000000         0.021178     0.896499
# 96          0.003857       0.007968         0.007339     0.651006
# 98          0.002314       0.000000         0.005871     0.737000
#
#     reg_score_2  reg_score_3  reg_score_4  reg_score_5  reg_overall
# 0      0.918531     0.657959     0.591068     0.896815     0.991062
# 1      0.329929     0.242772     0.678263     0.372461     0.910620
# 2      0.667653     0.879970     0.824546     0.695136     0.961619
# 3      0.842432     0.805220     0.597683     0.873549     0.731335
# 4      0.888431     1.000000     0.849824     0.967985     0.711356
# ..          ...          ...          ...          ...          ...
# 93     0.827653     0.540897     0.821950     0.581735     0.352787
# 94     0.217449     0.178099     0.520203     0.592408     0.764458
# 95     0.962279     0.626447     0.834270     1.000000     0.997371
# 96     0.858607     0.578806     0.489056     0.652259     0.699264
# 98     0.982666     0.886516     0.773931     0.755076     0.606730
#
# [77 rows x 51 columns]

# %% [markdown]
# ### Logistic Regression

# %%
# classification with scores as targets
def train(X, y):
    predictions = pd.DataFrame()
    pred_scores = {}
    for target in score_cols:
        model = LogisticRegression(max_iter=1000)
        y = df[target]
        model.fit(X, y)
        predictions[target] = model.predict(X)
        pred_scores[target] = model.score(X, y)
    return predictions, pred_scores

# %% [markdown]
# ### Test package

# %%
from WorkforceSentimentMonitoring.trainer import Trainer

# %%
df
# Out:
#                                               summary  \
# 0                            Best Company to work for
# 1   Moving at the speed of light, burn out is inev...
# 2   Great balance between big-company security and...
# 3   The best place I've worked and also the most d...
# 4                            Execellent for engineers
# ..                                                ...
# 93                               Partnerships Manager
# 94  A company culture build around the millenial s...
# 95   Great company - Long hours depending on position
# 96                                    Product Manager
# 98                                Great Place to work
#
#                                             positives  \
# 0                       People are smart and friendly
# 1   1) Food, food, food. 15+ cafes on main campus ...
# 2   * If you're a software engineer, you're among ...
# 3   You can't find a more well-regarded company th...
# 4              Impact driven. Best tech in the world.
# ..                                                ...
# 93  Tons of opportunity. Great people. Excellent p...
# 94                 Cost or budget is never a concern.
# 95          Great culture, offices, benefits, people.
# 96             Love Marketing so much an have willing
# 98               Compensation, benefits, and autonomy
#
#                                             negatives  \
# 0                  Bureaucracy is slowing things down
# 1   1) Work/life balance. What balance? All those ...
# 2   * It *is* becoming larger, and with it comes g...
# 3   I live in SF so the commute can take between 1...
# 4   Size matters. Engineers are a bit disconnected...
# ..                                                ...
# 93  Corporate hierarchy. Slow-moving HR. Growth bo...
# 94  The company culture is like a millennial perso...
# 95  Working with execs requires long demanding hou...
# 96                    Some stress but will reomove it
# 98                        Siloed environment at times
#
#                                        advice_to_mgmt  score_1  score_2  \
# 0                                                 NaN        4        5
# 1   1) Don't dismiss emotional intelligence and ad...        2        3
# 2   Keep the focus on the user. Everything else wi...        5        4
# 3   Keep on NOT micromanaging - that is a huge ben...        2        5
# 4                                                 NaN        5        5
# ..                                                ...      ...      ...
# 93                                                NaN        4        5
# 94  If a manager has over a dozen reports than cha...        3        2
# 95                                                NaN        5        5
# 96                                           Be Smart        4        5
# 98                                                NaN        5        5
#
#     score_3  score_4  score_5  overall  \
# 0         5        4        5        5
# 1         3        5        3        5
# 2         5        5        4        5
# 3         5        4        5        4
# 4         5        5        5        4
# ..      ...      ...      ...      ...
# 93        4        5        4        3
# 94        2        4        4        4
# 95        4        5        5        5
# 96        4        4        4        4
# 98        5        5        4        4
#
#                                         text_combined  text_combined_score_1
# 0   Best Company to work for People are smart and ...                      5
# 1   Moving at the speed of light, burn out is inev...                      5
# 2   Great balance between big-company security and...                      5
# 3   The best place I've worked and also the most d...                      5
# 4   Execellent for engineers Impact driven. Best t...                      5
# ..                                                ...                    ...
# 93  Partnerships Manager Tons of opportunity. Grea...                      4
# 94  A company culture build around the millenial s...                      5
# 95  Great company - Long hours depending on positi...                      5
# 96  Product Manager Love Marketing so much an have...                      4
# 98  Great Place to work Compensation, benefits, an...                      5
#
# [77 rows x 12 columns]

# %%
from WorkforceSentimentMonitoring.trainer import FEATURE_COLS, SCORE_COLS, feature_engineer, getSubjectivity, getPolarity, feature_sentiment, get_lengths, scaler, linear_feature

# %%
df = feature_engineer(df)

# %%
df = feature_sentiment(df)

# %%
df = get_lengths(df)

# %%
X = scaler(df)

# %%
X = linear_feature(X, df)

# %%
trainer = Trainer(X, y)

# %%
predictions = trainer.train(df)[0]
pred_scores = trainer.train(df)[1]

# %%
predictions
# Out:
#     score_1  score_2  score_3  score_4  score_5  overall
# 0         4        5        5        5        5        5
# 1         2        3        3        5        3        5
# 2         5        4        5        5        4        5
# 3         2        5        5        5        5        4
# 4         5        5        5        5        5        4
# ..      ...      ...      ...      ...      ...      ...
# 72        4        5        4        5        4        3
# 73        3        4        2        5        4        4
# 74        5        5        4        5        5        5
# 75        4        5        4        4        4        4
# 76        5        5        5        5        4        4
#
# [77 rows x 6 columns]

# %%
pred_scores
# Out:
# {'score_1': 0.948051948051948,
#  'score_2': 0.8441558441558441,
#  'score_3': 0.8051948051948052,
#  'score_4': 0.8441558441558441,
#  'score_5': 0.922077922077922,
#  'overall': 0.961038961038961}

# %%
plt.bar(range(len(pred_scores)), list(pred_scores.values()), align='center')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### Optimization

# %%
# Get data with our own functions, train & test splits
from WorkforceSentimentMonitoring.data import get_data, merge, holdout

submission, train, test = get_data()

display(submission.head())
display(train.head())
display(test.head())

# %%
# merge corresponding dataframes
df = merge(submission, train, test)

# %%
df.head()

# %%
# extract review lengths
