# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /Users/yunxizzy/code/theresa-sporn/WorkforceSentimentMonitoring

# %%
ls
# Out:
# MANIFEST.in                            lexicon/
# Makefile                               notebooks/
# Procfile                               raw_data/
# README.md                              requirements.txt
# WorkforceSentimentMonitoring/          scripts/
# WorkforceSentimentMonitoring.egg-info/ setup.py
# app.py                                 setup.sh
# build/                                 test_data/
# dist/                                  tests/
# joblib_files/

# %% [markdown]
# # import test data

# %%
from test_data.backup_test_data import get_test_data

# %%
input_data = get_test_data()
input_data
# Out:
#                                              positives  \
# 0    You're surrounded by smart people and the proj...
# 1    Brand name is great. Have yet to meet somebody...
# 2    Good money.Interaction with some great minds i...
# 3           nice pay and overtime and different shifts
# 4            Opportunity for those not afraid to work!
# ..                                                 ...
# 495  Compensation is great. Learning on and designi...
# 496                                   Seattle downtown
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                                              negatives  \
# 0    Internal tools proliferation has created a mes...
# 1    not the most stimulating work. Good brand name...
# 2    No proper growth plan for employees.Difficult ...
# 3                        didn't last quite long enough
# ...

# %%
test = input_data[['review']]
test
# Out:
#                                                 review
# 0    You're surrounded by smart people and the proj...
# 1    Brand name is great. Have yet to meet somebody...
# 2    Good money.Interaction with some great minds i...
# 3    nice pay and overtime and different shifts did...
# 4    Opportunity for those not afraid to work! Oppo...
# ..                                                 ...
# 495  Compensation is great. Learning on and designi...
# 496  Seattle downtown Politics influence your ratin...
# 497                                            nan nan
# 498                                            nan nan
# 499                                            nan nan
#
# [500 rows x 1 columns]

# %%
test_cp = test.copy()
test_cp
# Out:
#                                                 review
# 0    You're surrounded by smart people and the proj...
# 1    Brand name is great. Have yet to meet somebody...
# 2    Good money.Interaction with some great minds i...
# 3    nice pay and overtime and different shifts did...
# 4    Opportunity for those not afraid to work! Oppo...
# ..                                                 ...
# 495  Compensation is great. Learning on and designi...
# 496  Seattle downtown Politics influence your ratin...
# 497                                            nan nan
# 498                                            nan nan
# 499                                            nan nan
#
# [500 rows x 1 columns]

# %% [markdown]
# # Try out pipeline

# %%
import joblib
import os

# %%
os_path = os.getcwd()
os_path_abs = '/'.join(os_path.split('/')[:-1])
pipe_path = os.path.join(os_path_abs,'WorkforceSentimentMonitoring/joblib_files')
pipe_path
# Out:
# '/Users/yunxizzy/code/theresa-sporn/WorkforceSentimentMonitoring/joblib_files'

# %%
last_pipe = joblib.load(os.path.join(pipe_path, 'feature_pipeline.joblib'))
last_pipe
# Out:
# Pipeline(steps=[('first_pipe',
#                  Pipeline(steps=[('preprocessor', Preprocessor()),
#                                  ('emo_extractor', EmotionScoresExtractor()),
#                                  ('scaler', CustomMinMaxScaler()),
#                                  ('engineer', FeatureEngineer())])),
#                 ('mnb', MultiNBFeaturesExtractor())])

# %%
test_fea = last_pipe.fit_transform(test_cp)
test_fea
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 913.34it/s]
#                                                 review    length  anger_score  \
# 0    you are surrounded by smart people and the pro...  0.247059     0.126304
# 1    brand name is great have yet to meet somebody ...  0.358824     0.052395
# 2    good money interaction with some great mind in...  0.264706     0.010967
# 3    nice pay and overtime and different shift did ...  0.064706     0.000000
# 4    opportunity for those not afraid to work oppor...  0.076471     0.000000
# ..                                                 ...       ...          ...
# 495  compensation is great learning on and designin...  0.317647     0.142021
# 496  seattle downtown politics influence your ratin...  0.035294     0.167153
# 497                                            nan nan  0.000000     0.000000
# 498                                            nan nan  0.000000     0.000000
# ...

# %% [markdown]
# ## detect wrong language

# %%
from WorkforceSentimentMonitoring.data import detect_wrong_language, drop_wrong_language

# %%
tures = detect_wrong_language(test_fea, 'review')
# Out:
# ...
# 100%|██████████| 10/10 [00:48<00:00,  4.80s/it]

# %%
tures.value_counts()
# Out:
# False    493
# True       7
# Name: review, dtype: int64

# %%
test_eng = drop_wrong_language(test_fea, 'review')
test_eng
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Identifying entries in other languages...
# ...
# 100%|██████████| 10/10 [00:48<00:00,  4.80s/it]
# Drop 7 entries? [y] / n
# y
# Dropping 7 entries...
#                                                 review    length  anger_score  \
# 0    you are surrounded by smart people and the pro...  0.247059     0.126304
# 1    brand name is great have yet to meet somebody ...  0.358824     0.052395
# 2    good money interaction with some great mind in...  0.264706     0.010967
# 3    nice pay and overtime and different shift did ...  0.064706     0.000000
# 4    opportunity for those not afraid to work oppor...  0.076471     0.000000
# ..                                                 ...       ...          ...
# 488  good hour nice pay and lot of people to meet g...  0.188235     0.000000
# 489  great entry level job for pay and benefit lear...  0.194118     0.011562
# 490  good pay good benefit you get to work with som...  0.270588     0.088252
# ...

# %% [markdown]
# # Try out predict model

# %%
from WorkforceSentimentMonitoring.trainer import Classifier

# %%
clf = Classifier()

# %%
pred = clf.fit_transform(test_fea)
pred
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Identifying entries in other languages...
# ...
# 100%|██████████| 10/10 [00:48<00:00,  4.80s/it]
# Drop 6 entries? [y] / n
# y
# Dropping 6 entries...
#      work-life-balance  culture-values  career-opportunities  \
# 0                    0               0                     0
# 1                    0               0                     0
# 2                    0               0                     0
# 3                    0               0                     0
# 4                    0               0                     0
# ..                 ...             ...                   ...
# 489                  0               0                     0
# 490                  0               0                     0
# 491                  1               1                     0
# 492                  0               0                     0
# 493                  0               0                     0
#
# ...

# %%
test_pred = clf.fit_transform(test_eng)
test_pred
# Out:
#      work-life-balance  culture-values  career-opportunities  \
# 0                    0               0                     0
# 1                    0               0                     0
# 2                    0               0                     0
# 3                    0               0                     0
# 4                    0               0                     0
# ..                 ...             ...                   ...
# 488                  0               0                     0
# 489                  0               0                     0
# 490                  1               1                     0
# 491                  0               0                     0
# 492                  0               0                     0
#
#      company-benefits  senior-management  overall
# 0                   0                  0        0
# 1                   0                  0        0
# 2                   0                  0        0
# ...

# %% [markdown]
# # Final model

# %%
from sklearn.pipeline import Pipeline

# %%
use_case_pipe = Pipeline([
    ('features', last_pipe),
    ('sgd', Classifier())
])

# %%
def export_joblib(estimator, name):
    dirname = os.path.abspath('')
    filename = os.path.join(dirname, f'../WorkforceSentimentMonitoring/joblib_files/{name}.joblib')
    joblib.dump(estimator, filename)

# %%
export_joblib(use_case_pipe, 'use_case_pipeline')
