# %%
import pandas as pd
import numpy as np
import os

# %%
path = os.path.join(os.getcwd(), '../raw_data')

data_prep = pd.read_csv(os.path.join(path, 'x_train_preprocessed.csv'))
data_prep
# Out:
#        Unnamed: 0                                            summary  \
# 0               0                        good job considering retail
# 1               1                         warning potential new hire
# 2               2     demanding job get work brilliant mind industry
# 3               3                                  deliver get fired
# 4               4                           good salary perk benefit
# 5               5                          happy year working amazon
# 6               6                      one hopefully soon remembered
# 7               7                                    hardwork peanut
# 8               8                                 software developer
# 9               9          everyone high stress company growing pain
# 10             10                                            awesome
# 11             11                                   exciting journey
# 12             12                                    good place grow
# 13             13  best company work awesome work culture high value
# 14             14                                       area manager
# 15             15                 really horrible employee treatment
# 16             16                                              happy
# 17             17                                  software engineer
# 18             18                              ’ tough job rewarding
# 19             19                                                NaN
# 20             20                              best retail job world
# 21             21                                               good
# 22             22                               former employer year
# 23             23                    great company ethos shared site
# 24             24                                             amazon
# 25             25                                        store clark
# 26             26  amazing retail opportunity amazing career oppo...
# 27             27   awesome people great chalenges wonderful company
# 28             28                                 impactful stagnant
# 29             29                                great company enter
# ...           ...                                                ...
# 36940       36940                                    internet retail
# 36941       36941                                    amazing company
# 36942       36942                                             review
# 36943       36943                           amazing opportunity make
# 36944       36944              work smartest people deal bureaucracy
# 36945       36945                       email agent customer service
# 36946       36946                                      test engineer
# 36947       36947                              excellent environment
# 36948       36948                      good emplyee friendly company
# 36949       36949                               packing box scanning
# 36950       36950                  great experience well compensated
# 36951       36951                                             genius
# 36952       36952                      software development engineer
# 36953       36953                                     getting better
# 36954       36954                                      promotability
# 36955       36955                                          hard work
# 36956       36956                        technology behemoth pro con
# 36957       36957                                      sps associate
# 36958       36958                great company lot place move around
# 36959       36959    apple retail experience specialist fr fantastic
# 36960       36960                   manager iii program management l
# 36961       36961                                   apple specialist
# 36962       36962                                    make better got
# 36963       36963                                     amazonian make
# 36964       36964                               company great leader
# 36965       36965                                   great experience
# 36966       36966                        awesome ceo amazing company
# 36967       36967  great benefit need way training along apple cu...
# 36968       36968                                               icqa
# 36969       36969                                      general labor
#
#                                                positives  \
# 0      apple good company period pay average working ...
# 1                good pay smart coworkers good insurance
# 2      intelligent co worker encouraged innovate good...
# 3      pay competitive look good resume move around i...
# 4                               good salary perk benefit
# 5      great people challenging project fast paced en...
# 6      great experience advancement understanding uti...
# 7                          fellow team member great work
# 8                                 really nothing share v
# 9      world class benefit smart coworkers food galor...
# 10                  people technology impact scale money
# 11                          team work international echo
# 12                           dynamic fast moving company
# 13     good salary lot opportunity work different tec...
# 14     intelligent staff opportunity career developme...
# 15     easy straight forward job computer system easy...
# 16                                great brand add resume
# 17                   flexible work hour good environment
# 18          great pay great benefit lot cool people work
# 19     job lot flexibility scheduling allowed work bi...
# 20     people work every day customer contemporary di...
# 21       good hour everything dont see working long term
# 22                  good money smart people travel world
# 23              good salary great benefit flexible staff
# 24                                        okay easy work
# 25     work genius every department create innovative...
# 26     staff health benefit even part time employee v...
# 27     still feel like startup kind tech chalenges re...
# 28     part team smart caring approachable feel like ...
# 29     great benefit salary good need add benefit pac...
# ...                                                  ...
# 36940          stock option hiring bonus real dress code
# 36941  free self actualizing environment ever worked ...
# 36942        great people environment culture great well
# 36943  work solution architect amazon web service ama...
# 36944  microsoft company really make ton learning opp...
# 36945  good company work great lead manager good scop...
# 36946  innovation fast pace new stuff work time effic...
# 36947                overall supportive work environment
# 36948             employee friendly company good benefit
# 36949  company offer really good benefit well opportu...
# 36950  love working apple opportunity second none get...
# 36951  building relationship customer enriching life ...
# 36952  great work environment lot learning ideal plac...
# 36953                      good salary work life balance
# 36954                     fast growing company potential
# 36955  good option people right high school good opti...
# 36956        find diversity thing work many smart people
# 36957  amazon leading e commerce company best work right
# 36958                                 nice perk employee
# 36959  flexible hour plenty opportunity shift many op...
# 36960  thing happen fast good learning good culture g...
# 36961  meet good people diverse workforce good traini...
# 36962  working amazon expose weakness choose work get...
# 36963  fast pace easy pick day insurance peak dauntin...
# 36964  competitive pay good benefit growing company o...
# 36965  working environment google provide allow emplo...
# 36966  great working diverse people focused company s...
# 36967  work home great medical benefit decent pay gre...
# 36968     plenty overtime staff friendly usually helpful
# 36969  good pay amazing coworkers good hour lot overtime
#
#                                                negatives  \
# 0      job movement lateral extremely difficult get p...
# 1      hr protect company employee careful restricted...
# 2      promote work life balance word employee get re...
# 3      work life balance hostile environment reward b...
# 4      hectic schedule u ill learning cutting technology
# 5      hard get often turn away good people left clea...
# 6                       always enough time meet deadline
# 7                limited opportunity move within company
# 8                                  everything terrible v
# 9      work life balance unrealistic recruiting expec...
# 10        growing inertia mono culture better learn love
# 11                        con find big corporate company
# 12        getting bureaucratic many reporting goal clear
# 13                                         find con till
# 14     getting promoted depends know loud one would n...
# 15     high pressure bad treatment really bad hour re...
# 16     sure start bad management bad attitude recogni...
# 17                                       pay competitive
# 18     customer ridiculously high expectation apple g...
# 19     dealing angry customer worth hr system complic...
# 20     busy always foot retail environment customer o...
# 21                               feel like slave company
# 22     reorganization every year expect find job give...
# 23     far many hour worked nothing average hour week...
# 24                       get tiresome enough people work
# 25     zero zero zero work life balance exec saying y...
# 26     customer good long term career solution hard t...
# 27     medium harsh sometimes make feel good understa...
# 28     much opportunity growth depending location lea...
# 29     good new grade since google promotion easy big...
# ...                                                  ...
# 36940  foot hour day poor management leadership ambig...
# 36941        need lot structure wont find con pro others
# 36942  current management without vision seems know g...
# 36943  unrest really con job sa job right everyone jo...
# 36944  microsoft large k employee old founded pocket ...
# 36945                le pay outsourcing customer service
# 36946  crazy vacation day burned long weekend work cu...
# 36947                                  people may career
# 36948                              manual work automated
# 36949  management really suck demand really appreciat...
# 36950  hour long management always maintain common me...
# 36951                  scheduling course management type
# 36952                              oncall get tough time
# 36953  manager self consumed motivated undermine effo...
# 36954                    nepotism every level management
# 36955  long hour foot learn several area make people ...
# 36956  politics large part work sometime far business...
# 36957                                much con best place
# 36958                    sometimes workload overwhelming
# 36959  aside holiday hour retail store expected retai...
# 36960  work life balance challenge another challenge ...
# 36961  management shady selfish customer take frustra...
# 36962  mention tough place work go ahead cancel gym m...
# 36963  starting amazon life little feeling need ask q...
# 36964  lack development say development cop manager i...
# 36965  problem challenged sometimes hard meet require...
# 36966  competitive pressure side require u responsive...
# 36967  schedule whether part time full time offer lit...
# 36968  routine get promoted higher function depend li...
# 36969      night shift tough hard part trying stay awake
#
#                                           advice_to_mgmt  \
# 0                                                    NaN
# 1      many employment contract state restricted stoc...
# 2      employee get burned soon life outside work goi...
# 3                                      people disposable
# 4                                                    NaN
# 5                           great hiring need get better
# 6      keep positive attitude try cooperate much poss...
# 7            try treat team member like robot like human
# 8                                                    NaN
# 9      stop micromanaging sourcers current recruiting...
# 10                                                   NaN
# 11                                                   NaN
# 12                                le reporting real work
# 13                                                  none
# 14     pay bit attention quiet one fact quiet doesnt ...
# 15                                                   NaN
# 16     stop promoting hypocrisy focus good people ins...
# 17                                                   NaN
# 18     know came management position clothing store c...
# 19                                   training contact tl
# 20             maintain human element never let go credo
# 21                           create better bond employee
# 22                                                  none
# 23                                                   NaN
# 24     listen associate instead standing around talki...
# 25                                                   NaN
# 26                           really maybe take seriously
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 36940     read win friend influence people dale carnegie
# 36941                                                NaN
# 36942                                                NaN
# 36943  think lot people read bad press life amazon re...
# 36944  became lead given formal training think pickin...
# 36945                                     keep good work
# 36946        let people go vacation need avoid burn like
# 36947                                                NaN
# 36948               defined career progression guideline
# 36949                                                NaN
# 36950                                                NaN
# 36951      work team put personal aspiration back burner
# 36952                                                NaN
# 36953  empower respect engineer good check manager ab...
# 36954                           become technically sound
# 36955                                                NaN
# 36956                            get mobile right please
# 36957                                               none
# 36958                                              agile
# 36959                                                NaN
# 36960  treat indian employee par seattle respect timi...
# 36961  dont treat part time employee like red head st...
# 36962  director stop allowing anyone agenda project r...
# 36963  attention onboarding new hire ambassador spott...
# 36964  going advertise company great place work grow ...
# 36965                                                NaN
# 36966   keep going cloud first mobile first strategy win
# 36967  moving advisor team manager team manager way b...
# 36968             get trainer want see new employee well
# 36969                                        water break
#
#                                                   review  summary_length  \
# 0      good job considering retail apple good company...              31
# 1      warning potential new hire good pay smart cowo...              31
# 2      demanding job get work brilliant mind industry...              87
# 3      deliver get fired pay competitive look good re...              21
# 4      good salary perk benefit good salary perk bene...              34
# 5      happy year working amazon great people challen...              45
# 6      one hopefully soon remembered great experience...              35
# 7      hardwork peanut fellow team member great work ...              20
# 8      software developer really nothing share v ever...              18
# 9      everyone high stress company growing pain worl...              56
# 10     awesome people technology impact scale money g...               7
# 11     exciting journey team work international echo ...              17
# 12     good place grow dynamic fast moving company ge...              20
# 13     best company work awesome work culture high va...              58
# 14     area manager intelligent staff opportunity car...              12
# 15     really horrible employee treatment easy straig...              34
# 16     happy great brand add resume sure start bad ma...               9
# 17     software engineer flexible work hour good envi...              17
# 18     ’ tough job rewarding great pay great benefit ...              36
# 19     job lot flexibility scheduling allowed work bi...              11
# 20     best retail job world people work every day cu...              28
# 21     good good hour everything dont see working lon...              18
# 22     former employer year good money smart people t...              28
# 23     great company ethos shared site good salary gr...              43
# 24     amazon okay easy work get tiresome enough peop...               6
# 25     store clark work genius every department creat...              11
# 26     amazing retail opportunity amazing career oppo...              61
# 27     awesome people great chalenges wonderful compa...              50
# 28     impactful stagnant part team smart caring appr...              23
# 29     great company enter great benefit salary good ...              25
# ...                                                  ...             ...
# 36940  internet retail stock option hiring bonus real...              15
# 36941  amazing company free self actualizing environm...              15
# 36942  review great people environment culture great ...               6
# 36943  amazing opportunity make work solution archite...              48
# 36944  work smartest people deal bureaucracy microsof...              57
# 36945  email agent customer service good company work...              29
# 36946  test engineer innovation fast pace new stuff w...              13
# 36947  excellent environment overall supportive work ...              21
# 36948  good emplyee friendly company employee friendl...              33
# 36949  packing box scanning company offer really good...              32
# 36950  great experience well compensated love working...              34
# 36951  genius building relationship customer enrichin...               6
# 36952  software development engineer great work envir...              31
# 36953  getting better good salary work life balance m...              14
# 36954  promotability fast growing company potential n...              13
# 36955  hard work good option people right high school...               9
# 36956  technology behemoth pro con find diversity thi...              38
# 36957  sps associate amazon leading e commerce compan...              13
# 36958  great company lot place move around nice perk ...              44
# 36959  apple retail experience specialist fr fantasti...              61
# 36960  manager iii program management l thing happen ...              36
# 36961  apple specialist meet good people diverse work...              16
# 36962  make better got working amazon expose weakness...              62
# 36963  amazonian make fast pace easy pick day insuran...              42
# 36964  company great leader competitive pay good bene...              32
# 36965  great experience working environment google pr...              16
# 36966  awesome ceo amazing company great working dive...              29
# 36967  great benefit need way training along apple cu...              79
# 36968  icqa plenty overtime staff friendly usually he...               4
# 36969  general labor good pay amazing coworkers good ...              13
#
#        postives_length  negatives_length  advice_length  ...  \
# 0                  118               127              0  ...
# 1                   41               132           1509  ...
# 2                   89               164            150  ...
# 3                  189               306             26  ...
# 4                   34                57              0  ...
# 5                   59               108             50  ...
# 6                  121                40             80  ...
# 7                   44                50             67  ...
# 8                   26                28              0  ...
# 9                   60               235            238  ...
# 10                  41                62              0  ...
# 11                  32                40              0  ...
# 12                  31                57             30  ...
# 13                  67                32              4  ...
# 14                 269               151            112  ...
# 15                  55                78              0  ...
# 16                  33                87             63  ...
# 17                  36                28              0  ...
# 18                  60               224            258  ...
# 19                 105               119             34  ...
# 20                 176               233             54  ...
# 21                  70                41             34  ...
# 22                  42                83              4  ...
# 23                  46               116              0  ...
# 24                  22                54            166  ...
# 25                 159               406              0  ...
# 26                 256                84             70  ...
# 27                 279               148              0  ...
# 28                 130               125              0  ...
# 29                 113               147              0  ...
# ...                ...               ...            ...  ...
# 36940               48                82             64  ...
# 36941              270               100              0  ...
# 36942               51                91              0  ...
# 36943             1373               826            258  ...
# 36944              314               383            231  ...
# 36945              108                54             21  ...
# 36946              111               112             72  ...
# 36947               41                39              0  ...
# 36948               44                41             44  ...
# 36949               88                99              0  ...
# 36950              165               114              0  ...
# 36951               88                50             73  ...
# 36952              101                29              0  ...
# 36953               30                93            128  ...
# 36954               35                37             24  ...
# 36955               79                92              0  ...
# 36956               62               100             23  ...
# 36957               76                45              5  ...
# 36958               28                38             13  ...
# 36959              303               135              0  ...
# 36960              111                89             77  ...
# 36961              121               223            174  ...
# 36962              901               118            240  ...
# 36963              116               248             98  ...
# 36964               92               376            355  ...
# 36965               83                78              0  ...
# 36966              139                98             68  ...
# 36967               88               113            538  ...
# 36968               68                88             50  ...
# 36969               56                64             17  ...
#
#        subjectivity_summary  polarity_summary  subjectivity_positives  \
# 0                  0.600000          0.700000                0.666667
# 1                  0.727273          0.068182                0.614286
# 2                  1.000000          0.900000                0.833333
# 3                  0.000000          0.000000                0.460714
# 4                  0.600000          0.700000                0.600000
# 5                  1.000000          0.800000                0.783333
# 6                  0.000000          0.000000                0.575000
# 7                  0.000000          0.000000                0.750000
# 8                  0.000000          0.000000                0.200000
# 9                  0.540000          0.160000                0.421429
# 10                 1.000000          1.000000                0.000000
# 11                 0.800000          0.300000                0.000000
# 12                 0.600000          0.700000                0.383333
# 13                 0.613333          0.720000                0.600000
# 14                 0.000000          0.000000                0.561905
# 15                 1.000000         -1.000000                0.688889
# 16                 1.000000          0.800000                0.750000
# 17                 0.000000          0.000000                0.600000
# 18                 0.916667          0.055556                0.716667
# 19                 0.000000          0.000000                0.000000
# 20                 0.300000          1.000000                0.355556
# 21                 0.600000          0.700000                0.500000
# 22                 0.000000          0.000000                0.621429
# 23                 0.750000          0.800000                0.675000
# 24                 0.000000          0.000000                0.666667
# 25                 0.000000          0.000000                0.727273
# 26                 0.900000          0.600000                0.751786
# 27                 0.916667          0.933333                0.750000
# 28                 0.000000          0.000000                0.321429
# 29                 0.750000          0.800000                0.675000
# ...                     ...               ...                     ...
# 36940              0.000000          0.000000                0.300000
# 36941              0.900000          0.600000                0.640000
# 36942              0.000000          0.000000                0.750000
# 36943              0.900000          0.600000                0.475175
# 36944              0.000000          0.000000                0.466667
# 36945              0.000000          0.000000                0.650000
# 36946              0.000000          0.000000                0.684848
# 36947              1.000000          1.000000                0.500000
# 36948              0.550000          0.537500                0.550000
# 36949              0.000000          0.000000                0.300000
# 36950              0.750000          0.800000                0.437500
# 36951              0.000000          0.000000                0.000000
# 36952              0.000000          0.000000                0.745833
# 36953              0.500000          0.500000                0.600000
# 36954              0.000000          0.000000                0.800000
# 36955              0.541667         -0.291667                0.568929
# 36956              0.000000          0.000000                0.571429
# 36957              0.000000          0.000000                0.417857
# 36958              0.750000          0.800000                1.000000
# 36959              0.900000          0.400000                0.440476
# 36960              0.000000          0.000000                0.600000
# 36961              0.000000          0.000000                0.666667
# 36962              0.500000          0.500000                0.502547
# 36963              0.000000          0.000000                0.700000
# 36964              0.750000          0.800000                0.550000
# 36965              0.750000          0.800000                0.200000
# 36966              0.950000          0.800000                0.546429
# 36967              0.750000          0.800000                0.604762
# 36968              0.000000          0.000000                0.375000
# 36969              0.500000          0.050000                0.700000
#
#        polarity_positives  subjectivity_negatives  polarity_negatives  \
# 0                0.516667                1.000000           -0.500000
# 1                0.538095                0.625000            0.075000
# 2                0.783333                0.000000            0.000000
# 3                0.403571                0.492063            0.031746
# 4                0.700000                0.950000           -0.550000
# 5                0.500000                0.381250            0.127083
# 6                0.450000                0.500000            0.000000
# 7                0.800000                0.142857           -0.071429
# 8                0.200000                1.000000           -1.000000
# 9                0.257143                0.644444           -0.300000
# 10               0.000000                0.550000            0.500000
# 11               0.000000                0.050000            0.000000
# 12               0.100000                0.441667            0.300000
# 13               0.350000                0.000000            0.000000
# 14               0.328571                0.600000            0.250000
# 15               0.355556                0.530833           -0.310000
# 16               0.800000                0.743056           -0.025000
# 17               0.700000                0.000000            0.000000
# 18               0.650000                0.320000            0.080000
# 19               0.000000                0.640000            0.040000
# 20               0.222222                0.685000            0.120000
# 21               0.325000                0.000000            0.000000
# 22               0.457143                0.000000            0.000000
# 23               0.750000                0.740000           -0.110000
# 24               0.466667                0.750000           -0.250000
# 25               0.318182                0.467143            0.217143
# 26               0.121429                0.385417            0.089583
# 27               0.666667                0.600000            0.333333
# 28               0.107143                0.200000            0.200000
# 29               0.750000                0.414646            0.169949
# ...                   ...                     ...                 ...
# 36940            0.200000                0.600000           -0.400000
# 36941            0.680000                0.000000            0.000000
# 36942            0.800000                0.400000           -0.025000
# 36943            0.141051                0.409226            0.332143
# 36944            0.133333                0.561669            0.224843
# 36945            0.733333                0.000000            0.000000
# 36946            0.312121                0.425000           -0.037500
# 36947            0.250000                0.000000            0.000000
# 36948            0.537500                0.000000            0.000000
# 36949            0.350000                0.200000            0.200000
# 36950            0.375000                0.450000           -0.175000
# 36951            0.000000                0.000000            0.000000
# 36952            0.608333                0.833333           -0.388889
# 36953            0.700000                0.000000            0.000000
# 36954            0.100000                0.000000            0.000000
# 36955            0.461429                0.200000           -0.025000
# 36956            0.357143                0.714286            0.157143
# 36957            0.642857                0.250000            0.600000
# 36958            0.600000                1.000000            0.500000
# 36959            0.404762                0.266667           -0.033333
# 36960            0.600000                0.000000            0.000000
# 36961            0.508333                0.558333           -0.266667
# 36962            0.223127                0.833333           -0.388889
# 36963            0.266667                0.400000           -0.197500
# 36964            0.350000                0.400000            0.500000
# 36965            0.200000                0.541667           -0.291667
# 36966            0.421429                0.000000            0.000000
# 36967            0.210476                0.525000            0.081250
# 36968            0.062500                0.500000            0.250000
# 36969            0.666667                0.687500           -0.340278
#
#        subjectivity_advice_to_mgmt  polarity_advice_to_mgmt  \
# 0                         0.000000                 0.000000
# 1                         0.499852                 0.120897
# 2                         0.368750                -0.156250
# 3                         0.000000                 0.000000
# 4                         0.000000                 0.000000
# 5                         0.625000                 0.650000
# 6                         0.772727                 0.113636
# 7                         0.100000                 0.000000
# 8                         0.000000                 0.000000
# 9                         0.594444                -0.133333
# 10                        0.000000                 0.000000
# 11                        0.000000                 0.000000
# 12                        0.300000                 0.200000
# 13                        0.000000                 0.000000
# 14                        0.451389                -0.104167
# 15                        0.000000                 0.000000
# 16                        0.600000                 0.700000
# 17                        0.000000                 0.000000
# 18                        0.350000                 0.062500
# 19                        0.000000                 0.000000
# 20                        0.100000                 0.000000
# 21                        0.500000                 0.500000
# 22                        0.000000                 0.000000
# 23                        0.000000                 0.000000
# 24                        1.000000                 0.500000
# 25                        0.000000                 0.000000
# 26                        0.433333                -0.066667
# 27                        0.000000                 0.000000
# 28                        0.000000                 0.000000
# 29                        0.000000                 0.000000
# ...                            ...                      ...
# 36940                     0.400000                 0.800000
# 36941                     0.000000                 0.000000
# 36942                     0.000000                 0.000000
# 36943                     0.608571                 0.122857
# 36944                     0.350000                 0.266667
# 36945                     0.600000                 0.700000
# 36946                     0.000000                 0.000000
# 36947                     0.000000                 0.000000
# 36948                     0.000000                 0.000000
# 36949                     0.000000                 0.000000
# 36950                     0.000000                 0.000000
# 36951                     0.150000                 0.000000
# 36952                     0.000000                 0.000000
# 36953                     0.600000                 0.700000
# 36954                     0.400000                 0.400000
# 36955                     0.000000                 0.000000
# 36956                     0.535714                 0.285714
# 36957                     0.000000                 0.000000
# 36958                     0.750000                 0.500000
# 36959                     0.000000                 0.000000
# 36960                     0.000000                 0.000000
# 36961                     0.391667                 0.116667
# 36962                     0.666667                 0.333333
# 36963                     0.454545                 0.136364
# 36964                     0.675000                 0.295000
# 36965                     0.000000                 0.000000
# 36966                     0.355556                 0.433333
# 36967                     0.602778                 0.297222
# 36968                     0.454545                 0.136364
# 36969                     0.000000                 0.000000
#
#        subjectivity_review  polarity_review
# 0                 0.720000         0.350000
# 1                 0.536005         0.157255
# 2                 0.706250         0.489583
# 3                 0.474150         0.244218
# 4                 0.775000         0.075000
# 5                 0.612500         0.410833
# 6                 0.639091         0.225455
# 7                 0.330952         0.242857
# 8                 0.600000        -0.400000
# 9                 0.566614        -0.069524
# 10                0.700000         0.666667
# 11                0.225000         0.075000
# 12                0.425000         0.283333
# 13                0.608000         0.572000
# 14                0.543800         0.200744
# 15                0.648750        -0.146667
# 16                0.760317         0.314286
# 17                0.600000         0.700000
# 18                0.547576         0.224646
# 19                0.640000         0.040000
# 20                0.489167         0.226667
# 21                0.525000         0.462500
# 22                0.414286         0.304762
# 23                0.725000         0.218750
# 24                0.766667         0.186667
# 25                0.541466         0.246011
# 26                0.601290         0.159226
# 27                0.754167         0.650000
# 28                0.280952         0.138095
# 29                0.509764         0.368855
# ...                    ...              ...
# 36940             0.433333         0.200000
# 36941             0.683333         0.666667
# 36942             0.575000         0.387500
# 36943             0.482003         0.201530
# 36944             0.517397         0.212913
# 36945             0.637500         0.725000
# 36946             0.536364         0.112338
# 36947             0.666667         0.500000
# 36948             0.550000         0.537500
# 36949             0.250000         0.275000
# 36950             0.485714         0.278571
# 36951             0.150000         0.000000
# 36952             0.763333         0.408889
# 36953             0.566667         0.633333
# 36954             0.666667         0.200000
# 36955             0.459626         0.214864
# 36956             0.621429         0.262857
# 36957             0.333929         0.621429
# 36958             0.875000         0.600000
# 36959             0.434286         0.272857
# 36960             0.600000         0.600000
# 36961             0.551667         0.158333
# 36962             0.533320         0.209068
# 36963             0.506061        -0.005682
# 36964             0.602500         0.397500
# 36965             0.497222         0.236111
# 36966             0.572487         0.509524
# 36967             0.602891         0.271301
# 36968             0.426136         0.127841
# 36969             0.662500         0.228241
#
# [36970 rows x 51 columns]

# %%
negatives = data_prep.negatives.dropna()
negatives
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0        job movement lateral extremely difficult get p...
# 1        hr protect company employee careful restricted...
# 2        promote work life balance word employee get re...
# 3        work life balance hostile environment reward b...
# 4        hectic schedule u ill learning cutting technology
# 5        hard get often turn away good people left clea...
# 6                         always enough time meet deadline
# 7                  limited opportunity move within company
# 8                                    everything terrible v
# 9        work life balance unrealistic recruiting expec...
# 10          growing inertia mono culture better learn love
# 11                          con find big corporate company
# 12          getting bureaucratic many reporting goal clear
# 13                                           find con till
# 14       getting promoted depends know loud one would n...
# 15       high pressure bad treatment really bad hour re...
# 16       sure start bad management bad attitude recogni...
# 17                                         pay competitive
# 18       customer ridiculously high expectation apple g...
# 19       dealing angry customer worth hr system complic...
# 20       busy always foot retail environment customer o...
# 21                                 feel like slave company
# 22       reorganization every year expect find job give...
# 23       far many hour worked nothing average hour week...
# 24                         get tiresome enough people work
# 25       zero zero zero work life balance exec saying y...
# 26       customer good long term career solution hard t...
# 27       medium harsh sometimes make feel good understa...
# 28       much opportunity growth depending location lea...
# 29       good new grade since google promotion easy big...
#                                ...
# 36940    foot hour day poor management leadership ambig...
# 36941          need lot structure wont find con pro others
# 36942    current management without vision seems know g...
# 36943    unrest really con job sa job right everyone jo...
# 36944    microsoft large k employee old founded pocket ...
# 36945                  le pay outsourcing customer service
# 36946    crazy vacation day burned long weekend work cu...
# 36947                                    people may career
# 36948                                manual work automated
# 36949    management really suck demand really appreciat...
# 36950    hour long management always maintain common me...
# 36951                    scheduling course management type
# 36952                                oncall get tough time
# 36953    manager self consumed motivated undermine effo...
# 36954                      nepotism every level management
# 36955    long hour foot learn several area make people ...
# 36956    politics large part work sometime far business...
# 36957                                  much con best place
# 36958                      sometimes workload overwhelming
# 36959    aside holiday hour retail store expected retai...
# 36960    work life balance challenge another challenge ...
# 36961    management shady selfish customer take frustra...
# 36962    mention tough place work go ahead cancel gym m...
# 36963    starting amazon life little feeling need ask q...
# 36964    lack development say development cop manager i...
# 36965    problem challenged sometimes hard meet require...
# 36966    competitive pressure side require u responsive...
# 36967    schedule whether part time full time offer lit...
# 36968    routine get promoted higher function depend li...
# 36969        night shift tough hard part trying stay awake
# Name: negatives, Length: 36961, dtype: object

# %%
negatives.dtype
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dtype('O')

# %%
from nltk import word_tokenize
def tokenize(df):
    tokenized_text = word_tokenize(str(df))
    return tokenized_text
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
negatives_tokenized = tokenize(negatives)
negatives_tokenized
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['0',
#  'job',
#  'movement',
#  'lateral',
#  'extremely',
#  'difficult',
#  'get',
#  'p',
#  '...',
#  '1',
#  'hr',
#  'protect',
#  'company',
#  'employee',
#  'careful',
#  'restricted',
#  '...',
#  '2',
#  'promote',
#  'work',
#  'life',
#  'balance',
#  'word',
#  'employee',
#  'get',
#  're',
#  '...',
#  '3',
#  'work',
#  'life',
#  'balance',
#  'hostile',
#  'environment',
#  'reward',
#  'b',
#  '...',
#  '4',
#  'hectic',
#  'schedule',
#  'u',
#  'ill',
#  'learning',
#  'cutting',
#  'technology',
#  '5',
#  'hard',
#  'get',
#  'often',
#  'turn',
#  'away',
#  'good',
#  'people',
#  'left',
#  'clea',
#  '...',
#  '6',
#  'always',
#  'enough',
#  'time',
#  'meet',
#  'deadline',
#  '7',
#  'limited',
#  'opportunity',
#  'move',
#  'within',
#  'company',
#  '8',
#  'everything',
#  'terrible',
#  'v',
#  '9',
#  'work',
#  'life',
#  'balance',
#  'unrealistic',
#  'recruiting',
#  'expec',
#  '...',
#  '10',
#  'growing',
#  'inertia',
#  'mono',
#  'culture',
#  'better',
#  'learn',
#  'love',
#  '11',
#  'con',
#  'find',
#  'big',
#  'corporate',
#  'company',
#  '12',
#  'getting',
#  'bureaucratic',
#  'many',
#  'reporting',
#  'goal',
#  'clear',
#  '13',
#  'find',
#  'con',
#  'till',
#  '14',
#  'getting',
#  'promoted',
#  'depends',
#  'know',
#  'loud',
#  'one',
#  'would',
#  'n',
#  '...',
#  '15',
#  'high',
#  'pressure',
#  'bad',
#  'treatment',
#  'really',
#  'bad',
#  'hour',
#  're',
#  '...',
#  '16',
#  'sure',
#  'start',
#  'bad',
#  'management',
#  'bad',
#  'attitude',
#  'recogni',
#  '...',
#  '17',
#  'pay',
#  'competitive',
#  '18',
#  'customer',
#  'ridiculously',
#  'high',
#  'expectation',
#  'apple',
#  'g',
#  '...',
#  '19',
#  'dealing',
#  'angry',
#  'customer',
#  'worth',
#  'hr',
#  'system',
#  'complic',
#  '...',
#  '20',
#  'busy',
#  'always',
#  'foot',
#  'retail',
#  'environment',
#  'customer',
#  'o',
#  '...',
#  '21',
#  'feel',
#  'like',
#  'slave',
#  'company',
#  '22',
#  'reorganization',
#  'every',
#  'year',
#  'expect',
#  'find',
#  'job',
#  'give',
#  '...',
#  '23',
#  'far',
#  'many',
#  'hour',
#  'worked',
#  'nothing',
#  'average',
#  'hour',
#  'week',
#  '...',
#  '24',
#  'get',
#  'tiresome',
#  'enough',
#  'people',
#  'work',
#  '25',
#  'zero',
#  'zero',
#  'zero',
#  'work',
#  'life',
#  'balance',
#  'exec',
#  'saying',
#  'y',
#  '...',
#  '26',
#  'customer',
#  'good',
#  'long',
#  'term',
#  'career',
#  'solution',
#  'hard',
#  't',
#  '...',
#  '27',
#  'medium',
#  'harsh',
#  'sometimes',
#  'make',
#  'feel',
#  'good',
#  'understa',
#  '...',
#  '28',
#  'much',
#  'opportunity',
#  'growth',
#  'depending',
#  'location',
#  'lea',
#  '...',
#  '29',
#  'good',
#  'new',
#  'grade',
#  'since',
#  'google',
#  'promotion',
#  'easy',
#  'big',
#  '...',
#  '...',
#  '36940',
#  'foot',
#  'hour',
#  'day',
#  'poor',
#  'management',
#  'leadership',
#  'ambig',
#  '...',
#  '36941',
#  'need',
#  'lot',
#  'structure',
#  'wont',
#  'find',
#  'con',
#  'pro',
#  'others',
#  '36942',
#  'current',
#  'management',
#  'without',
#  'vision',
#  'seems',
#  'know',
#  'g',
#  '...',
#  '36943',
#  'unrest',
#  'really',
#  'con',
#  'job',
#  'sa',
#  'job',
#  'right',
#  'everyone',
#  'jo',
#  '...',
#  '36944',
#  'microsoft',
#  'large',
#  'k',
#  'employee',
#  'old',
#  'founded',
#  'pocket',
#  '...',
#  '36945',
#  'le',
#  'pay',
#  'outsourcing',
#  'customer',
#  'service',
#  '36946',
#  'crazy',
#  'vacation',
#  'day',
#  'burned',
#  'long',
#  'weekend',
#  'work',
#  'cu',
#  '...',
#  '36947',
#  'people',
#  'may',
#  'career',
#  '36948',
#  'manual',
#  'work',
#  'automated',
#  '36949',
#  'management',
#  'really',
#  'suck',
#  'demand',
#  'really',
#  'appreciat',
#  '...',
#  '36950',
#  'hour',
#  'long',
#  'management',
#  'always',
#  'maintain',
#  'common',
#  'me',
#  '...',
#  '36951',
#  'scheduling',
#  'course',
#  'management',
#  'type',
#  '36952',
#  'oncall',
#  'get',
#  'tough',
#  'time',
#  '36953',
#  'manager',
#  'self',
#  'consumed',
#  'motivated',
#  'undermine',
#  'effo',
#  '...',
#  '36954',
#  'nepotism',
#  'every',
#  'level',
#  'management',
#  '36955',
#  'long',
#  'hour',
#  'foot',
#  'learn',
#  'several',
#  'area',
#  'make',
#  'people',
#  '...',
#  '36956',
#  'politics',
#  'large',
#  'part',
#  'work',
#  'sometime',
#  'far',
#  'business',
#  '...',
#  '36957',
#  'much',
#  'con',
#  'best',
#  'place',
#  '36958',
#  'sometimes',
#  'workload',
#  'overwhelming',
#  '36959',
#  'aside',
#  'holiday',
#  'hour',
#  'retail',
#  'store',
#  'expected',
#  'retai',
#  '...',
#  '36960',
#  'work',
#  'life',
#  'balance',
#  'challenge',
#  'another',
#  'challenge',
#  '...',
#  '36961',
#  'management',
#  'shady',
#  'selfish',
#  'customer',
#  'take',
#  'frustra',
#  '...',
#  '36962',
#  'mention',
#  'tough',
#  'place',
#  'work',
#  'go',
#  'ahead',
#  'cancel',
#  'gym',
#  'm',
#  '...',
#  '36963',
#  'starting',
#  'amazon',
#  'life',
#  'little',
#  'feeling',
#  'need',
#  'ask',
#  'q',
#  '...',
#  '36964',
#  'lack',
#  'development',
#  'say',
#  'development',
#  'cop',
#  'manager',
#  'i',
#  '...',
#  '36965',
#  'problem',
#  'challenged',
#  'sometimes',
#  'hard',
#  'meet',
#  'require',
#  '...',
#  '36966',
#  'competitive',
#  'pressure',
#  'side',
#  'require',
#  'u',
#  'responsive',
#  '...',
#  '36967',
#  'schedule',
#  'whether',
#  'part',
#  'time',
#  'full',
#  'time',
#  'offer',
#  'lit',
#  '...',
#  '36968',
#  'routine',
#  'get',
#  'promoted',
#  'higher',
#  'function',
#  'depend',
#  'li',
#  '...',
#  '36969',
#  'night',
#  'shift',
#  'tough',
#  'hard',
#  'part',
#  'trying',
#  'stay',
#  'awake',
#  'Name',
#  ':',
#  'negatives',
#  ',',
#  'Length',
#  ':',
#  '36961',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %%
import gensim
from gensim.models.phrases import Phrases
# Build the bigram and trigram models
bigram = gensim.models.Phrases(object_string, min_count=5, threshold=50) # higher threshold fewer phrases.
#trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
#trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(bigram_mod[bigram_mod[object_string]])
# Out:
# ['0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'j', 'o', 'b', ' ', 'm', 'o', 'v', 'e', 'm', 'e', 'n', 't', ' ', 'l', 'a', 't', 'e', 'r', 'a', 'l', ' ', 'e', 'x', 't', 'r', 'e', 'm', 'e', 'l', 'y', ' ', 'd', 'i', 'f', 'f', 'i', 'c', 'u', 'l', 't', ' ', 'g', 'e', 't', ' ', 'p', '.', '.', '.', '\n', '1', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'h', 'r', ' ', 'p', 'r', 'o', 't', 'e', 'c', 't', ' ', 'c', 'o', 'm', 'p', 'a', 'n', 'y', ' ', 'e', 'm', 'p', 'l', 'o', 'y', 'e', 'e', ' ', 'c', 'a', 'r', 'e', 'f', 'u', 'l', ' ', 'r', 'e', 's', 't', 'r', 'i', 'c', 't', 'e', 'd', '.', '.', '.', '\n', '2', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'p', 'r', 'o', 'm', 'o', 't', 'e', ' ', 'w', 'o', 'r', 'k', ' ', 'l', 'i', 'f', 'e', ' ', 'b', 'a', 'l', 'a', 'n', 'c', 'e', ' ', 'w', 'o', 'r', 'd', ' ', 'e', 'm', 'p', 'l', 'o', 'y', 'e', 'e', ' ', 'g', 'e', 't', ' ', 'r', 'e', '.', '.', '.', '\n', '3', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'w', 'o', 'r', 'k', ' ', 'l', 'i', 'f', 'e', ' ', 'b', 'a', 'l', 'a', 'n', 'c', 'e', ' ', 'h', 'o', 's', 't', 'i', 'l', 'e', ' ', 'e', 'n', 'v', 'i', 'r', 'o', 'n', 'm', 'e', 'n', 't', ' ', 'r', 'e', 'w', 'a', 'r', 'd', ' ', 'b', '.', '.', '.', '\n', '4', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'h', 'e', 'c', 't', 'i', 'c', ' ', 's', 'c', 'h', 'e', 'd', 'u', 'l', 'e', ' ', 'u', ' ', 'i', 'l', 'l', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 'c', 'u', 't', 't', 'i', 'n', 'g', ' ', 't', 'e', 'c', 'h', 'n', 'o', 'l', 'o', 'g', 'y', '\n', '5', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'h', 'a', 'r', 'd', ' ', 'g', 'e', 't', ' ', 'o', 'f', 't', 'e', 'n', ' ', 't', 'u', 'r', 'n', ' ', 'a', 'w', 'a', 'y', ' ', 'g', 'o', 'o', 'd', ' ', 'p', 'e', 'o', 'p', 'l', 'e', ' ', 'l', 'e', 'f', 't', ' ', 'c', 'l', 'e', 'a', '.', '.', '.', '\n', '6', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'a', 'l', 'w', 'a', 'y', 's', ' ', 'e', 'n', 'o', 'u', 'g', 'h', ' ', 't', 'i', 'm', 'e', ' ', 'm', 'e', 'e', 't', ' ', 'd', 'e', 'a', 'd', 'l', 'i', 'n', 'e', '\n', '7', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'l', 'i', 'm', 'i', 't', 'e', 'd', ' ', 'o', 'p', 'p', 'o', 'r', 't', 'u', 'n', 'i', 't', 'y', ' ', 'm', 'o', 'v', 'e', ' ', 'w', 'i', 't', 'h', 'i', 'n', ' ', 'c', 'o', 'm', 'p', 'a', 'n', 'y', '\n', '8', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'e', 'v', 'e', 'r', 'y', 't', 'h', 'i', 'n', 'g', ' ', 't', 'e', 'r', 'r', 'i', 'b', 'l', 'e', ' ', 'v', '\n', '9', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'w', 'o', 'r', 'k', ' ', 'l', 'i', 'f', 'e', ' ', 'b', 'a', 'l', 'a', 'n', 'c', 'e', ' ', 'u', 'n', 'r', 'e', 'a', 'l', 'i', 's', 't', 'i', 'c', ' ', 'r', 'e', 'c', 'r', 'u', 'i', 't', 'i', 'n', 'g', ' ', 'e', 'x', 'p', 'e', 'c', '.', '.', '.', '\n', '1', '0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'g', 'r', 'o', 'w', 'i', 'n', 'g', ' ', 'i', 'n', 'e', 'r', 't', 'i', 'a', ' ', 'm', 'o', 'n', 'o', ' ', 'c', 'u', 'l', 't', 'u', 'r', 'e', ' ', 'b', 'e', 't', 't', 'e', 'r', ' ', 'l', 'e', 'a', 'r', 'n', ' ', 'l', 'o', 'v', 'e', '\n', '1', '1', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'c', 'o', 'n', ' ', 'f', 'i', 'n', 'd', ' ', 'b', 'i', 'g', ' ', 'c', 'o', 'r', 'p', 'o', 'r', 'a', 't', 'e', ' ', 'c', 'o', 'm', 'p', 'a', 'n', 'y', '\n', '1', '2', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'g', 'e', 't', 't', 'i', 'n', 'g', ' ', 'b', 'u', 'r', 'e', 'a', 'u', 'c', 'r', 'a', 't', 'i', 'c', ' ', 'm', 'a', 'n', 'y', ' ', 'r', 'e', 'p', 'o', 'r', 't', 'i', 'n', 'g', ' ', 'g', 'o', 'a', 'l', ' ', 'c', 'l', 'e', 'a', 'r', '\n', '1', '3', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ...

# %%
print(bigram_mod[bigram_mod[negatives[0]]])
# Out:
# ['j', 'o', 'b', ' ', 'm', 'o', 'v', 'e', 'm', 'e', 'n', 't', ' ', 'l', 'a', 't', 'e', 'r', 'a', 'l', ' ', 'e', 'x', 't', 'r', 'e', 'm', 'e', 'l', 'y', ' ', 'd', 'i', 'f', 'f', 'i', 'c', 'u', 'l', 't', ' ', 'g', 'e', 't', ' ', 'p', 'r', 'o', 'm', 'o', 't', 'e', 'd', ' ', 'c', 'o', 'm', 'p', 'e', 't', 'i', 'n', 'g', ' ', 'c', 'o', 'w', 'o', 'r', 'k', 'e', 'r', 's', ' ', 's', 't', 'o', 'r', 'e']

# %%
from gensim.models import Phrases

from gensim.models.phrases import Phraser


sentence_stream = [doc.split(" ") for doc in negatives]
#print(sentence_stream)

bigram = Phrases(sentence_stream, min_count=3, threshold=4, delimiter=b' ')

bigram_phraser = Phraser(bigram)


#print(bigram_phraser)
tokens = []
for sent in sentence_stream:
    tokens_ = bigram_phraser[sent]
    tokens.append(tokens_)

tokens
    #print(tokens_)
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['job',
#   'movement',
#   'lateral',
#   'extremely difficult',
#   'get promoted',
#   'competing',
#   'coworkers',
#   'store'],
#  ['hr',
#   'protect',
#   'company',
#   'employee',
#   'careful',
#   'restricted stock',
#   'unit',
#   'awarded',
#   'exact',
#   'number'],
#  ['promote',
#   'work life',
#   'balance',
#   'word',
#   'employee',
#   'get recognized',
#   'hand',
#   'meeting',
#   'worked',
#   'hour week',
#   'never',
#   'took',
#   'time'],
#  ['work life',
#   'balance',
#   'hostile environment',
#   'reward',
#   'bully',
#   'limited',
#   'development',
#   'advancement',
#   'option',
#   'older employee',
#   'manager',
#   'check balance',
#   'get terminated',
#   'made',
#   'reason',
#   'employment',
#   'likely',
#   'rsus',
#   'vest',
#   'hr',
#   'support',
#   'manager',
#   'employee'],
#  ['hectic schedule', 'u', 'ill', 'learning', 'cutting', 'technology'],
#  ['hard get',
#   'often',
#   'turn',
#   'away',
#   'good',
#   'people left',
#   'clear',
#   'idea',
#   'make'],
#  ['always', 'enough', 'time', 'meet deadline'],
#  ['limited opportunity', 'move within', 'company'],
#  ['everything', 'terrible', 'v'],
#  ['work life',
#   'balance',
#   'unrealistic',
#   'recruiting',
#   'expectation',
#   'burnt',
#   'employee',
#   'constantly stressed',
#   'poor',
#   'office',
#   'morale',
#   'lack respect',
#   'management',
#   'career advancement',
#   'opportunity',
#   'unless',
#   'move',
#   'ca',
#   'headquarters'],
#  ['growing', 'inertia', 'mono', 'culture', 'better', 'learn', 'love'],
#  ['con', 'find', 'big', 'corporate', 'company'],
#  ['getting', 'bureaucratic', 'many', 'reporting', 'goal', 'clear'],
#  ['find con', 'till'],
#  ['getting promoted',
#   'depends',
#   'know',
#   'loud',
#   'one',
#   'would',
#   'notice',
#   'good',
#   'job',
#   'sometimes',
#   'long hour',
#   'working'],
#  ['high pressure',
#   'bad',
#   'treatment',
#   'really bad',
#   'hour',
#   'religious',
#   'accommodation'],
#  ['sure',
#   'start',
#   'bad',
#   'management',
#   'bad attitude',
#   'recognition',
#   'great',
#   'effort'],
#  ['pay competitive'],
#  ['customer',
#   'ridiculously high',
#   'expectation',
#   'apple',
#   'got ta',
#   'deal',
#   'manager',
#   'ex',
#   'gap',
#   'forever',
#   'manager',
#   '’',
#   'know anything',
#   'technical',
#   'charge',
#   'technician',
#   'tech',
#   'department'],
#  ['dealing angry',
#   'customer',
#   'worth',
#   'hr',
#   'system',
#   'complicated',
#   'training',
#   'actual',
#   'call',
#   'ideal'],
#  ['busy',
#   'always foot',
#   'retail environment',
#   'customer',
#   'often',
#   'difficult',
#   'demanding',
#   'pressure',
#   'even',
#   'greater',
#   'within apple',
#   'necessarily',
#   'answer',
#   'able find'],
#  ['feel like', 'slave', 'company'],
#  ['reorganization', 'every year', 'expect', 'find', 'job', 'given', 'july'],
#  ['far',
#   'many',
#   'hour',
#   'worked',
#   'nothing',
#   'average',
#   'hour week',
#   'people',
#   'wrong',
#   'position',
#   'making',
#   'wrong',
#   'decision'],
#  ['get', 'tiresome', 'enough', 'people', 'work'],
#  ['zero zero',
#   'zero work',
#   'life balance',
#   'exec',
#   'saying',
#   'year',
#   'understand',
#   'make',
#   'better',
#   'actuality',
#   'get',
#   'worse every',
#   'year',
#   'obviously',
#   'top management',
#   'lip service',
#   'meant',
#   'could',
#   'fix',
#   'tomorrow',
#   'hundred',
#   'billion',
#   'bank',
#   'really cared',
#   'employee',
#   'work life',
#   'balance',
#   'could',
#   'bring',
#   'aboard',
#   'right',
#   'number',
#   'folk',
#   'to…'],
#  ['customer',
#   'good',
#   'long term',
#   'career',
#   'solution',
#   'hard transition',
#   'corporate'],
#  ['medium',
#   'harsh',
#   'sometimes',
#   'make feel',
#   'good',
#   'understand',
#   'come',
#   'wave',
#   'start',
#   'deal',
#   'better'],
#  ['much',
#   'opportunity growth',
#   'depending location',
#   'leadership',
#   'may may',
#   'take',
#   'interest',
#   'developing',
#   'career'],
#  ['good',
#   'new',
#   'grade',
#   'since',
#   'google',
#   'promotion',
#   'easy',
#   'big company',
#   'work',
#   'small portion',
#   'big picture'],
#  ['wow',
#   'start',
#   'micro managed',
#   'much',
#   'believe',
#   '’',
#   'like',
#   'real',
#   'life',
#   'call duty',
#   'game',
#   'manager',
#   'would',
#   'constantly',
#   'radio',
#   'checking',
#   'supposed',
#   'told',
#   'training',
#   '’',
#   'customer service',
#   'target',
#   '’',
#   'big',
#   'lie',
#   'measured',
#   'thing',
#   'like',
#   'much',
#   'revenue',
#   'make',
#   'store',
#   'many',
#   'business',
#   'customer',
#   'introduce',
#   'many',
#   'iups',
#   'someone',
#   'speaks',
#   'say',
#   'believe',
#   'working apple',
#   'store',
#   'manager',
#   'bully',
#   'try make',
#   'resign',
#   'thing',
#   'like',
#   'promoting',
#   'making',
#   'stock',
#   'room',
#   'duty',
#   'make',
#   'cleaning',
#   'etc',
#   'management',
#   '’ care',
#   'happiness',
#   'unhappy',
#   'pretend',
#   'like',
#   'care',
#   'listen',
#   '’',
#   'anything',
#   'facial',
#   'expression',
#   'say',
#   'manager',
#   'know',
#   'replace',
#   'easily',
#   'care',
#   'feeling',
#   'happy',
#   'honest',
#   'review',
#   'busy',
#   'mall store',
#   'london',
#   'work',
#   'turnover rate',
#   'staff',
#   'high',
#   'use',
#   'abuse',
#   'people',
#   'good',
#   'job',
#   '’',
#   'sucking',
#   'relationship manager',
#   'get ready',
#   'get',
#   'managed',
#   'someone',
#   'resigns',
#   'every week',
#   '’',
#   'horrible',
#   'atmosphere'],
#  ['stack ranking',
#   'mean',
#   'competing',
#   'team member',
#   'strongly',
#   'inhibits',
#   'teamwork'],
#  ['start'],
#  ['hour', 'hour', 'overtime'],
#  ['push limit',
#   'far',
#   'work load',
#   'customer',
#   'help',
#   'instead',
#   'hiring new',
#   'employee',
#   'juggle',
#   'customer',
#   'every minute',
#   'pay worth'],
#  ['hour',
#   'long',
#   'sometimes',
#   'set',
#   'standard',
#   'availability',
#   'long',
#   'process',
#   'promotion',
#   'work',
#   'next level',
#   'actually',
#   'next level',
#   'compensation',
#   'role',
#   'wise'],
#  ['con', 'company', 'great', 'work'],
#  ['hard',
#   'work',
#   'pretty intense',
#   'hard',
#   'extract',
#   'fast pace',
#   'scale',
#   'problem'],
#  ['day',
#   'spent',
#   'computer',
#   'call',
#   'family',
#   'want',
#   'time',
#   'might',
#   'job'],
#  ['fairly',
#   'little room',
#   'upward mobility',
#   'retail side',
#   'thing',
#   'apple',
#   'hire',
#   'enthusiastic',
#   'people',
#   'mostly',
#   'highly',
#   'intelligent',
#   'motivated',
#   'trying get',
#   'ahead',
#   'rewarding',
#   'frustrating',
#   'everyone',
#   'mostly',
#   'level',
#   'seems',
#   'room',
#   'motion',
#   'inside',
#   'little',
#   'world',
#   'built',
#   'culture',
#   'fun',
#   'first',
#   'overwhelming'],
#  ['need', 'management', 'support', 'better', 'work life', 'balance'],
#  ['difficult', 'customer', 'updated', 'work', 'station'],
#  ['vendor',
#   'trade',
#   'partner',
#   'milked',
#   'treated fairly',
#   'long term',
#   'cooperation',
#   'view',
#   'team',
#   'great',
#   'microculture',
#   'others',
#   'killing',
#   'success',
#   'future',
#   'employee',
#   'depends',
#   'type',
#   'bos',
#   'defines',
#   'team',
#   'culture',
#   'well',
#   'may',
#   'impatient',
#   'hysteric',
#   'demanding',
#   'result',
#   'giving',
#   'support',
#   'resource',
#   'time',
#   'training',
#   'direction',
#   'management',
#   'bos',
#   'team leader',
#   'completely',
#   'opposite',
#   'hr',
#   'stepping',
#   'ensure',
#   'fairness',
#   'quality',
#   'management',
#   'practice',
#   'expected',
#   'almost',
#   'employee',
#   'write',
#   'sql query',
#   'otherwise',
#   'way',
#   'analyse',
#   'business',
#   'data',
#   'central',
#   'sql',
#   'expert',
#   'give',
#   'theory',
#   'support',
#   'reality',
#   'massively',
#   'overloaded',
#   'stakeholder',
#   'meeting',
#   'higher management',
#   'supposed',
#   'review',
#   'decide',
#   'strategic',
#   'topic',
#   'start',
#   'reading',
#   'pre',
#   'prepared',
#   'narrative',
#   'overwhelming',
#   'summary',
#   'imagine',
#   'page',
#   'booklet',
#   'minimal',
#   'margin',
#   'pt',
#   'size',
#   'letter',
#   'text',
#   'shining',
#   'pr',
#   'story',
#   'project',
#   'team',
#   'address',
#   'actual',
#   'issue',
#   'risk',
#   'resource',
#   'gap',
#   'may',
#   'happen',
#   'senior manager',
#   'intuitively',
#   'ask question',
#   'find',
#   'issue',
#   'usually',
#   'deep',
#   'insight',
#   'topic',
#   'project',
#   'operationally',
#   'plus',
#   'focus',
#   'led',
#   'long',
#   'document',
#   'like',
#   'watching',
#   'tv',
#   'switch',
#   'brain',
#   'half baked',
#   'innovation',
#   'eg',
#   'area',
#   'device',
#   'food',
#   'retail',
#   'thrown',
#   'market',
#   'unproportionally',
#   'big',
#   'marketing',
#   'effort',
#   'many',
#   'customer',
#   'buy',
#   'product',
#   'realise',
#   'delivering',
#   'promise',
#   'good',
#   'value',
#   'money'],
#  ['big organization',
#   'entrenched',
#   'culture',
#   'competition',
#   'collaboration',
#   'aging',
#   'product',
#   'make difficult',
#   'impossible',
#   'make',
#   'change',
#   'better',
#   'depending',
#   '’',
#   'changing',
#   'changing',
#   'year',
#   'process slow',
#   'disheartening',
#   'attitude',
#   'code',
#   'based',
#   'never',
#   'change'],
#  ['disorganization',
#   'long hour',
#   'short break',
#   'push',
#   'takt',
#   'time',
#   'throat'],
#  ['hard',
#   'make meaningful',
#   'impact',
#   'company',
#   'since',
#   'large',
#   'food',
#   'could better'],
#  ['almost',
#   'many',
#   'employee',
#   'sometimes difficult',
#   'get',
#   'full',
#   'hour week'],
#  ['work', 'live', 'balance', 'little', 'holiday', 'strange', 'culture'],
#  ['raye',
#   'expectation',
#   'raise',
#   'constantly',
#   'sometimes',
#   'unmanageable',
#   'poor training'],
#  ['offer', 'employee discount', 'amazon', 'even', 'full time', 'employess'],
#  ['sometimes', 'work', 'exciting'],
#  ['lack',
#   'perk',
#   'jeff bezos',
#   'literally',
#   'richest man',
#   'earth',
#   'would nice',
#   'kicked',
#   'back',
#   'money',
#   'employee',
#   'perk',
#   'compete',
#   'big company',
#   'would',
#   'help',
#   'attrition'],
#  ['slow', 'shift', 'underpaid compared', 'competition'],
#  ['follow', 'regular', 'process', 'open', 'option'],
#  ['limited opportunity',
#   'grow',
#   'significantly',
#   'within company',
#   'true',
#   'benefit',
#   'reserved',
#   'team',
#   'lack structure',
#   'department'],
#  ['political', 'work load', 'artificially', 'created', 'high pressure'],
#  ['slow growth', 'work', 'old technology', 'work', 'boring'],
#  ['feel', 'overall great', 'experience'],
#  ['con', 'complaint'],
#  ['management',
#   'horrible',
#   'hr help',
#   'whatsoever',
#   'multiple',
#   'issue',
#   'nothing',
#   'ever',
#   'resolved',
#   'get',
#   'touch',
#   'anyone',
#   'warehouse',
#   'present',
#   'warehouse',
#   'email',
#   'ignored',
#   'call'],
#  ['competitive', 'place work'],
#  ['long hour',
#   'especially',
#   'depending department',
#   'work',
#   'middle management',
#   'could use',
#   'work',
#   'expertise',
#   'necessarily',
#   'mean',
#   'management'],
#  ['long hour', 'stress', 'high', 'allow', 'learning', 'pace', 'important'],
#  ['office',
#   'culture',
#   'lot',
#   'burocratic',
#   'process',
#   'benefit',
#   'friend',
#   'employee'],
#  ['high expectation', 'long hour', 'q', 'retail side', 'brutal'],
#  ['con',
#   'believing',
#   'create',
#   'schedule',
#   'loop',
#   'preset',
#   'schedule',
#   'month',
#   'many people',
#   'quit',
#   'first day',
#   'expected',
#   'really',
#   'expect',
#   'warehouse',
#   'really',
#   'warehouse',
#   'management',
#   'trash',
#   'respond email',
#   'rarely',
#   'approve',
#   'sick',
#   'time',
#   'yet',
#   'always',
#   'wanted',
#   'write',
#   'give',
#   'occurrence',
#   'mistake',
#   'especially',
#   'late',
#   'missing',
#   'shift',
#   'approve',
#   'sick',
#   'time',
#   'received',
#   'occurrence',
#   'constantly',
#   'back',
#   'minute',
#   'inactivity',
#   'use restroom',
#   'hold',
#   'everything',
#   'end',
#   'hospital',
#   'bill',
#   'way',
#   'pay',
#   'pay',
#   'terrible',
#   'endure',
#   'receive',
#   'benefit',
#   'receive',
#   'product',
#   'amazon',
#   'though',
#   'item',
#   'sold',
#   'shipped',
#   'amazon',
#   'good luck',
#   'also',
#   'cap year',
#   'cheap',
#   'cheap',
#   'cheapity',
#   'cheap',
#   'stingy',
#   'company',
#   'room growth',
#   'company',
#   'distastful',
#   'left',
#   'feeling',
#   'cheated',
#   'never',
#   'pay',
#   'prime membership',
#   'seeing',
#   'operate',
#   'money',
#   'going',
#   'also',
#   'stop selling',
#   'expired',
#   'funky',
#   'item',
#   'customer',
#   'many',
#   'labor',
#   'law',
#   'broken'],
#  ['sometimes', 'orgs', 'get', 'bit', 'confusing', 'internally'],
#  ['hard',
#   'work',
#   'relex',
#   'work',
#   'work',
#   'work',
#   'apple',
#   'must',
#   'good',
#   'time',
#   'sometimes',
#   'face',
#   'people',
#   'like',
#   'know anything',
#   'never',
#   'let go'],
#  ['lower',
#   'management',
#   'great',
#   'best',
#   'manager',
#   'likely',
#   'get promoted',
#   'quickly',
#   'beat',
#   'em',
#   'join',
#   'mentality',
#   'manager tend',
#   'promote',
#   'followed',
#   'around',
#   'sometimes',
#   'new idea',
#   'welcomed'],
#  ['mandatory overtime',
#   'hour shift',
#   'shorter',
#   'shift',
#   'balance',
#   'personal life'],
#  ['many',
#   'hour day',
#   'week',
#   'hour per',
#   'day',
#   'part time',
#   'however',
#   'pick shift',
#   'easily'],
#  ['internal promotion',
#   'hyped',
#   'training',
#   'apple',
#   'fails',
#   'promote within'],
#  ['getting',
#   'screamed',
#   'whole shift',
#   'thing',
#   'completely',
#   'control',
#   'time',
#   'go',
#   'break',
#   'cry',
#   'people',
#   'truly',
#   'mean',
#   'package',
#   'day',
#   'freaking',
#   'late'],
#  ['creating',
#   'good',
#   'work life',
#   'balance',
#   'difficult',
#   'amazon',
#   'expectation',
#   'time',
#   'unreasonably high',
#   'mindset',
#   'pivot',
#   'quickly',
#   'depending',
#   'management'],
#  ['bad',
#   'culture',
#   'imposed',
#   'last year',
#   'extremely',
#   'focused',
#   'scorecard',
#   'taking',
#   'picture',
#   'many case',
#   'customer',
#   'new',
#   'executive',
#   'task',
#   'oriented',
#   'want',
#   'people',
#   'execute',
#   'instead',
#   'intelligent',
#   'people',
#   'different',
#   'approach',
#   'visión',
#   'many',
#   'decision based',
#   'impacting',
#   'scorecard',
#   'even',
#   'damage',
#   'company',
#   'image',
#   'future',
#   'business',
#   'customer',
#   'relationship'],
#  ['big',
#   'give',
#   'everyone',
#   'chance show',
#   'impact',
#   'lot',
#   'restructuring',
#   'going',
#   'time',
#   'focus',
#   'really',
#   'matter',
#   'people'],
#  ['work load', 'insecure', 'much competition'],
#  ['lot',
#   'opportunity grow',
#   'least',
#   'within retail',
#   'hour',
#   'le',
#   'fantastic',
#   'highly stressful',
#   'environment'],
#  ['management',
#   'really',
#   'listen',
#   'concern',
#   'make',
#   'working',
#   'little',
#   'le',
#   'appealing',
#   'time',
#   'making',
#   'employee',
#   'ready',
#   'leave early',
#   'encouragement',
#   'stay',
#   'get',
#   'product'],
#  ['life',
#   'inside outside',
#   'work',
#   'likely',
#   'become',
#   'blended',
#   'may',
#   'okay',
#   'many people',
#   'company',
#   'become',
#   'friend'],
#  ['work',
#   'intense',
#   'got ta',
#   'learn manage',
#   'time',
#   'well',
#   'fast paced',
#   'environment'],
#  ['think',
#   'everyone',
#   'realizes',
#   'much',
#   'really',
#   'need help',
#   'beginning',
#   'end',
#   'many',
#   'stowers',
#   'chill',
#   'isle',
#   'block',
#   'isle',
#   'overfill',
#   'bin',
#   'also',
#   'shut',
#   'leave',
#   'stolls',
#   'isle',
#   'lot',
#   'trash',
#   'item',
#   'floor',
#   'people',
#   'walk',
#   'buy'],
#  ['people',
#   'master',
#   'lot',
#   'different',
#   'product',
#   'many',
#   'scorecard',
#   'achieve',
#   'worklife balance',
#   'super',
#   'bad'],
#  ['among',
#   'area manager',
#   'huge amount',
#   'favoritism',
#   'company',
#   'also',
#   'base',
#   'performance',
#   'number',
#   'looking',
#   'someone',
#   'good',
#   'form',
#   'constructive feedback',
#   'however',
#   'kill morale',
#   'among',
#   'associate',
#   'push',
#   'many',
#   'find',
#   'place',
#   'employer'],
#  ['good luck', 'getting', 'hour', 'advertise'],
#  ['management',
#   'get',
#   'number',
#   'focused',
#   'seemingly',
#   'new',
#   'metric',
#   'push',
#   'month'],
#  ['extremely political',
#   'careful',
#   'management',
#   'peer',
#   'talk',
#   'much',
#   'going',
#   'well',
#   'change',
#   'may',
#   'seen',
#   'negative',
#   'never',
#   'overcome',
#   'even',
#   'sincere',
#   'intention',
#   'making',
#   'thing',
#   'better',
#   'offer',
#   'suggestion',
#   'change',
#   'value',
#   'external candidate',
#   'rather',
#   'internal',
#   'one',
#   'slow respond',
#   'new technology',
#   'opportunity'],
#  ['corporation',
#   '’',
#   'better',
#   'many',
#   '’',
#   'expect',
#   'rainbow',
#   'without',
#   'rain',
#   '’',
#   'watch',
#   'get sucked',
#   'sacrifice',
#   'work life',
#   'balance',
#   'typically',
#   '’',
#   'asked',
#   'though'],
#  ['unflagging',
#   'management',
#   'system',
#   'sanctimonious',
#   'external',
#   'iamge',
#   'feeling',
#   'bad',
#   'bland',
#   'customer',
#   'pcan',
#   'slove',
#   'customer',
#   'problem',
#   'really',
#   'felt',
#   'unhappy'],
#  ['call duty',
#   'worst',
#   'high pressure',
#   'try solve',
#   'emergency',
#   'situation',
#   'often',
#   'code',
#   'never seen',
#   'someone else',
#   'code',
#   'someone else',
#   'probably',
#   'left',
#   'company',
#   'long',
#   'time ago',
#   'also',
#   'getting',
#   'help others',
#   'tough',
#   'time',
#   'since',
#   'everybody',
#   'quite',
#   'busy',
#   'find',
#   'solution',
#   'via',
#   'company',
#   'wiki',
#   'etc',
#   'also',
#   'important',
#   'culture',
#   'amazon',
#   'lot',
#   'young',
#   'folk',
#   'sense',
#   'condescension',
#   'older',
#   'folk',
#   'fact',
#   'quite',
#   'seem',
#   'cynical',
#   'interacting',
#   'older generation'],
#  ['continuing',
#   'keep',
#   'simple',
#   'culture',
#   'everyone',
#   'con',
#   'really',
#   'change',
#   'location',
#   'people'],
#  ['perception', 'matter', 'rockstar', 'word', 'go', 'better', 'pack'],
#  ['favoritism',
#   'unnecessary rule',
#   'management',
#   'sneaky',
#   'write',
#   'without',
#   'telling',
#   'hr',
#   'suck'],
#  ['waiting',
#   'month',
#   'year',
#   'tell',
#   'friend family',
#   'cool stuff',
#   'working'],
#  ['rude', 'manager', 'lay', 'rate', 'extremely high'],
#  ['really',
#   'need',
#   'get',
#   'management',
#   'together',
#   'constantly changing',
#   'also',
#   'need',
#   'stop',
#   'killing',
#   'people',
#   'actually',
#   'work',
#   'hard',
#   'letting people',
#   'b',
#   'continue',
#   'amazon',
#   'might',
#   'good',
#   'company',
#   'order',
#   'sooner later',
#   'go',
#   'treat',
#   'employess'],
#  ['long hour',
#   'hour day',
#   'average',
#   'week',
#   'expectation',
#   'intense',
#   'metric',
#   'looked',
#   'hour',
#   'always',
#   'influence',
#   'decision',
#   'amazon',
#   'say',
#   'recruiting',
#   'onboarding'],
#  ['always', 'get', 'hour', 'need'],
#  ['upside',
#   'stock',
#   'growth',
#   'depends manager',
#   'team',
#   'le',
#   'unlike',
#   'others',
#   'free food',
#   'free soda',
#   'bad',
#   'health',
#   'cafe',
#   'food quality',
#   'really',
#   'great'],
#  ['hard',
#   'work',
#   'keep',
#   'fast growing',
#   'changing environment',
#   'need',
#   'hr week'],
#  ['career opportunity',
#   'mountain view',
#   'new york',
#   'office',
#   'old school',
#   'cheery',
#   'googlers',
#   'replaced',
#   'mba',
#   'shark',
#   'looking',
#   'feather',
#   'career',
#   'cap',
#   'come',
#   'excel',
#   'powerpoint',
#   'data',
#   'hand',
#   'want succeed',
#   'customer service',
#   'came',
#   'second',
#   'internal',
#   'posturing',
#   'happens',
#   'desirable',
#   'place work',
#   'unfortunate',
#   'answer',
#   'shareholder',
#   'almighty',
#   'dollar',
#   'matter',
#   'google',
#   'give',
#   'free lunch',
#   'laptop',
#   'keep',
#   'hook',
#   'job',
#   'hook',
#   'mature',
#   'family',
#   'need',
#   'work life',
#   'balance',
#   'google',
#   'place'],
#  ['low pay', 'move'],
#  ['people',
#   'running',
#   'retail',
#   'narrow',
#   'mindset',
#   'people',
#   'running',
#   'retail',
#   'business',
#   'clue',
#   'build',
#   'business',
#   'must love',
#   'apple',
#   'like',
#   'deity',
#   'order',
#   'advance',
#   'least',
#   'pretend'],
#  ['lot', 'perk compared', 'company'],
#  ['long',
#   'working hour',
#   'npi',
#   'slow career',
#   'path',
#   'good',
#   'pay',
#   'fresh graduate'],
#  ['indian', 'arm', 'still', 'politics', 'favouritism', 'bias', 'etc'],
#  ['long hour',
#   'overbearing',
#   'management',
#   'lack',
#   'freedom',
#   'reluctance',
#   'work',
#   'personal',
#   'restriction',
#   'absolute lack',
#   'communication skill',
#   'across board'],
#  ['company grows',
#   'culture',
#   'change',
#   'little',
#   'expected',
#   'politics',
#   'certain area',
#   'gotten',
#   'unbearable'],
#  ['low pay', 'inadequate', 'facility'],
#  ['little bit', 'slow', 'reaction'],
#  ['fair',
#   'promotion',
#   'base',
#   'sympathy',
#   'manager',
#   'base',
#   'hard',
#   'worked',
#   'performance',
#   'trained',
#   'agent',
#   'created',
#   'couple',
#   'training',
#   'peer',
#   'top performer',
#   'proactive',
#   'far',
#   'promoting people',
#   'even',
#   'half'],
#  ['stressful', 'monotonous work', 'flexible'],
#  ['culture',
#   'foster',
#   'reward',
#   'emotionally',
#   'abusive',
#   'behavior',
#   'far',
#   'many',
#   'middle manager'],
#  ['talk',
#   'ownership',
#   'every day',
#   'good',
#   'case',
#   'mean',
#   'time',
#   'unrealistic deadline',
#   'high pressure',
#   'environment',
#   'much focus',
#   'kpi',
#   'sometimes',
#   'kpi',
#   'mean',
#   'everything',
#   'people',
#   'smart',
#   'arrogant',
#   'even',
#   'wrong',
#   'leadership',
#   'priciple',
#   'taught',
#   'stick',
#   'idea',
#   'creates',
#   'inefficiency',
#   'hard',
#   'work',
#   'vain',
#   'reason',
#   'amazon',
#   'rated',
#   'fb google'],
#  ['time',
#   'customer experience',
#   'come',
#   'high',
#   'cost',
#   'employee',
#   'experience'],
#  ['entirely',
#   'number driven',
#   'company',
#   'immense',
#   'commitment',
#   'time',
#   'demanding',
#   'role'],
#  ['major con', 'far', 'month', 'job'],
#  ['far', 'drive', 'noisy', 'boring', 'get', 'sleepy', 'early shift'],
#  ['lack transparency',
#   'engineer',
#   'put',
#   'dev plan',
#   'without',
#   'even',
#   'notifying',
#   'goal',
#   'keep changing',
#   'suddenly',
#   'new',
#   'task',
#   'come',
#   'tight deadline',
#   'everything',
#   'put hold',
#   'lot',
#   'meeting',
#   'wasted',
#   'discussing',
#   'unnecessary',
#   'mundane',
#   'thing',
#   'work',
#   'within',
#   'parallel',
#   'universe',
#   'amazon',
#   'internal',
#   'technology',
#   'framework',
#   'probably',
#   'written',
#   'thousand',
#   'line code',
#   'year',
#   'project',
#   'basically',
#   'refactors',
#   'migration',
#   'one',
#   'framework',
#   'another',
#   'know',
#   'developer',
#   'spent',
#   'month',
#   'without',
#   'writing code',
#   'basically',
#   'spending time',
#   'configuration',
#   'jsons',
#   'thing',
#   'amazon',
#   'internal tool',
#   'project',
#   'look like',
#   'done',
#   'heck',
#   'perfectly',
#   'working',
#   'code',
#   'get written',
#   'use',
#   'internal',
#   'framework',
#   'apparent reason',
#   'course',
#   'paid',
#   'motivating'],
#  ['weak',
#   'hr policy',
#   'senior leadership',
#   'vp director',
#   'overworked',
#   'time',
#   'go deep'],
#  ['easy get', 'excited', 'caught', 'work', 'lead', 'working'],
#  ['much room',
#   'grow',
#   'retail',
#   'level',
#   'reach',
#   'position',
#   'really',
#   'option',
#   'growth within',
#   'company',
#   'retail',
#   'amount',
#   'work',
#   'revenue',
#   'generated',
#   'employee',
#   'tech company',
#   'still',
#   'underpaid',
#   'wage',
#   'per hour'],
#  ['duplicate',
#   'role',
#   'seem',
#   'common',
#   'coordination',
#   'across',
#   'work',
#   'team',
#   'difficult',
#   'great',
#   'opportunity'],
#  ['much', 'hierachy', 'free food'],
#  ['big company', 'retail', 'oriented', 'losing', 'aura'],
#  ['illegible', 'accent', 'international', 'coworkers'],
#  ['none', 'specifically', 'part', 'working', 'bigger', 'company'],
#  ['word',
#   'warning',
#   'parent',
#   'obligation',
#   'away',
#   'work',
#   'place',
#   'need',
#   'would',
#   'like',
#   'also',
#   'find',
#   'time',
#   'amazon',
#   'expects',
#   'full',
#   'commitment',
#   'many',
#   'review',
#   'people',
#   'calling',
#   'appalling',
#   'work life',
#   'balance',
#   'pay heed',
#   'many instance',
#   'seen',
#   'employee',
#   'sick leave',
#   'stress anxiety',
#   'little attention',
#   'paid',
#   'integrate',
#   'back',
#   'business',
#   'provide',
#   'appropriate',
#   'support',
#   'amazon',
#   'burn',
#   'mill',
#   'requires',
#   'full',
#   'focus',
#   'perfect',
#   'need',
#   'validation',
#   'life',
#   'work',
#   'perspective',
#   'awful',
#   'frugal',
#   'environment',
#   'extremely',
#   'lean',
#   'team',
#   'pretty',
#   'typical',
#   'individual',
#   'role',
#   'business',
#   'continues grow',
#   'increasing',
#   'concern',
#   'revenue',
#   'achieved',
#   'growth',
#   'seem',
#   'feed back',
#   'employee',
#   'senior management',
#   'attitude',
#   'focus',
#   'thing',
#   'go wrong',
#   'never',
#   'call',
#   'gone',
#   'well',
#   'depressing',
#   'attitude',
#   'take',
#   'business',
#   'demand',
#   'much',
#   'employee',
#   'amazon',
#   'get',
#   'data',
#   'get',
#   'people',
#   'encourage',
#   'positive',
#   'collegiate',
#   'culture',
#   'lot',
#   'new',
#   'naive',
#   'mba',
#   'business',
#   'suck',
#   'dry',
#   'high turnover',
#   'staff',
#   'people leave',
#   'disappear',
#   'never heard',
#   'people',
#   'would recommend',
#   'amazon',
#   'willing',
#   'completely',
#   'throw',
#   'career',
#   'year',
#   'get',
#   'experience',
#   'name',
#   'cv',
#   'even',
#   'need careful',
#   'take',
#   'board',
#   'business',
#   'suck',
#   'life',
#   'let'],
#  ['long hour', 'cut throat', 'culture'],
#  ['physically demanding', 'job', 'creativity', 'work'],
#  ['hour shift',
#   'short break',
#   'barely enough',
#   'time',
#   'eat lunch',
#   'literally',
#   'shove',
#   'food',
#   'expected',
#   'walk mile',
#   'daily',
#   'good luck',
#   'using restroom',
#   'without getting',
#   'trouble',
#   'parking',
#   'horrible'],
#  ['management',
#   'bearing',
#   'advancement',
#   'difficult',
#   'worth',
#   'work',
#   'take advantage',
#   'pd',
#   'time'],
#  ['slow', 'development cycle', 'many', 'team', 'lack', 'bonding'],
#  ['hard move', 'people', 'care', 'reprimanded'],
#  ['hard',
#   'work',
#   'management',
#   'always',
#   'forthright',
#   'sometimes',
#   'seems',
#   'though',
#   'employee',
#   'voice heard'],
#  ['amazon',
#   'product',
#   'sometimes',
#   'cutting edge',
#   'value',
#   'priced',
#   'sometimes',
#   'suck',
#   'employee',
#   'work',
#   'le',
#   'cool',
#   'company',
#   'team',
#   'tend',
#   'siloed',
#   'try',
#   'get',
#   'siloed',
#   'many',
#   'employee',
#   'benefit'],
#  ['•', 'unknown', 'role', 'apple', 'ambiguity'],
#  ['intense',
#   'people',
#   'work',
#   'ton',
#   'hour',
#   'hard manage',
#   'work life',
#   'balance',
#   'also',
#   'sometimes',
#   'hard get',
#   'team',
#   'work',
#   'together',
#   'across',
#   'orgs'],
#  ['long hour',
#   'work',
#   'extensive',
#   'mount',
#   'travel',
#   'asia',
#   'lot',
#   'manager',
#   'hire',
#   'relative',
#   'married',
#   'manager',
#   'kid',
#   'hooked',
#   'prostitute',
#   'asia',
#   'thats',
#   'motivation',
#   'travel',
#   'asia',
#   'senior director',
#   'like god',
#   'everyone',
#   'fallow',
#   'say',
#   'even',
#   'wrong',
#   'career growth',
#   'within',
#   'ops',
#   'ops manager',
#   'block',
#   'employee',
#   'growth',
#   'depended',
#   'direct report',
#   'since',
#   'busy',
#   'hooker',
#   'asia'],
#  ['despite',
#   'approval',
#   'general',
#   'concept',
#   'differentiation',
#   'find',
#   'stack rank',
#   'process',
#   'little',
#   'stark',
#   'hard',
#   'people',
#   'appreciate',
#   'real problem',
#   'get',
#   'lower',
#   'rating',
#   'get',
#   'lower',
#   'bonus stock',
#   'award',
#   'way',
#   'resolve',
#   'problem',
#   'reward',
#   'high performer',
#   'le',
#   'low performer',
#   'surface',
#   'employee',
#   'simply',
#   'unwilling',
#   'believe',
#   'everybody else',
#   'large company',
#   'success',
#   'largely',
#   'dependent',
#   'relationship',
#   'ability',
#   'connect',
#   'peer',
#   'counter intuitive',
#   'many',
#   'best',
#   'technology',
#   'always',
#   'win',
#   'compelling',
#   'argument',
#   'building',
#   'take',
#   'trust',
#   'consistent',
#   'result',
#   'good',
#   'network',
#   'suspect',
#   'time',
#   'leaving',
#   'great idea',
#   'cutting',
#   'room',
#   'floor',
#   'sake',
#   'relationship',
#   'across company',
#   'great',
#   'collaborative',
#   'culture',
#   'degree',
#   'feedback loop',
#   'become',
#   'galvanized',
#   'impenetrable',
#   'far',
#   'great',
#   'need',
#   'disruption',
#   'ground',
#   'tremendous amount',
#   'talent',
#   'within company'],
#  ['work life', 'balance', 'could improved', 'india office'],
#  ['stack ranking', 'bit rough', 'pro con', 'work', 'bright people'],
#  ['benefit',
#   'suck',
#   'company',
#   'going nowhere',
#   'decade',
#   'review system',
#   'abomination',
#   'unlucky enough',
#   'work',
#   'newer',
#   'building',
#   'enjoy',
#   'moronic',
#   'decision',
#   'put',
#   'everyone',
#   'open space',
#   'block',
#   'window',
#   'see',
#   'outside',
#   'like',
#   'working',
#   'cave',
#   'surrounded',
#   'maddening',
#   'level',
#   'noise',
#   'might',
#   'perfect',
#   'environment'],
#  ['much', 'con', 'job', 'maybe', 'sometimes', 'work load', 'higher', 'side'],
#  ['department', 'head', 'need', 'training'],
#  ['slower career', 'growth', 'move chain'],
#  ['none moment', 'think'],
#  ['sometimes', 'get', 'sent home', 'early'],
#  ['stuff', 'would', 'see', 'big company'],
#  ['really',
#   'need',
#   'go beyond',
#   'get',
#   'notice',
#   'technology',
#   'soft',
#   'selling',
#   'customer',
#   'going',
#   'underperformer',
#   'want',
#   'relocate',
#   'one',
#   'major',
#   'work',
#   'center',
#   'e g',
#   'redmond',
#   'going',
#   'top',
#   'work life',
#   'balance',
#   'tricky',
#   'especially',
#   'work home',
#   'office',
#   'let',
#   'get away',
#   'may',
#   'expect',
#   'online',
#   'time',
#   'every',
#   'device',
#   'put',
#   'online',
#   'moment notice'],
#  ['sometimes difficult', 'manage', 'work life', 'balance'],
#  ['culture',
#   'moved',
#   'sell',
#   'first',
#   'mindset',
#   'pushed',
#   'make',
#   'sale quota',
#   'even',
#   'hired',
#   'management',
#   'idea',
#   'cronyism',
#   'ripe'],
#  ['lot politics', 'beareaucratic'],
#  ['still', 'corporation', 'work environment', 'accordingly'],
#  ['clear', 'focus', 'personal', 'skill', 'building', 'rather', 'launch'],
#  ['treat like',
#   'slave',
#   'get',
#   'break',
#   'one',
#   'min lunch',
#   'work',
#   'ten hour',
#   'day'],
#  ['diverse',
#   'apple',
#   'claim',
#   'homophobia',
#   'racism',
#   'sexism',
#   'prevalent',
#   'control',
#   'hierarchy',
#   'achieving',
#   'leadership',
#   'trumpian',
#   'additionally',
#   'career',
#   'experience',
#   'serve',
#   'way',
#   'pay lower',
#   'wage',
#   'smart enough',
#   'realize',
#   'job duty',
#   'well beyond',
#   'pay grade',
#   'experience'],
#  ['many layer',
#   'politics',
#   'risk averse',
#   'business',
#   'like',
#   'lead',
#   'front',
#   'lock',
#   'individual',
#   'company',
#   'invested',
#   'stock',
#   'program'],
#  ['service',
#   'product',
#   'sold',
#   'faltered',
#   'put',
#   'pressure',
#   'sale person',
#   'rather',
#   'modify',
#   'product'],
#  ['micro management',
#   'difficult',
#   'customer',
#   'creep',
#   'webcam',
#   'usage',
#   'interview',
#   'management'],
#  ['yet find', 'hope', 'find'],
#  ['politics',
#   'get ahead',
#   'prepared',
#   'play game',
#   'great',
#   'work',
#   'good enough',
#   'diversity',
#   'talked',
#   'reality',
#   'fully',
#   'embraced'],
#  ['big company',
#   'always',
#   'feel like',
#   'contributing',
#   'lot',
#   'also',
#   'tend promote',
#   'within',
#   'interning',
#   'mtv',
#   'tax',
#   'pretty',
#   'brutal'],
#  ['work life',
#   'balance',
#   'great',
#   'really',
#   'love',
#   'excited come',
#   'work',
#   'every day',
#   'amazon',
#   'churn',
#   'people',
#   'like',
#   'meat grinder',
#   'team',
#   'average',
#   'new',
#   'person',
#   'leaving',
#   'starting',
#   'every week'],
#  ['high', 'salary', 'many', 'paid', 'leave', 'day'],
#  ['work life', 'balance', 'compensation', 'management'],
#  ['undercurrent',
#   'age discrimination',
#   'leadership',
#   'intimidation',
#   'jeckell',
#   'hyde',
#   'presentation',
#   'culture'],
#  ['little',
#   'hectic',
#   'time',
#   'work life',
#   'balance',
#   'good',
#   'much',
#   'cultural',
#   'activity',
#   'monotonous work',
#   'environment'],
#  ['take',
#   'l',
#   'sde',
#   'position',
#   'broken',
#   'level',
#   'people',
#   'year experience',
#   'judged',
#   'together',
#   'review',
#   'promoted',
#   'l',
#   'get',
#   'mid',
#   'top',
#   'mark',
#   'next',
#   'review',
#   'two',
#   'move',
#   'anger',
#   'yelling',
#   'rewarded',
#   'group',
#   'sr manager',
#   'managing',
#   'someone',
#   'career',
#   'rewarded'],
#  ['struggle',
#   'compete',
#   'market',
#   'regard',
#   'salary',
#   'perk',
#   'training',
#   'also',
#   'unfortunate',
#   'bay area',
#   'office space',
#   'san francisco'],
#  ['sometimes', 'pace fast', 'demanding'],
#  ['early morning', 'shift', 'cant', 'wake', 'bed'],
#  ['please customer'],
#  ['management',
#   'fake',
#   'customer',
#   'stuck',
#   'hell',
#   'coworkers',
#   'trying move',
#   'wolf',
#   'sheep',
#   'clothing'],
#  ['business',
#   'initiative',
#   'top',
#   'authority',
#   'always',
#   'take',
#   'priority',
#   'technical debt',
#   'architecture',
#   'fix',
#   'building',
#   'properly',
#   'leading',
#   'massive amount',
#   'operational',
#   'pain',
#   'without',
#   'end',
#   'sight',
#   'business',
#   'technical',
#   'team',
#   'fairly',
#   'silo',
#   'organization',
#   'causing',
#   'friction',
#   'come',
#   'delivery',
#   'deadline',
#   'well',
#   'requirement',
#   'since',
#   'business',
#   'respect',
#   'technical',
#   'team',
#   'enough',
#   'include',
#   'technical',
#   'need',
#   'op',
#   'roadmaps',
#   'eoe',
#   'consistently',
#   'de',
#   'prioritized',
#   'sake',
#   'moving fast',
#   'even',
#   'mean',
#   'operational',
#   'pain',
#   'increase',
#   'x',
#   'result',
#   'fast',
#   'fix',
#   'never',
#   'built',
#   'properly',
#   'reason',
#   'technical',
#   'design',
#   'account',
#   'full',
#   'scope',
#   'work',
#   'requires',
#   'completion',
#   'phase',
#   'seems',
#   'farthest',
#   'team',
#   'ever',
#   'get',
#   'given',
#   'feature',
#   'given',
#   'good enough',
#   'suit',
#   'business need',
#   'year',
#   'despite',
#   'built',
#   'use case',
#   'original',
#   'due',
#   'future',
#   'phase',
#   'accounting',
#   'generalization',
#   'abstraction',
#   'original',
#   'problem',
#   'elegant',
#   'design',
#   'k',
#   'plan',
#   'matching',
#   'horrific',
#   'half',
#   'base salary',
#   'total compensation',
#   'model',
#   'complete',
#   'garbage',
#   'work',
#   'entirely',
#   'money',
#   'get promoted',
#   'challenging',
#   'problem',
#   'smart',
#   'co worker',
#   'work',
#   'fairly',
#   'compensated',
#   'microsoft',
#   'google facebook',
#   'peer'],
#  ['work', 'intensive', 'demanding', 'pay'],
#  ['everyone', 'making', 'great', 'product', 'easy'],
#  ['incredibly smart',
#   'peer',
#   'huge',
#   'career',
#   'impact',
#   'would',
#   'vary',
#   'team',
#   'team',
#   'great',
#   'whenever',
#   'u',
#   'asked question',
#   'mentor',
#   'gently',
#   'answer question'],
#  ['bad',
#   'work environment',
#   'highly stressful',
#   'always worried',
#   'going',
#   'walk',
#   'badge',
#   'going',
#   'work'],
#  ['many',
#   'supposing',
#   'stakeholder',
#   'sometime',
#   'also',
#   'sake',
#   'visibility',
#   'number',
#   'consensus',
#   'communication',
#   'required',
#   'get',
#   'thing done',
#   'daunting'],
#  ['base salary',
#   'competitive',
#   'rate',
#   'similar',
#   'company',
#   'working',
#   'overtime required',
#   'highly',
#   'encouraged',
#   'depending team',
#   'advancement',
#   'position',
#   'may',
#   'take long',
#   'time',
#   'get',
#   'certain level',
#   'senior manager',
#   'frequently',
#   'give impression',
#   'idea'],
#  ['salary',
#   'lack',
#   'competition',
#   'support engineer',
#   'good',
#   'career path',
#   'actually',
#   'choice',
#   'future',
#   'role',
#   'job',
#   'need',
#   'call',
#   'frequently'],
#  ['microsoft',
#   'big machine',
#   'software',
#   'production',
#   'line',
#   'mentality',
#   'quality',
#   'often',
#   'de',
#   'prioritized',
#   'wealthy',
#   'money',
#   'wasted',
#   'especially',
#   'management',
#   'given',
#   'full',
#   'authority',
#   'disregard',
#   'health',
#   'well',
#   'direct report',
#   'hr',
#   'longer',
#   'represents',
#   'non',
#   'manager',
#   'employee'],
#  ['joined', 'yet', 'sure'],
#  ['foot day'],
#  ['flexible hour',
#   'must',
#   'work',
#   'day week',
#   'suck',
#   'college student',
#   'everyone',
#   'friendly'],
#  ['political', 'poor', 'team', 'relationship'],
#  ['long',
#   'working hour',
#   'oncall',
#   'stressful',
#   'benefit',
#   'good',
#   'competitor'],
#  ['google',
#   'run business',
#   'interest',
#   'employee',
#   'company',
#   'diverge',
#   'outcome',
#   'always',
#   'deemed',
#   'satisfactory',
#   'sometimes',
#   'result',
#   'good',
#   'people leaving',
#   'company',
#   'despite',
#   'liking',
#   'existing',
#   'role',
#   'location'],
#  ['little', 'time', 'pressure perform', 'raise bar'],
#  ['lot pressure', 'hit target'],
#  ['sub',
#   'average',
#   'management',
#   'much politics',
#   'unclear goal',
#   'culture',
#   'transition'],
#  ['senior management',
#   'infiltrated',
#   'retail',
#   'clothing',
#   'manager',
#   'understand technology',
#   'focused',
#   'fashion',
#   'wore',
#   'day',
#   'primary',
#   'skill',
#   'often',
#   'ability play',
#   'court',
#   'politics',
#   'also',
#   'almost',
#   'cult like',
#   'self',
#   'improvement',
#   'culture',
#   'except',
#   'senior manager',
#   'director level',
#   'apply',
#   'everyone',
#   'open feedback',
#   'time',
#   'management',
#   'role',
#   'showing',
#   'vulnerability',
#   'would',
#   'look'],
#  ['work life',
#   'balance',
#   'extremely',
#   'bad',
#   'work',
#   'plan',
#   'unhappy',
#   'miserable',
#   'cry desk',
#   'everyday',
#   'exaggeration',
#   'amazon',
#   'squeeze every',
#   'drop',
#   'life'],
#  ['hour',
#   'good',
#   'u',
#   'start',
#   'morning',
#   'hour',
#   'odd',
#   'worth',
#   'body',
#   'especially',
#   'mother',
#   'kid'],
#  ['extremely low',
#   'top',
#   'pay low',
#   'potential',
#   'advancement',
#   'management',
#   'share',
#   'employee',
#   'pay',
#   'retail store',
#   'colludes',
#   'advance',
#   'pay'],
#  ['’',
#   'surrounded',
#   'untrained',
#   'manager',
#   'depend',
#   'anonymous feedback',
#   'inability',
#   'look',
#   'beyond',
#   'seems',
#   'apparent',
#   'resistance change',
#   'willingness',
#   'ignore',
#   'issue',
#   'disruptive',
#   'harmful',
#   'public',
#   'order',
#   'narrative',
#   'compamy',
#   '“',
#   'good',
#   'world',
#   '”',
#   'one',
#   'company',
#   '’',
#   'pr',
#   'marketing',
#   'campaign'],
#  ['agility',
#   'delivery',
#   'microsoft',
#   'still',
#   'need',
#   'game',
#   'respect',
#   'innovation agility',
#   'delivery',
#   'risk taking',
#   'capability'],
#  ['bad',
#   'people',
#   'high pressure',
#   'workload',
#   'environment',
#   'bad',
#   'beverage',
#   'food',
#   'coffee',
#   'oncall',
#   'horrible',
#   'sometimes',
#   'weakened',
#   'mid',
#   'night',
#   'deal',
#   'ticket',
#   'management',
#   'bad manager',
#   'like',
#   'use',
#   'pip',
#   'threat',
#   'developer',
#   'press',
#   'work',
#   'cold',
#   'place',
#   'average',
#   'staying',
#   'period',
#   'month',
#   'people',
#   'flowing',
#   'quickly',
#   'leadership principle',
#   'like',
#   'brainwashing',
#   'people',
#   'like',
#   'use',
#   'lp',
#   'speak',
#   'set',
#   'obstacle',
#   'team member',
#   'show',
#   'self',
#   'value'],
#  ['training program',
#   'sufficient',
#   'meet',
#   'company',
#   'demand',
#   'expectation'],
#  ['bad', 'traffic', 'bad', 'food', 'though', 'free'],
#  ['high school',
#   'politics',
#   'micromanagement',
#   'holding',
#   'opportunity',
#   'potential',
#   'people',
#   'constantly',
#   'teaching',
#   'people',
#   'basic',
#   'computer',
#   'skill',
#   'get',
#   'mundane work',
#   'life balance',
#   'terrible',
#   'see',
#   'much',
#   'future',
#   'credo',
#   'culture',
#   'bit',
#   'desired',
#   'one',
#   'thing',
#   'believe',
#   'product',
#   'culture',
#   'way much',
#   'juice',
#   'fearless feedback',
#   'etc',
#   'many',
#   'employee',
#   'also',
#   'know',
#   'much',
#   'product',
#   'use'],
#  ['language barrier',
#   'customer',
#   'sometimes',
#   'management',
#   'side',
#   'customer',
#   'make',
#   'happy'],
#  ['like',
#   'office politics',
#   'senior management',
#   'team member',
#   'far',
#   'interested',
#   'politics',
#   'practical',
#   'work'],
#  ['difficult',
#   'first',
#   'lot',
#   'pick',
#   'learn',
#   'work',
#   'sometimes',
#   'tedious',
#   'free',
#   'amazon prime'],
#  ['shift',
#   'change',
#   'internal',
#   'job posting',
#   'week offs',
#   'proper',
#   'communication',
#   'regard',
#   'ijps',
#   'people',
#   'interact'],
#  ['seriously',
#   'think',
#   'single',
#   'negative',
#   'thing',
#   'facebook',
#   'see',
#   'working',
#   'company'],
#  ['new ceo',
#   'firing',
#   'nearly',
#   'get rid',
#   'unnecessary',
#   'layer',
#   'mgmt',
#   'layoff',
#   'ic',
#   'mgrs',
#   'retained',
#   'moved',
#   'ic',
#   'role',
#   'unqualified'],
#  ['potential', 'heavy workload', 'food'],
#  ['continually', 'improve', 'left behind'],
#  ['work',
#   'microsoft',
#   'corporate',
#   'non',
#   'field based',
#   'outside redmond',
#   'culture',
#   'somewhat',
#   'lacking',
#   'opportunity outside',
#   'redmond',
#   'also',
#   'somewhat',
#   'lacking',
#   'engineer'],
#  ['nothing much',
#   'work',
#   'hour',
#   'look',
#   'apart',
#   'everything',
#   'good',
#   'amazon',
#   'best',
#   'fresher'],
#  ['hard',
#   'work life',
#   'balance',
#   'hour shift',
#   'poor management',
#   'boring',
#   'store',
#   'meeting',
#   'consistent',
#   'frustrated customer'],
#  ['actually',
#   'work',
#   'sending email',
#   'software engineer',
#   'instead',
#   'coding',
#   'also',
#   'person',
#   'send',
#   'reply email',
#   'fast',
#   'professional',
#   'word',
#   'get',
#   'improved',
#   'one',
#   'care',
#   'done'],
#  ['management micromanages',
#   'break',
#   'obfuscates',
#   'situation',
#   'miscommunicates',
#   'co worker',
#   'make',
#   'situation',
#   'worse',
#   'mispercieved',
#   'wish',
#   'place',
#   'worse',
#   'enemy'],
#  ['new feature',
#   'need',
#   'ensure',
#   'privacy',
#   'user',
#   'data',
#   'preserved',
#   'finest',
#   'detail',
#   'thus',
#   'requiring',
#   'great',
#   'engineering',
#   'effort',
#   'build',
#   'something',
#   'substantial'],
#  ['new hire', 'usually', 'get', 'salary', 'existing employee'],
#  ['management',
#   'always',
#   'problem',
#   'hr',
#   'might',
#   'well',
#   'exist amazon',
#   'hire',
#   'people',
#   'peak',
#   'fire people',
#   'afterwards',
#   'point',
#   'expect',
#   'remaining',
#   'worker',
#   'pick',
#   'extra',
#   'workload'],
#  ['promotion', 'per', 'performance', 'attrition high'],
#  ['low', 'growth opportunity', 'employee'],
#  ['zero work',
#   'life balance',
#   'zero',
#   'underlined',
#   'bold',
#   'good luck',
#   'trying',
#   'ever',
#   'get',
#   'shift',
#   'covered',
#   'likely',
#   'event',
#   'need',
#   'certain',
#   'day',
#   'full timer',
#   'get',
#   'pick',
#   'designated',
#   'day',
#   'rather',
#   'get',
#   'preferred day',
#   'never',
#   'granted',
#   'weekend day',
#   'must',
#   'full',
#   'open availability',
#   'part timer',
#   'must',
#   'day',
#   'full',
#   'availability',
#   'make impossible',
#   'full time',
#   'student',
#   'job',
#   'place',
#   'get sick',
#   'lot',
#   'use',
#   'anything',
#   'even close',
#   'something',
#   'sterilizes',
#   'cleaning',
#   'oh',
#   'sit',
#   'little',
#   'squishy',
#   'ball',
#   'seat',
#   'kid',
#   'table',
#   'call',
#   'pee',
#   'ball',
#   'reason',
#   'constantly',
#   'micro',
#   'manged',
#   'point',
#   'hard',
#   'tell',
#   'actually',
#   'harassing',
#   'get',
#   'zero',
#   'training',
#   'time',
#   'expected',
#   'know',
#   'everything',
#   'latest',
#   'software hardware',
#   'constantly',
#   'running around',
#   'like',
#   'chicken',
#   'head',
#   'cut',
#   'helping',
#   'multiple',
#   'people',
#   'answering',
#   'stupid',
#   'question',
#   'could',
#   'simply',
#   'googled',
#   'customer',
#   'coworkers',
#   'little opportunity',
#   'growth unless',
#   'become',
#   'manager',
#   'little',
#   'pet',
#   'bend',
#   'every',
#   'whim',
#   'maybe',
#   'get',
#   'interview',
#   'something',
#   'end',
#   'losing',
#   'external hire',
#   'lastly',
#   'valued',
#   'mere',
#   'cog big',
#   'corporate',
#   'machine',
#   'apple',
#   'easily',
#   'replace',
#   'regardless',
#   'much',
#   'time',
#   'blood',
#   'sweat',
#   'tear',
#   'gave',
#   'place',
#   'apple',
#   'culture',
#   'made',
#   'company',
#   'awesome',
#   'unique',
#   'longer exists',
#   'long gone',
#   'died',
#   'angela',
#   'ahrendts',
#   'cancer',
#   'apple retail'],
#  ['still',
#   'negative attitude',
#   'people',
#   'work',
#   'always',
#   'evil',
#   'empire',
#   'people',
#   'also',
#   'complain',
#   'frustration',
#   'regardless whether',
#   'involved',
#   'product'],
#  ['bad', 'traffic', 'downtown seattle', 'tough', 'find', 'parking', 'spot'],
#  ['overworked',
#   'hour',
#   'expectation',
#   'work life',
#   'balance exist',
#   'management',
#   'need',
#   'development'],
#  ['great',
#   'power',
#   'come',
#   'great',
#   'responsibility',
#   'sometimes',
#   'need thick',
#   'skin',
#   'work',
#   'user',
#   'facing',
#   'thing'],
#  ['benefit',
#   'weak',
#   'since',
#   'obamacare',
#   'used',
#   'coverage',
#   'medical',
#   'expense',
#   'deductible',
#   'copay',
#   'paycheck',
#   'deduction',
#   'pay',
#   'k',
#   'yr',
#   'family',
#   'team',
#   'moving',
#   'cubicle',
#   'farm',
#   'open',
#   'work',
#   'area',
#   'instead',
#   'private office',
#   'everyone',
#   'used'],
#  ['shift',
#   'work weekend',
#   'work',
#   'lot',
#   'employee turnover',
#   'lot stress',
#   'kpi',
#   'focus',
#   'however',
#   'mostly',
#   'positive',
#   'time'],
#  ['microsoft',
#   'big company',
#   'build',
#   'product',
#   'almost',
#   'tech',
#   'aligning',
#   'product',
#   'together',
#   'common goal',
#   'one',
#   'big',
#   'daunting',
#   'task',
#   'microsoft'],
#  ['level', 'little bit', 'slow'],
#  ['long hour', 'normal', 'shift'],
#  ['job', 'stole', 'soul', 'sold', 'faceless', 'corporation'],
#  ['pay low', 'compare market'],
#  ['lot',
#   'tech debt',
#   'much',
#   'autonomy',
#   'team',
#   'level',
#   'address issue',
#   'waterfall',
#   'requirement',
#   'gather',
#   'slowly',
#   'product',
#   'lifecycle',
#   'need',
#   'slimming',
#   'oncall',
#   'experience',
#   'pretty',
#   'taxing',
#   'personal life',
#   'time'],
#  ['company',
#   'huge',
#   'focus',
#   'customer',
#   'little',
#   'priority',
#   'employee',
#   'culture',
#   'unsafe',
#   'toxic',
#   'underdeveloped',
#   'dog eat',
#   'dog',
#   'culture',
#   'manger',
#   'performance based',
#   'connection score',
#   'number',
#   'score',
#   'rate',
#   'individual',
#   'based',
#   'anonymous feedback',
#   'generated',
#   'questionnaire',
#   'sent',
#   'associate',
#   'daily',
#   'scrutinizing',
#   'system',
#   'brow',
#   'beat',
#   'management',
#   'playing favorite',
#   'top performer',
#   'offset',
#   'boomerang',
#   'negative feedback',
#   'resulting',
#   'average',
#   'low performer',
#   'response',
#   'attrition',
#   'horrendous',
#   'high turnover',
#   'result',
#   'lack trust',
#   'little',
#   'momentum',
#   'gained',
#   'every day',
#   'literally',
#   'day',
#   'former',
#   'manager',
#   'left',
#   'without notice',
#   'transition',
#   'plan',
#   'place',
#   'newcomer',
#   'walk',
#   'resentful',
#   'team',
#   'little',
#   'training development',
#   'expected',
#   'continually',
#   'perform',
#   'get',
#   'team',
#   'perform',
#   'continually',
#   'rising',
#   'standard'],
#  ['politics', 'old way', 'thinking', 'difficult', 'adapt new', 'technology'],
#  ['job',
#   'pleasure',
#   'work',
#   'really',
#   'negative',
#   'paid',
#   'would',
#   'perfect',
#   'pay',
#   'really',
#   'good'],
#  ['opinion',
#   'currently',
#   'real',
#   'side',
#   'working apple',
#   'mainly',
#   'minor',
#   'adjustment',
#   'lifestyle',
#   'help',
#   'employee',
#   'maximize',
#   'success',
#   'enjoyment',
#   'working apple',
#   'must',
#   'know',
#   'handle',
#   'many',
#   'personality',
#   'willing take',
#   'give feedback'],
#  ['though',
#   'one',
#   'thing',
#   'work',
#   'four day',
#   'week',
#   'least',
#   'manager',
#   'pretty',
#   'full',
#   'always',
#   'load',
#   'uk',
#   'manager',
#   'pm pm',
#   'mon',
#   'thurs',
#   'video conference',
#   'season',
#   'mind',
#   'coming late',
#   'stay late',
#   'ok',
#   'prefer',
#   'start',
#   'early',
#   'make',
#   'long',
#   'day'],
#  ['smartest people',
#   'planet',
#   'believe press',
#   'internal',
#   'squabbling',
#   'bickering',
#   'people',
#   'moaning',
#   'complaining',
#   'stack ranking',
#   'company',
#   'influence',
#   'surprisingly',
#   'closed',
#   'mind'],
#  ['never heard', 'downstairs', 'company'],
#  ['maybe',
#   'maybe',
#   'culture',
#   'really',
#   'go',
#   'grid',
#   'let say',
#   'half',
#   'week',
#   'thing',
#   'break',
#   'fix',
#   'going',
#   'disaster',
#   'could',
#   'avoided',
#   'quite',
#   'frankly',
#   'choose',
#   'ownership',
#   'responsibility',
#   'ability',
#   'go',
#   'completely',
#   'grid',
#   'choose',
#   'former'],
#  ['want',
#   'home',
#   'life',
#   'love',
#   'aware',
#   'healthy',
#   'salary package',
#   'work'],
#  ['upper management',
#   'unrealistic expectation',
#   'people left',
#   'stretcher',
#   'pretty',
#   'often',
#   'probably',
#   'keep',
#   'paramedic',
#   'site',
#   'hr',
#   'pretty',
#   'inept',
#   'job'],
#  ['parking', 'horrible', 'hire', 'many', 'temp'],
#  ['work life',
#   'balance',
#   'seems',
#   'new',
#   'norm',
#   'company',
#   'including',
#   'apple'],
#  ['position',
#   'pay',
#   'retail',
#   'position',
#   'would',
#   'far',
#   'demanding',
#   'apple',
#   'extract',
#   'lot',
#   'productivity',
#   'employee',
#   'availability requirement',
#   'extremely',
#   'inflexible',
#   'volume',
#   'challenging',
#   'necessarily',
#   'feel',
#   'reward',
#   'dealing',
#   'get',
#   'pumped',
#   'lot',
#   'world',
#   'changing',
#   'big picture',
#   'type',
#   'idea',
#   'baseline',
#   'customer service',
#   'work',
#   'upward mobility',
#   'coworkers',
#   'people',
#   'worked',
#   'position',
#   'year',
#   'management',
#   'political',
#   'nepotism',
#   'predominant',
#   'throughout',
#   'expect',
#   'external hire',
#   'new hire',
#   'get',
#   'much',
#   'promotion',
#   'revolving door',
#   'apple',
#   'evolved',
#   'lot',
#   'tim cook'],
#  ['travel', 'turnover', 'hr'],
#  ['everything', 'microsoft', 'good'],
#  ['weird', 'people', 'nice place'],
#  ['tech', 'people', 'think', 'know'],
#  ['worked',
#   'san',
#   'bernardino',
#   'fulfillment center',
#   'facility',
# ...
#   'specific',
#   'people',
#   'skill',
#   'information',
#   'difficult keep',
#   'innovation',
#   'change',
#   'though',
#   'many',
#   'internal',
#   'mechanism',
#   'help'],
#  ['work', 'hectic'],
#  ['high',
#   'amount',
#   'churn',
#   'especially',
#   'operation',
#   'due',
#   'stressful',
#   'nature job',
#   'really',
#   'long hour',
#   'week',
#   'limited career',
#   'growth opportunity',
#   'manager',
#   'hard get',
#   'promoted',
#   'manage',
#   'team',
#   'group',
#   'also',
#   'operate',
#   'silo',
#   'little transparency',
#   'due',
#   'secretive culture',
#   'company'],
#  ['company',
#   'big',
#   'people',
#   'lot',
#   'job',
#   'people',
#   'much',
#   'help',
#   'anything',
#   'help',
#   'may',
#   'make',
#   'hard',
#   'job',
#   'efficiently'],
#  ['time', 'work life', 'balance', 'might get', 'impacted'],
#  ['physically demanding', 'discount', 'could better'],
#  ['working',
#   'shift',
#   'sin',
#   'started',
#   'applying',
#   'every month',
#   'different',
#   'day',
#   'always',
#   'say',
#   'sorry',
#   'position',
#   'longer',
#   'available',
#   'see',
#   'recent',
#   'hiries',
#   'get',
#   'better',
#   'shift',
#   'employee',
#   'mor',
#   'year',
#   'bother',
#   'good',
#   'employee',
#   'stay',
#   'task',
#   'every day',
#   'good'],
#  ['bad', 'unfair', 'review system', 'stack ranking'],
#  ['ever', 'move'],
#  ['need',
#   'find right',
#   'team',
#   'project',
#   'often',
#   'get',
#   'scrapped',
#   'lose',
#   'momentum',
#   'hard grow',
#   'ladder'],
#  ['little', 'work life', 'balance'],
#  ['hectic schedule', 'availability'],
#  ['big company', 'thing move', 'slow', 'time'],
#  ['competitive',
#   'fault',
#   'review process',
#   'entirely',
#   'political',
#   'echo chamber',
#   'individual contribution',
#   'probably',
#   'irrelevant',
#   'company',
#   'whole'],
#  ['site',
#   'menlo park',
#   'really',
#   'nice',
#   'difficult get',
#   'almost',
#   'anywhere',
#   'hate',
#   'commute'],
#  ['higher authority',
#   'good',
#   'immediate',
#   'management',
#   'lack',
#   'managerial',
#   'option'],
#  ['due',
#   'high',
#   'number',
#   'contact',
#   'keep',
#   'receiving',
#   'round clock',
#   'asked',
#   'work',
#   'overtime',
#   'needed',
#   'part',
#   'customer obsession',
#   'nothing',
#   'complaint'],
#  ['way', 'many reorganization', 'people', 'losing job', 'day day'],
#  ['everything',
#   'suck',
#   'atmosphere',
#   'dead',
#   'everyone',
#   'working',
#   'hated',
#   'job',
#   'coworkers',
#   'would',
#   'working hour',
#   'nonstop',
#   'foot',
#   'min break',
#   'well',
#   'min lunch',
#   'break room',
#   'fun'],
#  ['good',
#   'manager',
#   'left',
#   'left',
#   'hard find',
#   'hr',
#   'review process',
#   'manager',
#   'never',
#   'act',
#   'bad review',
#   'would',
#   'avoid',
#   'like plague'],
#  ['ssp', 'difficult', 'engage', 'cx', 'level', 'support', 'executive'],
#  ['time',
#   'bother',
#   'applying',
#   'dedicated',
#   'really con',
#   'reading review',
#   'take consideration',
#   'tone',
#   'written',
#   'majority',
#   'con',
#   'issue',
#   'read',
#   'disgruntled',
#   'associate',
#   'manage',
#   'time',
#   'goof',
#   'work',
#   'wonder',
#   'manager',
#   'call'],
#  ['scheduling',
#   'ruin',
#   'personal life',
#   'lot',
#   'rude customer',
#   'cringe',
#   'people',
#   'uk'],
#  ['high expectation',
#   'perform',
#   'daily',
#   'poor',
#   'tool',
#   'plan',
#   'execution',
#   'timely manner',
#   'unrealistic',
#   'daily',
#   'communication',
#   'pool',
#   'success',
#   'saturated',
#   'idea',
#   'roll',
#   'keep busy',
#   'day',
#   'creating',
#   'report',
#   'filing',
#   'many',
#   'administrative',
#   'duty',
#   'need',
#   'completed',
#   'audit',
#   'constantly',
#   'interrupted',
#   'store',
#   'sale',
#   'lack',
#   'team',
#   'support',
#   'creates',
#   'struggle maintain',
#   'employee moral',
#   'ethic',
#   'microsoft',
#   'company',
#   'many',
#   'great',
#   'solid',
#   'future',
#   'proof',
#   'idea',
#   'poor',
#   'plan',
#   'execution',
#   'almost',
#   'plan',
#   'road map',
#   'success',
#   'number',
#   'goal',
#   'time',
#   'line',
#   'create',
#   'constant',
#   'struggle',
#   'perform',
#   'daily',
#   'base',
#   'lack knowledge',
#   'hows',
#   'high',
#   'rate',
#   'failure',
#   'program',
#   'add',
#   'often',
#   'time',
#   'triple',
#   'goal',
#   'expectation',
#   'creating',
#   'unbalanced',
#   'depiction',
#   'company',
#   'success',
#   'go',
#   'business',
#   'employee',
#   'success',
#   'strategy',
#   'failing',
#   'microsoft',
#   'decides',
#   'focus',
#   'importance',
#   'goal',
#   'exist',
#   'first place',
#   'constant',
#   'race',
#   'top',
#   'although',
#   'microsoft',
#   'may',
#   'never know',
#   'top',
#   'get'],
#  ['starting',
#   'get',
#   'weighed',
#   'bureaucracy',
#   'due',
#   'scale',
#   'dead end',
#   'project',
#   'floating around',
#   'may',
#   'result',
#   'getting',
#   'stuck',
#   'unless',
#   'proactive'],
#  ['slow',
#   'system',
#   'much',
#   'help',
#   'given',
#   'department',
#   'inputting',
#   'info',
#   'easy',
#   'behind competitor',
#   'market'],
#  ['bad', 'work', 'hour', 'pressure'],
#  ['review system', 'culture', 'politics', 'destroying', 'company'],
#  ['company',
#   'lot',
#   'ladder',
#   'make',
#   'internal movement',
#   'hard',
#   'based',
#   'u'],
#  ['grind',
#   'culture',
#   'work',
#   'often feel',
#   'joyless',
#   'company',
#   'known',
#   'working',
#   'people',
#   'bone'],
#  ['constant orgs',
#   'tough',
#   'continue',
#   'momentum',
#   'even',
#   'get',
#   'groundswell',
#   'think',
#   'traction',
#   'company',
#   'team',
#   'another',
#   'reorg',
#   'priority',
#   'shifted',
#   'responsibility',
#   'changed',
#   'start',
#   'challenge',
#   'longer exists'],
#  ['sometimes',
#   'people',
#   'get',
#   'overly competitive',
#   'good',
#   'many',
#   'young',
#   'people',
#   'company',
#   'arrogant',
#   'entitled',
#   'depending group',
#   'could',
#   'fratty',
#   'culture'],
#  ['middle management',
#   'could',
#   'seem',
#   'let go',
#   'past',
#   'company',
#   'moving towards',
#   'platform',
#   'agnostic',
#   'setup',
#   'focus',
#   'service',
#   'yet',
#   'many',
#   'manager',
#   'talked',
#   'still',
#   'help',
#   'concept',
#   'window',
#   'king',
#   'work life',
#   'balance',
#   'phrase',
#   'known',
#   'expected',
#   'reply email',
#   'forget',
#   'vacation',
#   'would',
#   'email',
#   'reason left'],
#  ['growth opportunity', 'limited', 'lot', 'number', 'pressure'],
#  ['much',
#   'mandatory overtime',
#   'hour',
#   'hour',
#   'optional',
#   'minimum',
#   'per',
#   'pay',
#   'period',
#   'take toll',
#   'month',
#   'loud',
#   'work environment',
#   'get',
#   'minute lunch',
#   'break',
#   'extremely',
#   'crowded',
#   'break room',
#   'waste',
#   'way much',
#   'time',
#   'trying get',
#   'microwave',
#   'looking',
#   'table',
#   'taken',
#   'hire',
#   'like crazy',
#   'add',
#   'microwave',
#   'table',
#   'result',
#   'terrible',
#   'lunch',
#   'experience',
#   'get',
#   'minute break',
#   'short break',
#   'room',
#   'far',
#   'employee',
#   'stay',
#   'work',
#   'area',
#   'break',
#   'worth',
#   'walk',
#   'difficult find',
#   'time',
#   'use',
#   'rest',
#   'room',
#   'need',
#   'go',
#   'work',
#   'day',
#   'leave',
#   'area',
#   'automatically',
#   'start',
#   'tracked',
#   'time task',
#   'certain',
#   'function',
#   'happen',
#   'come',
#   'work',
#   'diarrhea',
#   'better',
#   'going',
#   'home',
#   'get trouble',
#   'using restroom',
#   'getting',
#   'time task',
#   'amazon',
#   'successfully',
#   'lowered',
#   'warehouse',
#   'job',
#   'wage',
#   'around',
#   'country',
#   'low pay',
#   'work',
#   'amazon',
#   'interview',
#   'thought',
#   'okay',
#   'first',
#   'start',
#   'wish',
#   'kind',
#   'interview',
#   'majority',
#   'employee',
#   'low quality',
#   'work ethic',
#   'productivity',
#   'attitude',
#   'much',
#   'make',
#   'workplace',
#   'miserable',
#   'people',
#   'amazon',
#   'literally',
#   'walk around',
#   'warehouse',
#   'day',
#   'talk',
#   'friend',
#   'almost',
#   'one',
#   'follow',
#   'assigned task',
#   'day',
#   'sign',
#   'whatever',
#   'function',
#   'feel like',
#   'go',
#   'hang',
#   'friend',
#   'working',
#   'professional',
#   'attitude',
#   'job',
#   'definitely',
#   'basically',
#   'handful',
#   'employee',
#   'actually',
#   'work',
#   'properly',
#   'even',
#   'le',
#   'follow rule',
#   'meant',
#   'help',
#   'everyone'],
#  ['politics',
#   'still',
#   'onerous',
#   'manager',
#   'still',
#   'driven',
#   'ego',
#   'result',
#   'experience',
#   'largely',
#   'driven',
#   'manager',
#   'manager'],
#  ['political',
#   'nonesense',
#   'l',
#   'vp level',
#   'inability',
#   'prioritize',
#   'focus',
#   'arbitrary',
#   'review process'],
#  ['working',
#   'week',
#   '’',
#   'awful',
#   'change',
#   'start date',
#   'another',
#   'well',
#   'never',
#   'cancelled',
#   'first',
#   'one',
#   '“',
#   'termed',
#   '”',
#   'system',
#   'therefore',
#   '’',
#   'info',
#   'need',
#   'give',
#   'badge',
#   'actually',
#   'job',
#   '’',
#   'log',
#   'handheld',
#   'get',
#   'certified',
#   'operate',
#   'pit',
#   '’',
#   'look',
#   'info',
#   'literally',
#   'useless',
#   'right',
#   'called',
#   'today',
#   'still',
#   'resolved',
#   'issue'],
#  ['worked',
#   'like slave',
#   'break',
#   'enough',
#   'running',
#   'throughout',
#   'ginormous',
#   'wear',
#   'house',
#   'definitely',
#   'pay',
#   'summertime',
#   'beyond',
#   'unbearably',
#   'hot',
#   'hard',
#   'make rate',
#   'picker'],
#  ['difficult', 'good', 'work environment', 'top', 'secretive'],
#  ['lot overtime', 'hour foot', 'management', 'make', 'known', 'replacable'],
#  ['amount',
#   'work',
#   'responsibility',
#   'need',
#   'owner',
#   'work',
#   'expect',
#   'others',
#   'say',
#   'need'],
#  ['work life',
#   'balance exist',
#   'poor',
#   'flexibility',
#   'working hour',
#   'especially',
#   'parent'],
#  ['hardworking',
#   'nit',
#   'picking',
#   'culture',
#   'work',
#   'practice',
#   'lot',
#   'game',
#   'playing',
#   'point',
#   'scoring',
#   'amongst',
#   'senior leadership'],
#  ['really',
#   'really',
#   'really bad',
#   'pay',
#   'business',
#   'manager',
#   'clue',
#   'progression',
#   'pay increase',
#   'tiny',
#   'professional',
#   'role'],
#  ['work life',
#   'balance',
#   'good',
#   'leader',
#   'ask',
#   'work',
#   'extra',
#   'time',
#   'endless',
#   'work',
#   'time'],
#  ['really', 'whole', 'time', 'worked'],
#  ['work life', 'balance', 'problem', 'product', 'driven culture', 'amazon'],
#  ['hardly anything', 'microsoft', 'improve upon'],
#  ['long hour',
#   'physically demanding',
#   'work',
#   'manager',
#   'always',
#   'demanding',
#   'production',
#   'fc',
#   'worked',
#   'specific',
#   'detail',
#   'production',
#   'safety quality',
#   'allowed',
#   'suffer',
#   'sake',
#   'production',
#   'tier iii',
#   'associate',
#   'set failure',
#   'leading',
#   'write ups',
#   'dismissal',
#   'department',
#   'department',
#   'transfer',
#   'tier tier',
#   'iii',
#   'associate',
#   'extremely',
#   'rare'],
#  ['program', 'lot', 'hand holding', 'new grad'],
#  ['working',
#   'u',
#   'asia',
#   'rarely',
#   'feel',
#   'offline',
#   'expensive cost',
#   'living',
#   'without',
#   'tech company',
#   'perk'],
#  ['combative culture',
#   'getting better',
#   'bad manager',
#   'screwed',
#   'need',
#   'move'],
#  ['leadership',
#   'vision',
#   'promote based',
#   'popularity',
#   'real',
#   'contribution',
#   'success',
#   'brown nose',
#   'incompetence',
#   'msft',
#   'management',
#   'lazy',
#   'motivation',
#   'msft',
#   'culture',
#   'company',
#   'dismal',
#   'failing',
#   'outlook',
#   'sataya',
#   'n',
#   'waste time',
#   'useless',
#   'hour',
#   'hour',
#   'meeting',
#   'debating',
#   'terminology',
#   'seasoned',
#   'professional',
#   'wonder',
#   'google',
#   'apple',
#   'kicking',
#   'company',
#   'butt',
#   'handing',
#   'mst',
#   'butt',
#   'back',
#   'lunch'],
#  ['work environment',
#   'great',
#   'bonus',
#   'great',
#   'benefit average',
#   'freedom',
#   'choosing',
#   'project',
#   'work'],
#  ['difficult',
#   'woman minority',
#   'succeed',
#   'definitely',
#   'male dominated',
#   'male',
#   'oriented',
#   'company',
#   'changed',
#   'twenty year'],
#  ['foot', 'lot'],
#  ['food', 'counter', 'bagmane', 'building', 'need improvement'],
#  ['flat organization',
#   'limited opportunity',
#   'outside engineering',
#   'sale',
#   'sale',
#   'office',
#   'becoming',
#   'faceless',
#   'googley',
#   'long term',
#   'client',
#   'relationship',
#   'sacrifice',
#   'short term',
#   'quota',
#   'gain'],
#  ['none', 'noticed', 'yet'],
#  ['big', 'hard', 'align', 'goal', 'internally'],
#  ['naturally',
#   'empathetic',
#   'truly care',
#   'others',
#   'job',
#   'destroy',
#   'emotionally',
#   'mentally',
#   'started',
#   'load',
#   'confidence',
#   'year later',
#   'shell',
#   'target',
#   'achievable',
#   'begin',
#   'manager',
#   'time',
#   'singled',
#   'trouble',
#   'option',
#   'progress',
#   'willing',
#   'lot',
#   'work',
#   'role',
#   'advance',
#   'without',
#   'extra pay',
#   'recognition',
#   'poor',
#   'work life',
#   'balance',
#   'attention',
#   'mental health',
#   'people',
#   'working home',
#   'complain',
#   'told',
#   'negative',
#   'well',
#   'suggest',
#   'fix',
#   'happens',
#   'even though',
#   'every',
#   'meeting',
#   'manager',
#   'talk',
#   'important',
#   'mental health'],
#  ['main',
#   'downside',
#   'work life',
#   'balance',
#   'many',
#   'colleague',
#   'routinely',
#   'work',
#   'hour day',
#   'usually',
#   'work',
#   'hour weekend',
#   'whilst',
#   'directly',
#   'asked',
#   'extra hour',
#   'asked',
#   'deliver',
#   'project',
#   'work',
#   'short amount',
#   'time',
#   'even',
#   'shorter',
#   'notice',
#   'period'],
#  ['size',
#   'brings',
#   'great',
#   'benefit',
#   'opportunity',
#   'also mean',
#   'learn navigate',
#   'assertive',
#   'get',
#   'want'],
#  ['different',
#   'shift',
#   'every day',
#   'make',
#   'work life',
#   'balance',
#   'difficult',
#   'pay',
#   'everyone',
#   'within',
#   'position',
#   'try find',
#   'others',
#   'make',
#   'avoid',
#   'frustration',
#   'paper',
#   'working apple',
#   'seems',
#   'great',
#   'reality',
#   'many',
#   'policy',
#   'outlined',
#   'followed'],
#  ['underestimate',
#   'much',
#   'repetitive work',
#   'need',
#   'every',
#   'manpower',
#   'sort',
#   'box',
#   'wrap',
#   'pallet',
#   'transport',
#   'box',
#   'truck',
#   'thing',
#   'whole shift',
#   'unless',
#   'manager',
#   'tell',
#   'person',
#   'want',
#   'something',
#   'differently',
#   'every day',
#   'le',
#   'likely'],
#  ['difficult', 'customer', 'short break', 'home', 'environment'],
#  ['enough', 'job', 'growth', 'could better'],
#  ['nothing bad', 'sometimes', 'like', 'ecommerce', 'potential employer'],
#  ['employee', 'used', 'abused', 'system', 'culture', 'poor', 'general'],
#  ['changed', 'policy procedure', 'caring', 'employee'],
#  ['size',
#   'invested',
#   'many',
#   'technology market',
#   'segment',
#   'tough',
#   'agile',
#   'time',
#   'work life',
#   'balance',
#   'despite',
#   'flexible',
#   'work arrangement',
#   'people',
#   'working',
#   'way',
#   'hour',
#   'like',
#   'culture',
#   'jettison',
#   'highly',
#   'effective',
#   'performer',
#   'longer',
#   'want move',
#   'level'],
#  ['moving towards', 'big company', 'culture'],
#  ['better',
#   'engineer',
#   'designer',
#   'fro',
#   'discipline',
#   'stock',
#   'captured',
#   'huge',
#   'growth',
#   'start',
#   'basically',
#   'parking lot',
#   'intern',
#   'eat',
#   'best',
#   'food'],
#  ['enough money', 'long hour'],
#  ['role',
#   'objective',
#   'driven',
#   'stressful',
#   'manager tend',
#   'focus',
#   'micromanagement',
#   'team',
#   'development',
#   'intensity',
#   'environment',
#   'something',
#   'fit',
#   'profile'],
#  ['work death', 'mandatory overtime'],
#  ['find',
#   'group',
#   'area',
#   'amazon',
#   'upper management',
#   'focused',
#   'get',
#   'bite',
#   'moving forward',
#   'working',
#   'hard',
#   'achieving',
#   'great',
#   'result',
#   'simply',
#   'matter',
#   'discover',
#   'late'],
#  ['technology', 'date'],
#  ['advancement',
#   'working',
#   'hoping',
#   'career growth',
#   'place',
#   'look',
#   'also',
#   'annual review',
#   'raise',
#   'absolutely horrendous',
#   'max',
#   'could',
#   'receive',
#   'salary',
#   'go beyond',
#   'job',
#   'role',
#   'others',
#   'job',
#   'including',
#   'management',
#   'even',
#   'still',
#   'promised',
#   'max'],
#  ['salary', 'bit', 'le'],
#  ['made', 'leave', 'lay'],
#  ['political',
#   'performance',
#   'stack ranking',
#   'methodology',
#   'discourages',
#   'employee',
#   'cooperation',
#   'actually',
#   'encourages',
#   'managing',
#   'excessive',
#   'self promotion'],
#  ['politics', 'ego', 'senior level'],
#  ['feel', 'ownership', 'product'],
#  ['despite',
#   'throwing',
#   'around',
#   'work life',
#   'balance',
#   'little',
#   'place',
#   'reality',
#   'google',
#   'era',
#   'quarterly',
#   'review',
#   'fun',
#   'fair',
#   'randomly',
#   'getting',
#   'eye',
#   'pecked',
#   'crow'],
#  ['store', 'busy', 'loud', 'customer', 'lot', 'time', 'complain'],
#  ['process procedure', 'constantly', 'development', 'bad', 'goid'],
#  ['many', 'process', 'hinder', 'fast', 'development'],
#  ['required', 'hr week', 'holiday', 'make', 'one', 'mistake', 'gone'],
#  ...]

# %%
flat_list = []
for sublist in tokens:
    for item in sublist:
        flat_list.append(item)

# %%
flat_list
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['job movement',
#  'lateral',
#  'extremely difficult',
#  'get promoted',
#  'competing coworkers',
#  'store',
#  'hr protect',
#  'company',
#  'employee',
#  'careful',
#  'restricted stock',
#  'unit',
#  'awarded',
#  'exact number',
#  'promote',
#  'work life',
#  'balance',
#  'word',
#  'employee',
#  'get recognized',
#  'hand meeting',
#  'worked',
#  'hour week',
#  'never took',
#  'time',
#  'work life',
#  'balance',
#  'hostile environment',
#  'reward',
#  'bully',
#  'limited',
#  'development advancement',
#  'option',
#  'older employee',
#  'manager',
#  'check balance',
#  'get terminated',
#  'made',
#  'reason',
#  'employment',
#  'likely rsus',
#  'vest hr',
#  'support',
#  'manager',
#  'employee',
#  'hectic schedule',
#  'u',
#  'ill',
#  'learning',
#  'cutting',
#  'technology',
#  'hard get',
#  'often turn',
#  'away',
#  'good people',
#  'left',
#  'clear idea',
#  'make',
#  'always',
#  'enough time',
#  'meet deadline',
#  'limited opportunity',
#  'move within',
#  'company',
#  'everything',
#  'terrible v',
#  'work life',
#  'balance unrealistic',
#  'recruiting',
#  'expectation',
#  'burnt employee',
#  'constantly stressed',
#  'poor',
#  'office',
#  'morale',
#  'lack respect',
#  'management',
#  'career advancement',
#  'opportunity',
#  'unless move',
#  'ca',
#  'headquarters',
#  'growing inertia',
#  'mono culture',
#  'better',
#  'learn',
#  'love',
#  'con',
#  'find',
#  'big corporate',
#  'company',
#  'getting bureaucratic',
#  'many',
#  'reporting',
#  'goal clear',
#  'find con',
#  'till',
#  'getting promoted',
#  'depends know',
#  'loud',
#  'one would',
#  'notice',
#  'good job',
#  'sometimes',
#  'long hour',
#  'working',
#  'high pressure',
#  'bad treatment',
#  'really bad',
#  'hour',
#  'religious',
#  'accommodation',
#  'sure',
#  'start',
#  'bad management',
#  'bad attitude',
#  'recognition',
#  'great effort',
#  'pay competitive',
#  'customer',
#  'ridiculously high',
#  'expectation',
#  'apple',
#  'got ta',
#  'deal',
#  'manager',
#  'ex gap',
#  'forever',
#  'manager',
#  '’ know',
#  'anything',
#  'technical',
#  'charge',
#  'technician',
#  'tech',
#  'department',
#  'dealing angry',
#  'customer',
#  'worth',
#  'hr',
#  'system complicated',
#  'training',
#  'actual',
#  'call',
#  'ideal',
#  'busy always',
#  'foot',
#  'retail environment',
#  'customer',
#  'often',
#  'difficult',
#  'demanding',
#  'pressure',
#  'even greater',
#  'within apple',
#  'necessarily',
#  'answer',
#  'able find',
#  'feel like',
#  'slave',
#  'company',
#  'reorganization every',
#  'year',
#  'expect',
#  'find',
#  'job',
#  'given',
#  'july',
#  'far many',
#  'hour worked',
#  'nothing',
#  'average',
#  'hour week',
#  'people',
#  'wrong',
#  'position',
#  'making',
#  'wrong',
#  'decision',
#  'get tiresome',
#  'enough',
#  'people',
#  'work',
#  'zero zero',
#  'zero work',
#  'life balance',
#  'exec saying',
#  'year',
#  'understand',
#  'make',
#  'better actuality',
#  'get worse',
#  'every year',
#  'obviously top',
#  'management',
#  'lip service',
#  'meant could',
#  'fix tomorrow',
#  'hundred billion',
#  'bank really',
#  'cared employee',
#  'work life',
#  'balance could',
#  'bring aboard',
#  'right',
#  'number folk',
#  'to…',
#  'customer',
#  'good',
#  'long term',
#  'career',
#  'solution',
#  'hard transition',
#  'corporate',
#  'medium',
#  'harsh sometimes',
#  'make feel',
#  'good',
#  'understand',
#  'come wave',
#  'start',
#  'deal',
#  'better',
#  'much opportunity',
#  'growth',
#  'depending location',
#  'leadership',
#  'may may',
#  'take interest',
#  'developing career',
#  'good',
#  'new',
#  'grade',
#  'since',
#  'google',
#  'promotion',
#  'easy',
#  'big company',
#  'work',
#  'small portion',
#  'big picture',
#  'wow',
#  'start',
#  'micro managed',
#  'much',
#  'believe',
#  '’',
#  'like',
#  'real life',
#  'call duty',
#  'game',
#  'manager',
#  'would',
#  'constantly',
#  'radio',
#  'checking',
#  'supposed',
#  'told training',
#  '’',
#  'customer service',
#  'target',
#  '’',
#  'big',
#  'lie',
#  'measured',
#  'thing like',
#  'much revenue',
#  'make',
#  'store',
#  'many',
#  'business',
#  'customer',
#  'introduce',
#  'many',
#  'iups',
#  'someone speaks',
#  'say',
#  'believe',
#  'working apple',
#  'store manager',
#  'bully',
#  'try make',
#  'resign',
#  'thing like',
#  'promoting',
#  'making',
#  'stock',
#  'room',
#  'duty',
#  'make',
#  'cleaning',
#  'etc',
#  'management',
#  '’ care',
#  'happiness',
#  'unhappy',
#  'pretend',
#  'like',
#  'care',
#  'listen',
#  '’',
#  'anything',
#  'facial',
#  'expression',
#  'say',
#  'manager know',
#  'replace',
#  'easily',
#  'care feeling',
#  'happy',
#  'honest review',
#  'busy',
#  'mall store',
#  'london',
#  'work',
#  'turnover rate',
#  'staff',
#  'high',
#  'use',
#  'abuse',
#  'people',
#  'good job',
#  '’',
#  'sucking',
#  'relationship manager',
#  'get ready',
#  'get managed',
#  'someone',
#  'resigns',
#  'every week',
#  '’',
#  'horrible atmosphere',
#  'stack ranking',
#  'mean competing',
#  'team member',
#  'strongly',
#  'inhibits',
#  'teamwork',
#  'start',
#  'hour',
#  'hour',
#  'overtime',
#  'push limit',
#  'far',
#  'work load',
#  'customer',
#  'help instead',
#  'hiring new',
#  'employee',
#  'juggle',
#  'customer',
#  'every minute',
#  'pay worth',
#  'hour long',
#  'sometimes',
#  'set standard',
#  'availability',
#  'long',
#  'process',
#  'promotion',
#  'work',
#  'next level',
#  'actually',
#  'next level',
#  'compensation',
#  'role',
#  'wise',
#  'con',
#  'company',
#  'great',
#  'work',
#  'hard work',
#  'pretty intense',
#  'hard',
#  'extract',
#  'fast pace',
#  'scale problem',
#  'day spent',
#  'computer',
#  'call',
#  'family want',
#  'time',
#  'might',
#  'job',
#  'fairly',
#  'little room',
#  'upward mobility',
#  'retail side',
#  'thing',
#  'apple',
#  'hire',
#  'enthusiastic',
#  'people',
#  'mostly',
#  'highly intelligent',
#  'motivated',
#  'trying get',
#  'ahead',
#  'rewarding',
#  'frustrating everyone',
#  'mostly',
#  'level',
#  'seems',
#  'room',
#  'motion',
#  'inside little',
#  'world',
#  'built',
#  'culture fun',
#  'first',
#  'overwhelming',
#  'need',
#  'management',
#  'support',
#  'better',
#  'work life',
#  'balance',
#  'difficult customer',
#  'updated work',
#  'station',
#  'vendor',
#  'trade',
#  'partner',
#  'milked',
#  'treated fairly',
#  'long term',
#  'cooperation',
#  'view',
#  'team',
#  'great',
#  'microculture',
#  'others',
#  'killing',
#  'success future',
#  'employee',
#  'depends type',
#  'bos',
#  'defines',
#  'team',
#  'culture',
#  'well',
#  'may',
#  'impatient',
#  'hysteric',
#  'demanding',
#  'result',
#  'giving',
#  'support',
#  'resource',
#  'time',
#  'training',
#  'direction',
#  'management',
#  'bos',
#  'team leader',
#  'completely opposite',
#  'hr',
#  'stepping',
#  'ensure fairness',
#  'quality',
#  'management practice',
#  'expected',
#  'almost',
#  'employee',
#  'write sql',
#  'query',
#  'otherwise',
#  'way',
#  'analyse',
#  'business',
#  'data',
#  'central',
#  'sql',
#  'expert',
#  'give',
#  'theory',
#  'support',
#  'reality',
#  'massively',
#  'overloaded',
#  'stakeholder',
#  'meeting',
#  'higher management',
#  'supposed',
#  'review decide',
#  'strategic',
#  'topic',
#  'start',
#  'reading',
#  'pre prepared',
#  'narrative',
#  'overwhelming',
#  'summary',
#  'imagine',
#  'page',
#  'booklet',
#  'minimal',
#  'margin',
#  'pt',
#  'size',
#  'letter',
#  'text',
#  'shining',
#  'pr',
#  'story',
#  'project',
#  'team',
#  'address',
#  'actual',
#  'issue',
#  'risk',
#  'resource',
#  'gap',
#  'may happen',
#  'senior manager',
#  'intuitively',
#  'ask question',
#  'find',
#  'issue usually',
#  'deep insight',
#  'topic',
#  'project',
#  'operationally',
#  'plus',
#  'focus',
#  'led',
#  'long',
#  'document',
#  'like',
#  'watching',
#  'tv',
#  'switch',
#  'brain',
#  'half baked',
#  'innovation',
#  'eg',
#  'area',
#  'device',
#  'food',
#  'retail',
#  'thrown',
#  'market',
#  'unproportionally',
#  'big',
#  'marketing effort',
#  'many',
#  'customer buy',
#  'product',
#  'realise',
#  'delivering promise',
#  'good',
#  'value',
#  'money',
#  'big organization',
#  'entrenched',
#  'culture',
#  'competition collaboration',
#  'aging',
#  'product',
#  'make difficult',
#  'impossible make',
#  'change',
#  'better',
#  'depending',
#  '’',
#  'changing',
#  'changing',
#  'year',
#  'process slow',
#  'disheartening',
#  'attitude',
#  'code',
#  'based',
#  'never',
#  'change',
#  'disorganization',
#  'long hour',
#  'short break',
#  'push',
#  'takt time',
#  'throat',
#  'hard make',
#  'meaningful impact',
#  'company',
#  'since large',
#  'food',
#  'could better',
#  'almost',
#  'many employee',
#  'sometimes difficult',
#  'get full',
#  'hour week',
#  'work',
#  'live',
#  'balance',
#  'little',
#  'holiday',
#  'strange culture',
#  'raye',
#  'expectation',
#  'raise',
#  'constantly',
#  'sometimes unmanageable',
#  'poor training',
#  'offer',
#  'employee discount',
#  'amazon',
#  'even',
#  'full time',
#  'employess',
#  'sometimes',
#  'work',
#  'exciting',
#  'lack perk',
#  'jeff bezos',
#  'literally',
#  'richest man',
#  'earth',
#  'would nice',
#  'kicked',
#  'back',
#  'money',
#  'employee perk',
#  'compete',
#  'big company',
#  'would',
#  'help attrition',
#  'slow',
#  'shift',
#  'underpaid compared',
#  'competition',
#  'follow',
#  'regular',
#  'process',
#  'open',
#  'option',
#  'limited opportunity',
#  'grow',
#  'significantly',
#  'within company',
#  'true',
#  'benefit',
#  'reserved',
#  'team',
#  'lack structure',
#  'department',
#  'political',
#  'work load',
#  'artificially created',
#  'high pressure',
#  'slow growth',
#  'work',
#  'old technology',
#  'work',
#  'boring',
#  'feel',
#  'overall great',
#  'experience',
#  'con',
#  'complaint',
#  'management horrible',
#  'hr help',
#  'whatsoever',
#  'multiple',
#  'issue',
#  'nothing ever',
#  'resolved',
#  'get touch',
#  'anyone',
#  'warehouse',
#  'present',
#  'warehouse',
#  'email',
#  'ignored',
#  'call',
#  'competitive place',
#  'work',
#  'long hour',
#  'especially',
#  'depending department',
#  'work',
#  'middle management',
#  'could use',
#  'work',
#  'expertise',
#  'necessarily mean',
#  'management',
#  'long hour',
#  'stress high',
#  'allow',
#  'learning',
#  'pace',
#  'important',
#  'office culture',
#  'lot',
#  'burocratic',
#  'process',
#  'benefit',
#  'friend',
#  'employee',
#  'high expectation',
#  'long hour',
#  'q',
#  'retail side',
#  'brutal',
#  'con',
#  'believing',
#  'create schedule',
#  'loop',
#  'preset',
#  'schedule',
#  'month',
#  'many people',
#  'quit first',
#  'day',
#  'expected',
#  'really',
#  'expect',
#  'warehouse',
#  'really',
#  'warehouse',
#  'management',
#  'trash',
#  'respond email',
#  'rarely',
#  'approve sick',
#  'time',
#  'yet',
#  'always wanted',
#  'write',
#  'give',
#  'occurrence',
#  'mistake',
#  'especially',
#  'late',
#  'missing shift',
#  'approve sick',
#  'time',
#  'received',
#  'occurrence',
#  'constantly',
#  'back',
#  'minute',
#  'inactivity',
#  'use restroom',
#  'hold',
#  'everything',
#  'end hospital',
#  'bill',
#  'way',
#  'pay',
#  'pay terrible',
#  'endure',
#  'receive benefit',
#  'receive',
#  'product',
#  'amazon',
#  'though',
#  'item sold',
#  'shipped amazon',
#  'good luck',
#  'also',
#  'cap year',
#  'cheap cheap',
#  'cheapity',
#  'cheap',
#  'stingy',
#  'company',
#  'room growth',
#  'company',
#  'distastful',
#  'left feeling',
#  'cheated',
#  'never',
#  'pay',
#  'prime membership',
#  'seeing',
#  'operate',
#  'money',
#  'going',
#  'also',
#  'stop selling',
#  'expired',
#  'funky',
#  'item',
#  'customer',
#  'many',
#  'labor law',
#  'broken',
#  'sometimes',
#  'orgs',
#  'get bit',
#  'confusing',
#  'internally',
#  'hard work',
#  'relex',
#  'work',
#  'work',
#  'work',
#  'apple',
#  'must',
#  'good',
#  'time',
#  'sometimes',
#  'face',
#  'people',
#  'like',
#  'know anything',
#  'never let',
#  'go',
#  'lower',
#  'management',
#  'great',
#  'best',
#  'manager',
#  'likely get',
#  'promoted quickly',
#  'beat',
#  'em',
#  'join',
#  'mentality',
#  'manager tend',
#  'promote',
#  'followed',
#  'around',
#  'sometimes',
#  'new idea',
#  'welcomed',
#  'mandatory overtime',
#  'hour shift',
#  'shorter',
#  'shift',
#  'balance',
#  'personal life',
#  'many',
#  'hour day',
#  'week',
#  'hour per',
#  'day',
#  'part time',
#  'however',
#  'pick shift',
#  'easily',
#  'internal promotion',
#  'hyped',
#  'training',
#  'apple',
#  'fails',
#  'promote within',
#  'getting screamed',
#  'whole shift',
#  'thing',
#  'completely control',
#  'time',
#  'go',
#  'break cry',
#  'people',
#  'truly',
#  'mean',
#  'package',
#  'day',
#  'freaking',
#  'late',
#  'creating',
#  'good',
#  'work life',
#  'balance difficult',
#  'amazon',
#  'expectation',
#  'time',
#  'unreasonably high',
#  'mindset',
#  'pivot quickly',
#  'depending',
#  'management',
#  'bad',
#  'culture',
#  'imposed',
#  'last year',
#  'extremely',
#  'focused',
#  'scorecard',
#  'taking picture',
#  'many case',
#  'customer',
#  'new',
#  'executive',
#  'task oriented',
#  'want',
#  'people',
#  'execute',
#  'instead',
#  'intelligent people',
#  'different approach',
#  'visión',
#  'many',
#  'decision based',
#  'impacting',
#  'scorecard',
#  'even',
#  'damage',
#  'company image',
#  'future',
#  'business',
#  'customer',
#  'relationship',
#  'big',
#  'give',
#  'everyone',
#  'chance show',
#  'impact',
#  'lot',
#  'restructuring',
#  'going',
#  'time',
#  'focus',
#  'really matter',
#  'people',
#  'work load',
#  'insecure',
#  'much competition',
#  'lot opportunity',
#  'grow',
#  'least',
#  'within retail',
#  'hour',
#  'le',
#  'fantastic',
#  'highly stressful',
#  'environment',
#  'management',
#  'really listen',
#  'concern',
#  'make',
#  'working',
#  'little',
#  'le appealing',
#  'time',
#  'making',
#  'employee',
#  'ready leave',
#  'early',
#  'encouragement',
#  'stay',
#  'get',
#  'product',
#  'life',
#  'inside outside',
#  'work',
#  'likely become',
#  'blended',
#  'may okay',
#  'many people',
#  'company',
#  'become',
#  'friend',
#  'work',
#  'intense',
#  'got ta',
#  'learn manage',
#  'time',
#  'well',
#  'fast paced',
#  'environment',
#  'think',
#  'everyone',
#  'realizes',
#  'much',
#  'really need',
#  'help',
#  'beginning end',
#  'many',
#  'stowers',
#  'chill',
#  'isle',
#  'block',
#  'isle',
#  'overfill',
#  'bin',
#  'also',
#  'shut',
#  'leave',
#  'stolls',
#  'isle',
#  'lot',
#  'trash',
#  'item',
#  'floor',
#  'people',
#  'walk',
#  'buy',
#  'people',
#  'master',
#  'lot',
#  'different product',
#  'many',
#  'scorecard',
#  'achieve',
#  'worklife balance',
#  'super',
#  ...]

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
from gensim.corpora import Dictionary
import pyLDAvis
import pyLDAvis.gensim

# %%
id2word = corpora.Dictionary(tokens)
dictionary = id2word
dictionary = dictionary.filter_extremes(no_above=0.90)

texts = tokens
corpus = [id2word.doc2bow(text) for text in texts]
ldamallet = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=2, id2word=id2word, iterations=100)

coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=texts, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()

def compute_coherence_values(dictionary, corpus, texts, limit=8, start=2, step=1):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=id2word, alpha=.91)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts, start=4, limit=8, step=2)

max_y = max(coherence_values)  # Find the maximum y value
max_x = coherence_values.index(max(coherence_values))  # Find the x value corresponding to the maximum y value
#xmax = x[numpy.argmax(y)]

optimal_model = model_list[coherence_values.index(max(coherence_values))]
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(optimal_model, corpus, id2word, R=10)
vis
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.153638 -0.070528       1        1  27.790388
# 5     -0.043158 -0.042685       2        1  15.442578
# 3     -0.024685 -0.062193       3        1  15.033714
# 4     -0.200416  0.022732       4        1  14.977421
# 1      0.074234  0.172784       5        1  13.455653
# 0      0.040387 -0.020109       6        1  13.300240, topic_info=     Category         Freq                 Term        Total  loglift  logprob
# 169   Default  9258.000000                 work  9258.000000  10.0000  10.0000
# 14    Default  2690.000000              balance  2690.000000   9.0000   9.0000
# 24    Default  2823.000000            work life  2823.000000   8.0000   8.0000
# 164   Default  5118.000000               people  5118.000000   7.0000   7.0000
# 109   Default  1955.000000                 hour  1955.000000   6.0000   6.0000
# 555   Default  1350.000000                  pay  1350.000000   5.0000   5.0000
# 99    Default  1075.000000            long hour  1075.000000   4.0000   4.0000
# 87    Default  1043.000000                  con  1043.000000   3.0000   3.0000
# 200   Default  2407.000000                 much  2407.000000   2.0000   2.0000
# 399   Default   769.000000               retail   769.000000   1.0000   1.0000
# 3006   Topic1   107.505539               survey   109.043449   1.2663  -7.1379
# 6713   Topic1    50.979790             spending    51.822899   1.2641  -7.8840
# 6714   Topic1    55.608624              trainer    56.552341   1.2637  -7.7971
# 992    Topic1    99.468132                    •   101.212364   1.2631  -7.2156
# 4935   Topic1    48.587872             approved    49.526569   1.2613  -7.9320
# 4548   Topic1    57.603924              scanner    58.730869   1.2611  -7.7618
# 8343   Topic1    43.694176            terminate    44.564808   1.2608  -8.0382
# 7759   Topic1    55.897263              go home    57.077145   1.2596  -7.7919
# 7103   Topic1    42.879826          join amazon    43.786644   1.2596  -8.0570
# 1472   Topic1    87.554199                   oh    89.406433   1.2595  -7.3431
# 1334   Topic1   168.608551                    ”   172.189728   1.2595  -6.6878
# 1333   Topic1   138.757233                    “   142.970093   1.2506  -6.8827
# 3176   Topic1   135.246628               safety   139.500717   1.2495  -6.9083
# 407    Topic1   102.401314                story   105.211075   1.2534  -7.1865
# 2918   Topic1   177.584991               called   186.404236   1.2320  -6.6360
# 2860   Topic1    92.409103              advisor    95.230850   1.2504  -7.2892
# 3663   Topic1   251.883102                  ask   267.949127   1.2186  -6.2864
# 549    Topic1   217.966583               minute   231.747101   1.2192  -6.4311
# 261    Topic1   372.511353                 told   406.207672   1.1939  -5.8951
# 2633   Topic1   224.203369                fired   239.619186   1.2140  -6.4028
# ...       ...          ...                  ...          ...      ...      ...
# 563    Topic5   395.811554             schedule   679.777405   1.4649  -5.1092
# 169    Topic5  1148.346680                 work  9258.261719  -0.0814  -4.0440
# 71     Topic5   831.825684           management  4271.364258   0.3697  -4.3665
# 5954   Topic6    63.353172                  und    64.223808   2.0037  -6.9298
# 1821   Topic6    74.386009  horrible management    75.632774   2.0008  -6.7692
# 6078   Topic6    60.307728          end working    61.400265   1.9994  -6.9790
# 3853   Topic6    46.690281                  der    47.624557   1.9976  -7.2350
# 6788   Topic6    45.440056              anytime    46.364582   1.9972  -7.2621
# 6409   Topic6    48.479702                 dept    49.726795   1.9920  -7.1973
# 4313   Topic6    44.644161            workspace    45.851593   1.9907  -7.2798
# 5938   Topic6    30.582945                  bei    31.432837   1.9900  -7.6580
# 3854   Topic6    36.198441                  ist    37.232464   1.9892  -7.4895
# 8542   Topic6    28.535049                  auf    29.359936   1.9889  -7.7274
# 6509   Topic6    59.320141            headcount    61.107845   1.9877  -6.9955
# 4366   Topic6    40.031864  leadership position    41.434120   1.9830  -7.3888
# 87     Topic6   902.276855                  con  1043.452881   1.8720  -4.2736
# 213    Topic6   663.747498                  big   761.670349   1.8798  -4.5806
# 1682   Topic6    70.509743                  die    74.426682   1.9633  -6.8227
# 3186   Topic6   136.438721           repetitive   164.949753   1.8276  -6.1626
# 169    Topic6  4014.608643                 work  9258.261719   1.1818  -2.7808
# 5015   Topic6    87.132538           aggressive   100.077911   1.8789  -6.6111
# 955    Topic6   197.109634               pretty   273.334351   1.6905  -5.7947
# 164    Topic6  1947.565430               people  5118.803711   1.0510  -3.5042
# 558    Topic6   760.711487               really  1718.598022   1.2024  -4.4442
# 200    Topic6   950.870544                 much  2407.618408   1.0884  -4.2211
# 49     Topic6   886.857544                 good  2510.462402   0.9769  -4.2908
# 679    Topic6   433.877411                place   943.769043   1.2403  -5.0057
# 522    Topic6   953.681763                  lot  2989.769775   0.8748  -4.2182
# 52     Topic6   598.138123                 make  1799.819092   0.9158  -4.6847
# 167    Topic6   783.252686                  get  4137.765625   0.3529  -4.4150
#
# [203 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 2532      1  0.011822     activity
# 2532      2  0.910298     activity
# 2532      3  0.023644     activity
# 2532      4  0.023644     activity
# 2532      5  0.011822     activity
# 2860      1  0.966074      advisor
# 2860      5  0.021002      advisor
# 5015      1  0.019984   aggressive
# 5015      2  0.019984   aggressive
# 5015      3  0.009992   aggressive
# 5015      4  0.059953   aggressive
# 5015      5  0.019984   aggressive
# 5015      6  0.869323   aggressive
# 3720      2  0.947306        agile
# 3720      3  0.022555        agile
# 3720      4  0.011277        agile
# 6294      3  0.978560          air
# 458       1  0.727215       amazon
# 458       2  0.062608       amazon
# 458       3  0.052538       amazon
# 458       4  0.011821       amazon
# 458       5  0.012259       amazon
# 458       6  0.133972       amazon
# 6788      6  0.970568      anytime
# 2736      5  0.981850  apple store
# 4935      1  0.989368     approved
# 3663      1  0.940477          ask
# 3663      2  0.007464          ask
# 3663      3  0.011196          ask
# 3663      4  0.003732          ask
# ...     ...       ...          ...
# 24        6  0.045327    work life
# 104       1  0.306059      working
# 104       2  0.049884      working
# 104       3  0.363737      working
# 104       4  0.040011      working
# 104       5  0.061316      working
# 104       6  0.179271      working
# 4313      6  0.981427    workspace
# 105       1  0.674358        would
# 105       2  0.056894        would
# 105       3  0.151438        would
# 105       4  0.009203        would
# 105       5  0.076137        would
# 105       6  0.033467        would
# 9995      4  0.988652            à
# 268       1  0.730914            ’
# 268       2  0.014873            ’
# 268       3  0.004250            ’
# 268       4  0.003187            ’
# 268       5  0.239034            ’
# 268       6  0.007437            ’
# 1333      1  0.972231            “
# 1333      2  0.013989            “
# 1333      4  0.006994            “
# 1334      1  0.981476            ”
# 1334      2  0.011615            ”
# 1334      4  0.005808            ”
# 1334      5  0.005808            ”
# 992       1  0.978141            •
# 992       5  0.009880            •
#
# [693 rows x 3 columns], R=10, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 6, 4, 5, 2, 1])

# %%
pyLDAvis.save_html(vis, 'pyLDAvis1.html')
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from gensim.models.phrases import Phrases
bigram = Phrases(phrases)
print(bigram[negatives])

# %%
from nltk import word_tokenize
def tokenize(df):
    tokenized_text = word_tokenize(str(df))
    return tokenized_text

negatives_tokenized = negatives.apply(tokenize)
negatives_tokenized[0]
