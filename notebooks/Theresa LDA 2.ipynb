# %%
import pandas as pd
import numpy as np
import os
import gensim
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
from gensim.corpora import Dictionary
import pyLDAvis
import pyLDAvis.gensim
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
path = os.path.join(os.getcwd(), '../raw_data')

data_prep = pd.read_csv(os.path.join(path, 'pos_neg_df.csv'))
data_prep
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                positives  \
# 0      work people passionate care greater good fanta...
# 1      lot knowledge flexible hour office process rea...
# 2      immense carrier opportunity growth opportunity...
# 3      employee food benefit perk shuttle basically e...
# 4                          good pay somewhat nice people
# 5      great environment work product excellent repre...
# 6      great benefit salary ability move around team ...
# 7      perk life fb help manage every aspect work lif...
# 8      get face almost everything looking technical e...
# 9                  flexible tech driven health conscious
# 10       big money good software developer guess con pro
# 11            lot learning opportunity inside de company
# 12     name recognition literally thing going worst p...
# 13     working oak amazon fresh best job ever shut do...
# 14     much opportunity grow let make mistake matter ...
# 15              easy relocate internally competitive pay
# 16     friendly environment amazing office relaxed at...
# 17     gym pay lot task center let work sweat move di...
# 18     great role working company around solution sel...
# 19      straight forward management flexible complicated
# 20                               great benefit start day
# 21                             called brand nothing else
# 22               flexible school great co worker benefit
# 23                              fun enviorment learn lot
# 24     really nice food mean really nice food always ...
# 25     benefit hour lunch community involvement emplo...
# 26     lovely campus financially healthy good fresh h...
# 27          complicated help customer job easy competent
# 28     flexible working environment respect career op...
# 29     miss team people google done great job hiring ...
# ...                                                  ...
# 29864                 good pay good people good facility
# 29865  everyone matter high company willing help what...
# 29866                 excellent benefit medical dental k
# 29867  amazon provides excellent work environment ass...
# 29868   good work environment smart people great company
# 29869                great team environment within store
# 29870                                          sorry pro
# 29871                      co worker made job worthwhile
# 29872  facility world class get work nice mac compute...
# 29873  benefit exception health insurance good health...
# 29874  making design customer experience go live used...
# 29875  amazing training opportunity work abroad take ...
# 29876  employee discount flexible schedule please see...
# 29877  good selection benefit competitive wage casual...
# 29878  great benefit great pay nice environment usual...
# 29879  benefit share medical insurance thing keeping ...
# 29880  clearly best pay greatest work love colleague ...
# 29881        successful company great talk friend family
# 29882  good working environment colleague easy deal f...
# 29883                       company benefit believe sell
# 29884  decent pay good benefit everyone got along wel...
# 29885  easy stand good job hour pretty flexible compl...
# 29886  good employer great benefit work home remote m...
# 29887               world wide impact product enterprise
# 29888              work home quarterly merit based bonus
# 29889  reasonable salary brand value international pr...
# 29890  excellent pay smart people great benefit gadge...
# 29891               flexible hour good work life balance
# 29892  free dinner great pay nice campus apple produc...
# 29893  cleverest people worked amazing tool use great...
#
#                                                negatives
# 0                  need open office many office sunlight
# 1      key problem company lost true leader existing ...
# 2      working fc first difficult week get habitual s...
# 3      company become way vertical performance evalua...
# 4                               hired ’ always something
# 5      pay low opportunity move within pay scale lie ...
# 6      lot lot meeting top decision making lot coaste...
# 7      environment hyper competitive everybody really...
# 8      management matured always end micro managing r...
# 9                                            amazon scam
# 10     difficult work environment useless competition...
# 11                           office politics slow career
# 12     discrimination back stabbing retaliation list ...
# 13     working ar site suck oak micromanaged througho...
# 14     job role limited hard get promotion salary com...
# 15     hardly decency mutual respect among employee b...
# 16       amount work rapid changing environment priority
# 17     ask deceive simple way question management met...
# 18     focus around monthly target need long term str...
# 19                              pay average know getting
# 20     promote within company overlook employee degre...
# 21     risky outside hire see amazon recruiting time ...
# 22     customer nasty expect much manager agree long ...
# 23     maybe work life balance could better overall good
# 24     nothing really everybody employed nice polite ...
# 25     everything worse team history employment inter...
# 26     stack ranking killer promotes people work back...
# 27     technically discriminate age either constant c...
# 28     repetitive overtime work overtime work overtim...
# 29     people outside u increasingly becoming u well ...
# ...                                                  ...
# 29864                         hour work week peak season
# 29865  work culture largely self driven particular st...
# 29866                    need flexibility remote working
# 29867  hour tiring working hour shift everyone long p...
# 29868                nothing advice needed great company
# 29869                   retail job micromanaging manager
# 29870  advance thought would priority qualification s...
# 29871          constant crush customer store always busy
# 29872  contractor staffing company pay low even k man...
# 29873  health insurance benefit went zero premium zer...
# 29874  expect gain weight go anti anxiety med resume ...
# 29875                  bureaucratic also many team might
# 29876  always wanted work apple culture seems welcomi...
# 29877  short break min break dedicated walking back f...
# 29878  competitive nature team make hard make cross g...
# 29879  manager people skill hardly good manager one u...
# 29880  comfortable sometimes probably challenging eno...
# 29881  secrecy security get way time work life balanc...
# 29882  salary lack competition support engineer good ...
# 29883                            room growth within sale
# 29884  much politics manager favorite feel like worki...
# 29885  really hard work full hour either get vto mto ...
# 29886               metric death scorecard cow come home
# 29887    work life balance constantly changing landscape
# 29888  customer treat horribly everything merit based...
# 29889  poor management transparency top speech limite...
# 29890  big slow many silo distributed hard tell going...
# 29891  weak senior management la office manager train...
# 29892     encourage stay past limited term impact create
# 29893  big company little pond huge sometimes politic...
#
# [29894 rows x 2 columns]

# %%
negatives = data_prep.negatives.dropna()
negatives
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0                    need open office many office sunlight
# 1        key problem company lost true leader existing ...
# 2        working fc first difficult week get habitual s...
# 3        company become way vertical performance evalua...
# 4                                 hired ’ always something
# 5        pay low opportunity move within pay scale lie ...
# 6        lot lot meeting top decision making lot coaste...
# 7        environment hyper competitive everybody really...
# 8        management matured always end micro managing r...
# 9                                              amazon scam
# 10       difficult work environment useless competition...
# 11                             office politics slow career
# 12       discrimination back stabbing retaliation list ...
# 13       working ar site suck oak micromanaged througho...
# 14       job role limited hard get promotion salary com...
# 15       hardly decency mutual respect among employee b...
# 16         amount work rapid changing environment priority
# 17       ask deceive simple way question management met...
# 18       focus around monthly target need long term str...
# 19                                pay average know getting
# 20       promote within company overlook employee degre...
# 21       risky outside hire see amazon recruiting time ...
# 22       customer nasty expect much manager agree long ...
# 23       maybe work life balance could better overall good
# 24       nothing really everybody employed nice polite ...
# 25       everything worse team history employment inter...
# 26       stack ranking killer promotes people work back...
# 27       technically discriminate age either constant c...
# 28       repetitive overtime work overtime work overtim...
# 29       people outside u increasingly becoming u well ...
#                                ...
# 29864                           hour work week peak season
# 29865    work culture largely self driven particular st...
# 29866                      need flexibility remote working
# 29867    hour tiring working hour shift everyone long p...
# 29868                  nothing advice needed great company
# 29869                     retail job micromanaging manager
# 29870    advance thought would priority qualification s...
# 29871            constant crush customer store always busy
# 29872    contractor staffing company pay low even k man...
# 29873    health insurance benefit went zero premium zer...
# 29874    expect gain weight go anti anxiety med resume ...
# 29875                    bureaucratic also many team might
# 29876    always wanted work apple culture seems welcomi...
# 29877    short break min break dedicated walking back f...
# 29878    competitive nature team make hard make cross g...
# 29879    manager people skill hardly good manager one u...
# 29880    comfortable sometimes probably challenging eno...
# 29881    secrecy security get way time work life balanc...
# 29882    salary lack competition support engineer good ...
# 29883                              room growth within sale
# 29884    much politics manager favorite feel like worki...
# 29885    really hard work full hour either get vto mto ...
# 29886                 metric death scorecard cow come home
# 29887      work life balance constantly changing landscape
# 29888    customer treat horribly everything merit based...
# 29889    poor management transparency top speech limite...
# 29890    big slow many silo distributed hard tell going...
# 29891    weak senior management la office manager train...
# 29892       encourage stay past limited term impact create
# 29893    big company little pond huge sometimes politic...
# Name: negatives, Length: 29889, dtype: object

# %%
from nltk import word_tokenize
def tokenize(df):
    tokenized_text = word_tokenize(str(df))
    return tokenized_text
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from gensim.models import Phrases

from gensim.models.phrases import Phraser


sentence_stream = [doc.split(" ") for doc in negatives]
#print(sentence_stream)

bigram = Phrases(sentence_stream, min_count=13, threshold=65, delimiter=b' ')

bigram_phraser = Phraser(bigram)


#print(bigram_phraser)
tokens = []
for sent in sentence_stream:
    tokens_ = bigram_phraser[sent]
    tokens.append(tokens_)

tokens
    #print(tokens_)
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['need', 'open', 'office', 'many', 'office', 'sunlight'],
#  ['key',
#   'problem',
#   'company',
#   'lost',
#   'true',
#   'leader',
#   'existing',
#   'one',
#   'wildly',
#   'praising',
#   'importance',
#   'exaggerating',
#   'anything',
#   'may',
#   'sound',
#   'nice',
#   'cultivated',
#   'truly',
#   'ego',
#   'centric',
#   'behavior',
#   'dramatic',
#   'completely',
#   'misaligned',
#   'original',
#   'value',
#   'focused',
#   'teamwork',
#   'actual',
#   'achievement',
#   'biggest',
#   'priority',
#   'became',
#   'report',
#   'make',
#   'excellent',
#   'selling',
#   'story',
#   'present',
#   'management',
#   'without',
#   'sound',
#   'criticism',
#   'deep',
#   'insight',
#   'showing',
#   'influencing',
#   'others',
#   'bad',
#   'decision',
#   'became',
#   'core',
#   'competence',
#   'anything',
#   'anyone',
#   'move',
#   'get',
#   'bubble',
#   'transparent',
#   'fact',
#   'measured',
#   'obstructed',
#   'often',
#   'destroyed',
#   'early',
#   'stage',
#   'amazing',
#   'sensitivity',
#   'aggression',
#   'changing',
#   'marketing',
#   'agency',
#   'also',
#   'bad',
#   'smell',
#   'nutshell',
#   'big',
#   'investment',
#   'hr',
#   'branding',
#   'real',
#   'disappointment',
#   'real',
#   'job'],
#  ['working',
#   'fc',
#   'first',
#   'difficult',
#   'week',
#   'get',
#   'habitual',
#   'sometimes',
#   'really',
#   'need',
#   'someone',
#   'handhold',
#   'new',
#   'thing',
#   'believe',
#   'find',
#   'one',
#   'make',
#   'mistake',
#   'learn',
#   'repeat',
#   'growth',
#   'opportunity',
#   'defined',
#   'never',
#   'know',
#   'thing',
#   'might',
#   'lead',
#   'next',
#   'level',
#   'might',
#   'hold',
#   'back'],
#  ['company',
#   'become',
#   'way',
#   'vertical',
#   'performance evaluation',
#   'longer',
#   'representative',
#   'arbitrary',
#   'unwritten',
#   'rule',
#   'contradict',
#   'written',
#   'rule'],
#  ['hired', '’', 'always', 'something'],
#  ['pay',
#   'low',
#   'opportunity',
#   'move',
#   'within',
#   'pay',
#   'scale',
#   'lie',
#   'ability',
#   'relocate',
#   'cupertino',
#   'long',
#   'term',
#   'career',
#   'difficult',
#   'imagine'],
#  ['lot',
#   'lot',
#   'meeting',
#   'top',
#   'decision making',
#   'lot',
#   'coaster',
#   'lack',
#   'bias action',
#   'make',
#   'change',
#   'required'],
#  ['environment',
#   'hyper',
#   'competitive',
#   'everybody',
#   'really',
#   'good',
#   'motivated',
#   'room',
#   'slightest',
#   'slack',
#   'lot',
#   'employee',
#   'seem',
#   'taking',
#   'perk',
#   'culture',
#   'granted',
#   'good',
#   'trend'],
#  ['management',
#   'matured',
#   'always',
#   'end',
#   'micro managing',
#   'rather',
#   'focussing',
#   'burning',
#   'issue'],
#  ['amazon', 'scam'],
#  ['difficult',
#   'work',
#   'environment',
#   'useless',
#   'competition',
#   'within',
#   'team'],
#  ['office', 'politics', 'slow', 'career'],
#  ['discrimination',
#   'back stabbing',
#   'retaliation',
#   'list',
#   'go',
#   'forever',
#   'leveling',
#   'white male',
#   'leveling',
#   'woman',
#   'people',
#   'color',
#   'even',
#   'seen',
#   'legal',
#   'department',
#   'try',
#   'pip',
#   'fire',
#   'woman',
#   'simply',
#   'taking',
#   'maternity leave'],
#  ['working',
#   'ar',
#   'site',
#   'suck',
#   'oak',
#   'micromanaged',
#   'throughout',
#   'shift',
#   'productivity',
#   'rate',
#   'high',
#   'using',
#   'restroom',
#   'bring',
#   'rate',
#   'lot',
#   'favoritism',
#   'lot',
#   'cherry',
#   'picker',
#   'way',
#   'make',
#   'rate',
#   'quality',
#   'writeups',
#   'every',
#   'quality',
#   'mistake',
#   'must',
#   'stow',
#   'unit',
#   'otherwise',
#   'get',
#   'write',
#   'easy',
#   'make',
#   'honest',
#   'mistake',
#   'three',
#   'writeups',
#   'terminated',
#   'short break',
#   'two',
#   'minute',
#   'break',
#   'hour',
#   'shift',
#   'one',
#   'minute',
#   'lunch',
#   'break',
#   'enough',
#   'restroom',
#   'nearby',
#   'least',
#   'stall',
#   'restroom',
#   'mezzanine'],
#  ['job',
#   'role',
#   'limited',
#   'hard',
#   'get',
#   'promotion',
#   'salary',
#   'competitive'],
#  ['hardly',
#   'decency',
#   'mutual',
#   'respect',
#   'among',
#   'employee',
#   'bogus',
#   'value',
#   'even',
#   'try',
#   'live',
#   'work',
#   'life balance'],
#  ['amount', 'work', 'rapid', 'changing', 'environment', 'priority'],
#  ['ask',
#   'deceive',
#   'simple',
#   'way',
#   'question',
#   'management',
#   'met',
#   'shoulder',
#   'shrug',
#   'pat',
#   'vague',
#   'answer',
#   'outright',
#   'lie',
#   'gross',
#   'inefficiency',
#   'morale',
#   'killing',
#   'perverse',
#   'incentive',
#   'scanner',
#   'tool',
#   'cash',
#   'incentive',
#   'discourage',
#   'rather',
#   'encourage',
#   'broad',
#   'scale',
#   'individual',
#   'performance',
#   'improvement',
#   'advantage',
#   'people',
#   'performing',
#   'certain',
#   'function',
#   'improvement',
#   'resource',
#   'inadequate',
#   'employee',
#   'waste',
#   'hour',
#   'wandering',
#   'around',
#   'looking',
#   'location',
#   'resource',
#   'shift',
#   'regularly',
#   'floor',
#   'guide',
#   'map',
#   'update',
#   'employee',
#   'change',
#   'line',
#   'supervisor',
#   'often',
#   'clueless',
#   'sorter',
#   'inconsistent',
#   'rule',
#   'early',
#   'release',
#   'opportunity',
#   'communicated',
#   'different',
#   'way',
#   'different',
#   'time',
#   'day',
#   'secret',
#   'offer',
#   'group',
#   'individual',
#   'technique',
#   'encourage',
#   'worker',
#   'break',
#   'company',
#   'rule',
#   'cell phone',
#   'use',
#   'shift',
#   'biased',
#   'scanner',
#   'based',
#   'feedback',
#   'system',
#   'employee',
#   'must',
#   'answer',
#   'three',
#   'survey',
#   'question',
#   'appear',
#   'scanner',
#   'device',
#   'becomes',
#   'functional',
#   'opening',
#   'screen',
#   'response',
#   'includes',
#   'positive',
#   'choice',
#   'negative',
#   'response',
#   'require',
#   'tapping',
#   'multiple',
#   'key',
#   'scrolling',
#   'limited',
#   'remedial',
#   'training',
#   'supervisor',
#   'respond',
#   'scanner',
#   'indicate',
#   'repeated',
#   'error',
#   'onsite',
#   'tutorial',
#   'manual',
#   'employee',
#   'consult',
#   'answer question',
#   'learn',
#   'new',
#   'technique',
#   'easily',
#   'correctable',
#   'pallet',
#   'building',
#   'error',
#   'frustrate',
#   'employee',
#   'rarely',
#   'addressed',
#   'standups',
#   'downer',
#   'leader',
#   'spout',
#   'stock',
#   'safety',
#   'quality',
#   'message',
#   'meeting',
#   'shift',
#   'start',
#   'handed',
#   'superior',
#   'repeated',
#   'incessantly',
#   'visuals',
#   'time',
#   'q',
#   'lot',
#   'jargon',
#   'mean',
#   'nothing',
#   'translation',
#   'employee',
#   'weak',
#   'english',
#   'understanding'],
#  ['focus', 'around', 'monthly', 'target', 'need', 'long', 'term', 'strategic'],
#  ['pay', 'average', 'know', 'getting'],
#  ['promote',
#   'within',
#   'company',
#   'overlook',
#   'employee',
#   'degree',
#   'education',
#   'important',
#   'management',
#   'favoritism'],
#  ['risky',
#   'outside',
#   'hire',
#   'see',
#   'amazon',
#   'recruiting',
#   'time',
#   'reason',
#   'high',
#   'attrition',
#   'need',
#   'employee',
#   'every',
#   'external',
#   'hire',
#   'quit',
#   'year',
#   'quit',
#   'nd',
#   'year',
#   'end',
#   'remain',
#   'till',
#   'end',
#   'th',
#   'year',
#   'rsus',
#   'vest',
#   'outside',
#   'hire',
#   'chance',
#   'quit',
#   'year',
#   'denting',
#   'cv',
#   'high',
#   'risk',
#   'ready',
#   'micromanaged',
#   'jeff bezos',
#   'infamous',
#   'micromanager',
#   'manager',
#   'amazon',
#   'micromanage',
#   'told',
#   'including',
#   'font',
#   'word',
#   'document',
#   'type',
#   'excel',
#   'create',
#   'type',
#   'comment',
#   'provide',
#   'nobody',
#   'care',
#   'hr',
#   'non existent',
#   'company',
#   'leadership principle',
#   'big',
#   'hoax',
#   'paper',
#   'none',
#   'followed',
#   'manager',
#   'interested',
#   'furthering',
#   'career',
#   'meaningful',
#   'career',
#   'discussion',
#   'possible',
#   'career',
#   'level',
#   'one',
#   'joined',
#   'campus',
#   'stayed',
#   'many',
#   'year',
#   'amazon',
#   'drastic',
#   'margin',
#   'career',
#   'level',
#   'amazon',
#   'level',
#   'sde',
#   'level',
#   'sde',
#   'tpm',
#   'manager',
#   'ii',
#   'product',
#   'manager',
#   'level',
#   'sde',
#   'sr',
#   'engineer',
#   'tpm',
#   'iii',
#   'manager',
#   'iii',
#   'sr',
#   'product',
#   'manager',
#   'level',
#   'principal',
#   'engineer',
#   'principal',
#   'tpm',
#   'senior',
#   'manager',
#   'software',
#   'dev',
#   'senior',
#   'manager',
#   'product',
#   'management',
#   'camouflage',
#   'external',
#   'market',
#   'general',
#   'manager',
#   'hoodwink',
#   'ppl',
#   'level',
#   'director',
#   'level',
#   'vp',
#   'level',
#   'level',
#   'svp',
#   'level',
#   'bezos',
#   'ceo',
#   'internal',
#   'campus',
#   'hire',
#   'level',
#   'usually',
#   'sde',
#   'stay',
#   'year',
#   'making',
#   'level',
#   'level',
#   'level',
#   'tough',
#   'take',
#   'upto',
#   'year',
#   'level',
#   'also',
#   'year',
#   'external',
#   'hire',
#   'outsider',
#   'level',
#   'folk',
#   'le',
#   'year',
#   'work',
#   'ex',
#   'salary',
#   'lower',
#   'max',
#   'band',
#   'level',
#   'come',
#   'level',
#   'folk',
#   'salary',
#   'le',
#   'max',
#   'level',
#   'upto',
#   'year',
#   'hired',
#   'level',
#   'folk',
#   'le',
#   'year',
#   'hired',
#   'level',
#   'need',
#   'net',
#   'net',
#   'level',
#   'outsider',
#   'could',
#   'director',
#   'travelocity',
#   'campus',
#   'hire',
#   'within',
#   'year',
#   'bad',
#   'outsider',
#   'director',
#   'yahoo',
#   'may',
#   'join',
#   'level',
#   'report',
#   'joker',
#   'ppl',
#   'manager',
#   'skill',
#   'year',
#   'younger',
#   'associate',
#   'team',
#   'bangalore',
#   'one',
#   'team',
#   'worst',
#   'work',
#   'pay',
#   'design',
#   'pay',
#   'base',
#   'pay',
#   'sign',
#   'sign',
#   'first',
#   'year',
#   'second',
#   'year',
#   'trick',
#   'ensure',
#   'run',
#   'treadmill',
#   'year',
#   'salary',
#   'beginning',
#   'rd',
#   'year',
#   'le',
#   'first',
#   'year',
#   'promoted',
#   'recruiter',
#   'lie',
#   'due',
#   'high',
#   'hiring',
#   'bar',
#   'bar',
#   'raiser',
#   'interview',
#   'reject',
#   'interview',
#   'mean',
#   'recruiter',
#   'tremendous',
#   'pressure',
#   'get',
#   'candidate',
#   'position',
#   'open',
#   'month',
#   'finaly',
#   'moved',
#   'back',
#   'seattle',
#   'recruiter',
#   'lie',
#   'left',
#   'right',
#   'center',
#   'get',
#   'candidate',
#   'trust',
#   'recruiter',
#   'lack',
#   'social',
#   'etiquette',
#   'amazon',
#   'official',
#   'line',
#   'since',
#   'ppl',
#   'overworked',
#   'socialize',
#   'develop',
#   'social',
#   'etiquette',
#   'typical',
#   'amazon',
#   'manager',
#   'grow',
#   'within',
#   'abrasive',
#   'net',
#   'net',
#   'bad',
#   'place',
#   'join',
#   'anyone',
#   'experienced',
#   'risk',
#   'outweigh',
#   'benefit',
#   'infact',
#   'unless',
#   'offer',
#   'x',
#   'pay',
#   'worth',
#   'joining',
#   'amazon',
#   'recommend',
#   'company',
#   'worst',
#   'enemy'],
#  ['customer',
#   'nasty',
#   'expect',
#   'much',
#   'manager',
#   'agree',
#   'long',
#   'often',
#   'rule',
#   'judgment',
#   'situation'],
#  ['maybe', 'work', 'life balance', 'could', 'better', 'overall', 'good'],
#  ['nothing',
#   'really',
#   'everybody',
#   'employed',
#   'nice',
#   'polite',
#   'great',
#   'change',
#   'average',
#   'office',
#   'cubicle',
#   'job'],
#  ['everything',
#   'worse',
#   'team',
#   'history',
#   'employment',
#   'internal',
#   'process',
#   'practically',
#   'make',
#   'everyone',
#   'go',
#   'ad',
#   'leadership',
#   'cant',
#   'even',
#   'get',
#   'job',
#   'right',
#   'policy',
#   'rule',
#   'sexual',
#   'harrassment',
#   'physical',
#   'threat',
#   'policy',
#   'violation',
#   'ignored',
#   'personal',
#   'life',
#   'family',
#   'school',
#   'second',
#   'job',
#   'arent',
#   'taken',
#   'consideration',
#   'dont',
#   'care',
#   'alot',
#   'legal',
#   'issue',
#   'making',
#   'thing',
#   'moral',
#   'value',
#   'ethic',
#   'law',
#   'religion',
#   'constantly',
#   'tell',
#   'find',
#   'new',
#   'job',
#   'currently',
#   'work',
#   'mass',
#   'firing',
#   'giving',
#   'anyone',
#   'reason',
#   'write ups',
#   'legal',
#   'proof',
#   'structure',
#   'promotion',
#   'based',
#   'favoritism',
#   'dead end',
#   'role',
#   'growth',
#   'opportunity',
#   'demean',
#   'praise',
#   'care',
#   'number',
#   'bot',
#   'person',
#   'accountability',
#   'leadership',
#   'role',
#   'place',
#   'blame',
#   'everyone',
#   'right',
#   'dont',
#   'practice',
#   'preach',
#   'leadership principle',
#   'dont',
#   'go',
#   'beyond',
#   'leadership',
#   'take',
#   'full',
#   'advantage',
#   'every',
#   'way',
#   'possible',
#   'without',
#   'promotion',
#   'legal',
#   'tool',
#   'resource',
#   'effectively',
#   'job',
#   'quality',
#   'auditing',
#   'process',
#   'horrific',
#   'accountability',
#   'within',
#   'leadership',
#   'nooooo',
#   'consistency',
#   'place',
#   'blame',
#   'team',
#   'environment',
#   'senior',
#   'taking',
#   'everyone',
#   'want',
#   'quit',
#   'team',
#   'creation',
#   'outcome',
#   'exact',
#   'opposite',
#   'upskills',
#   'garbage',
#   'dont',
#   'offer',
#   'tool',
#   'resource',
#   'enough',
#   'training',
#   'help',
#   'anything',
#   'right',
#   'taught',
#   'get',
#   'fail',
#   'every',
#   'way',
#   'including',
#   'quality',
#   'audit',
#   'dont',
#   'fall',
#   'trick',
#   'dont',
#   'care',
#   'say',
#   'anything',
#   'voice',
#   'influence',
#   'care',
#   'world',
#   'given',
#   'leadership',
#   'regard',
#   'anything',
#   'good luck',
#   'rest',
#   'fool',
#   'apply',
#   'role'],
#  ['stack ranking',
#   'killer',
#   'promotes',
#   'people',
#   'work',
#   'backstabbing',
#   'etc',
#   'innovation',
#   'non',
#   'competitive',
#   'nature',
#   'always',
#   'late',
#   'market',
#   'reward',
#   'technical',
#   'skill',
#   'poor',
#   'decision',
#   'maker',
#   'higher',
#   'management',
#   'long',
#   'release',
#   'cycle',
#   'bureaucracy',
#   'politics',
#   'overrrides',
#   'everything',
#   'including',
#   'healthy',
#   'competition'],
#  ['technically',
#   'discriminate',
#   'age',
#   'either',
#   'constant',
#   'caffeine',
#   'induced',
#   'hyperactive',
#   'episode',
#   'naturally',
#   'one',
#   'people',
#   'hyper',
#   'day',
#   'everyday',
#   'utterly',
#   'miserable',
#   'performance',
#   'standard',
#   'require',
#   'much',
#   'speed',
#   'constant',
#   'frenzy',
#   'meet'],
#  ['repetitive', 'overtime', 'work', 'overtime', 'work', 'overtime', 'work'],
#  ['people',
#   'outside',
#   'u',
#   'increasingly',
#   'becoming',
#   'u',
#   'well',
#   'valley',
#   'centric',
#   'aside',
#   'regional',
#   'role',
#   'interesting',
#   'senior',
#   'role',
#   'based',
#   'beware',
#   'europe',
#   'elsewhere',
#   'globally',
#   'drain',
#   'people',
#   'moving',
#   'mean',
#   'career',
#   'also',
#   'politics',
#   'big',
#   'company',
#   'rife',
#   'silo',
#   'strong',
#   'finally',
#   'expect',
#   'much',
#   'life',
#   'outside',
#   'company'],
#  ['get',
#   'lost',
#   'organization',
#   'careful',
#   'product',
#   'seem',
#   'lack',
#   'focus'],
#  ['want',
#   'constantly',
#   'work',
#   'overtime',
#   'even',
#   'work',
#   'work',
#   'boring',
#   'pay',
#   'gove',
#   'enough',
#   'training',
#   'new',
#   'job',
#   'lot',
#   'favoritism',
#   'hard',
#   'advance',
#   'difficult',
#   'find',
#   'anything',
#   'everyone',
#   'different',
#   'answer question'],
#  ['management', 'instruction', 'really', 'confusing', 'sometime'],
#  ['nothing',
#   'everything',
#   'excellent',
#   'maybe',
#   'look',
#   'reduction',
#   'waste',
#   'avoid',
#   'excessive',
#   'usage',
#   'valuable',
#   'resource',
#   'water',
#   'electricity',
#   'beverage',
#   'tissue',
#   'etc',
#   'saved',
#   'reserved',
#   'future',
#   'generation'],
#  ['work',
#   'life balance',
#   'group',
#   'flat',
#   'organization',
#   'small',
#   'team',
#   'many',
#   'individual contributor',
#   'role',
#   'base',
#   'salary',
#   'low',
#   'much',
#   'compensation',
#   'tied',
#   'restricted',
#   'stock',
#   'unit'],
#  ['unreasonable',
#   'metric',
#   'expectation',
#   'crappy',
#   'discount',
#   'order',
#   'benefit',
#   'company',
#   'even',
#   'offer',
#   'free',
#   'prime',
#   'least',
#   'kindle',
#   'book',
#   'people',
#   'call',
#   'mean',
#   'hateful',
#   'tough',
#   'skin',
#   'needed',
#   'never',
#   'able',
#   'work',
#   'hour',
#   'stretch',
#   'draining',
#   'even',
#   'home',
#   'minute',
#   'call',
#   'wrap',
#   'long',
#   'email',
#   'need',
#   'send',
#   'followup',
#   'need',
#   'enough',
#   'time',
#   'also',
#   'bathroom',
#   'break',
#   'unless',
#   'put',
#   'customer',
#   'hold',
#   'unprofessional',
#   'company',
#   'cheap',
#   'feel',
#   'stifling',
#   'time',
#   'career',
#   'advancement',
#   'unless',
#   'want',
#   'customer',
#   'service',
#   'manager',
#   'something',
#   'really',
#   'want',
#   'work',
#   'company',
#   'like',
#   'amazon',
#   'recent',
#   'policy',
#   'change',
#   'favor',
#   'increased',
#   'security',
#   'made',
#   'harder',
#   'help',
#   'customer',
#   'new',
#   'policy',
#   'create',
#   'increased',
#   'work',
#   'csa',
#   'customer',
#   'sometimes',
#   'result',
#   'paradox',
#   'impossible',
#   'help',
#   'customer',
#   'problem',
#   'without',
#   'breaching',
#   'security',
#   'protocol',
#   'metric',
#   'based',
#   'able',
#   'help',
#   'customer',
#   'problem',
#   'problem',
#   'literally',
#   'solved',
#   'scammer',
#   'chronic',
#   'returners',
#   'missed',
#   'package',
#   'delivered',
#   'next',
#   'day',
#   'customer',
#   'want',
#   'personally',
#   'call',
#   'carrier',
#   'package',
#   'arrive',
#   'immediately',
#   'even',
#   'though',
#   'carrier',
#   'office',
#   'close',
#   'draining',
#   'work',
#   'make',
#   'dislike',
#   'humanity',
#   'time'],
#  ['many',
#   'hard',
#   'list',
#   'since',
#   'building',
#   'new',
#   'celebrated',
#   'year',
#   'free',
#   'cooky',
#   'essentially',
#   'people',
#   'experience',
#   'leadership',
#   'team',
#   'predominately',
#   'somethings',
#   'hired',
#   'right',
#   'college',
#   'distribution',
#   'management',
#   'matter',
#   'people',
#   'experience',
#   'add',
#   'large',
#   'amount',
#   'ethnicity',
#   'culture',
#   'difficult',
#   'environment',
#   'manage',
#   'even',
#   'seasoned',
#   'veteran',
#   'political',
#   'correctness',
#   'gone',
#   'far',
#   'one',
#   'address',
#   'issue',
#   'bathroom',
#   'cleanliness',
#   'terrible',
#   'coming',
#   'man',
#   'general',
#   'vibe',
#   'like',
#   'large',
#   'urban',
#   'high',
#   'school',
#   'new',
#   'teacher',
#   'mandatory overtime',
#   'constant',
#   'want',
#   'make',
#   'good',
#   'money',
#   'low',
#   'skill',
#   'job',
#   'might',
#   'place',
#   'life',
#   'outside',
#   'amazon',
#   'hard',
#   'physical',
#   'nature',
#   'work',
#   'constant',
#   'standing',
#   'demanding',
#   'especially',
#   'ship',
#   'dock',
#   'long',
#   'shift',
#   'wipe',
#   'management',
#   'seem',
#   'care',
#   'response',
#   'take',
#   'allocated',
#   'time'],
#  ['hard', 'work', 'breathing', 'room', 'heavily', 'analytics', 'based'],
#  ['many',
#   'incompentent',
#   'manager',
#   'lead',
#   'know',
#   'stimulate',
#   'people',
#   'serious',
#   'nepotism',
#   'office',
#   'politics',
#   'chance',
#   'reward',
#   'given',
#   'people',
#   'good',
#   'making',
#   'show',
#   'people',
#   'contribute',
#   'good',
#   'selling'],
#  ['politics',
#   'process',
#   'sometimes',
#   'many',
#   'hurdle',
#   'get',
#   'something',
#   'shipped'],
#  ['none', 'think'],
#  ['unrewarding',
#   'minimal',
#   'time',
#   'human resource',
#   'worthless',
#   'unprofessional',
#   'leadership',
#   'promotion',
#   'process',
#   'lack',
#   'industry standard'],
#  ['uninformed', 'public', 'opportunity', 'exhausting', 'challenge'],
#  ['leadership',
#   'work',
#   'life balance',
#   'manager',
#   'dont',
#   'always',
#   'listen',
#   'new',
#   'idea',
#   'associate'],
#  ['standing', 'one', 'spot', 'hour'],
#  ['monitoring', 'staff', 'poor'],
#  ['manager',
#   'young',
#   'immature',
#   'inexperienced',
#   'mood',
#   'swing',
#   'like',
#   'child',
#   'playground',
#   'ultimately',
#   'effect',
#   'work',
#   'flow',
#   'production',
#   'left',
#   'single',
#   'position',
#   'forever',
#   'encouragement',
#   'advance'],
#  ['wish',
#   'management',
#   'helpful',
#   'good',
#   'team',
#   'bad',
#   'team',
#   'helping',
#   'team',
#   'efficient'],
#  ['difficult', 'communicate', 'team', 'large', 'company'],
#  ['intentionally',
#   'keep',
#   'edge',
#   'job',
#   'loss',
#   'possibility',
#   'reality',
#   'pressure',
#   'intense'],
#  ['high',
#   'expectation',
#   'come',
#   'metric',
#   'change',
#   'team',
#   'manager',
#   'frequently',
#   'lose',
#   'office',
#   'feeling',
#   'since',
#   'interact',
#   'peer',
#   'remotely',
#   'mandatory',
#   'work',
#   'weekend'],
#  ['competitive', 'environment', 'cut throat', 'competition'],
#  ['biggest',
#   'downside',
#   'mandatory overtime',
#   'choice',
#   'high',
#   'backlog',
#   'forced',
#   'come',
#   'work',
#   'shift',
#   'well',
#   'end',
#   'many',
#   'people',
#   'people',
#   'end',
#   'sweeping',
#   'floor',
#   'direct',
#   'function',
#   'available',
#   'thing',
#   'make',
#   'overtime',
#   'bearable',
#   'money'],
#  ['able',
#   'choose',
#   'way',
#   'impact',
#   'facebook',
#   'mission',
#   'liberating',
#   'also',
#   'imposes',
#   'lot',
#   'pressure',
#   'every single',
#   'individual',
#   'prove',
#   'every',
#   'half',
#   'worth',
#   'investment',
#   'facebook',
#   'make',
#   'people',
#   'london',
#   'office',
#   'certainly',
#   'smaller',
#   'selection',
#   'team',
#   'california',
#   'knowing',
#   'would',
#   'make',
#   'significantly',
#   'money',
#   'across',
#   'pond',
#   'also',
#   'awkward'],
#  ['another',
#   'sale',
#   'job',
#   'enough',
#   'new',
#   'opportunity',
#   'presented',
#   'management',
#   'sometimes',
#   'busy',
#   'could',
#   'found',
#   'needed'],
#  ['contractor',
#   'rarely',
#   'converted',
#   'permanent',
#   'employee',
#   'upper',
#   'management',
#   'supportive',
#   'team',
#   'obvious',
#   'favoritism'],
#  ['hard',
#   'drive',
#   'meaningful',
#   'impact',
#   'especially',
#   'pop',
#   'excessive',
#   'weight',
#   'placed',
#   'academic',
#   'credential',
#   'personnel',
#   'decision',
#   'training',
#   'people',
#   'manager',
#   'lacking'],
#  ['almost',
#   'always',
#   'follower',
#   'market',
#   'slow',
#   'move',
#   'management',
#   'incentivized',
#   'make',
#   'thing',
#   'work',
#   'well',
#   'across',
#   'whole',
#   'product',
#   'portfolio',
#   'stock',
#   'good',
#   'dividend',
#   'maddening',
#   'bureaucracy',
#   'abound'],
#  ['con', 'great', 'place', 'work'],
#  ['amazon',
#   'work',
#   'hard',
#   'extremely',
#   'long',
#   'hour',
#   'yes',
#   'honestly',
#   'value',
#   'experience',
#   'feel',
#   'like',
#   'much',
#   'stronger',
#   'smarter',
#   'person',
#   'time',
#   'amazon',
#   'really',
#   'become',
#   'small',
#   'fish',
#   'big',
#   'ocean',
#   'biggest',
#   'two',
#   'issue',
#   'hr',
#   'work',
#   'week',
#   'say',
#   'become',
#   'le',
#   'never',
#   'manager',
#   'develops',
#   'certain',
#   'people',
#   'team',
#   'get',
#   'angry',
#   'thing',
#   'go',
#   'right',
#   'also',
#   'fact',
#   'management',
#   'change',
#   'leader',
#   'every',
#   'month',
#   'build',
#   'relationship',
#   'manager',
#   'gain',
#   'support',
#   'always',
#   'changing',
#   'role',
#   'moving',
#   'facility',
#   'mind',
#   'hour',
#   'work',
#   'week',
#   'around',
#   'really',
#   'competitive',
#   'people',
#   'ruthless',
#   'go',
#   'right',
#   'ahead',
#   'college',
#   'student',
#   'trying',
#   'decide',
#   'area',
#   'manager',
#   'strongly',
#   'consider',
#   'want',
#   'spend',
#   'young',
#   'year',
#   'working',
#   'company',
#   'take',
#   'take',
#   'take',
#   'want',
#   'work',
#   'company',
#   'customer',
#   'obsessed',
#   'also',
#   'employee',
#   'obsessed',
#   'promise',
#   'benefit',
#   'morale',
#   'company',
#   'become',
#   'much',
#   'important',
#   'would',
#   'think',
#   'young',
#   'professional',
#   'right',
#   'college',
#   'really',
#   'consider',
#   'decision',
#   'make',
#   'sure',
#   'area',
#   'manager',
#   'want',
#   'lot',
#   'potential',
#   'growth',
#   'company',
#   'ruthless',
#   'really',
#   'intelligent',
#   'get',
#   'go',
#   'know',
#   'company',
#   'work',
#   'hard',
#   'understand',
#   'life',
#   'outside',
#   'work'],
#  ['think', 'con', 'unless', 'lied', 'wan na'],
#  ['cafeteria',
#   'food',
#   'good',
#   'outdoor',
#   'game',
#   'place',
#   'wont',
#   'get',
#   'much',
#   'time',
#   'enjoy',
#   'facility'],
#  ['chance',
#   'grow',
#   'within',
#   'company',
#   'thought',
#   'moving',
#   'first',
#   'ambassador',
#   'moved',
#   'become',
#   'full',
#   'time',
#   'process',
#   'assistant',
#   'almost',
#   'full',
#   'year',
#   'demoted',
#   'back',
#   'tier',
#   'associate',
#   'many',
#   'people',
#   'work',
#   'easily',
#   'replaced'],
#  ['forced',
#   'curve',
#   'review',
#   'model',
#   'cause',
#   'great',
#   'team',
#   'give',
#   'bad',
#   'review',
#   'good',
#   'employee',
#   'someone',
#   'could',
#   'year',
#   'average',
#   'review',
#   'get',
#   'caught',
#   'curve',
#   'bad',
#   'manager',
#   'forced',
#   'leave',
#   'company',
#   'stigma',
#   'difficulty',
#   'work',
#   'way',
#   'bad',
#   'review',
#   'many',
#   'senior',
#   'leader',
#   'oblivious',
#   'waste',
#   'bad',
#   'decision',
#   'leader',
#   'small',
#   'efficient',
#   'team',
#   'usually',
#   'taken',
#   'empire',
#   'builder',
#   'cause',
#   'waste',
#   'people',
#   'told',
#   'resource',
#   'company',
#   'however',
#   'decision',
#   'made',
#   'effect',
#   'employment',
#   'individual',
#   'done',
#   'without',
#   'discussion',
#   'people',
#   'involved',
#   'many',
#   'decision',
#   'made',
#   'management',
#   'data driven'],
#  ['work',
#   'life balance',
#   'missing',
#   'else',
#   'really',
#   'good',
#   'place',
#   'work',
#   'stress'],
#  ['given', 'opportunity', 'advance'],
#  ['easy', 'become', 'burned', 'much', 'stimulate', 'professionally'],
#  ['pay',
#   'lower',
#   'site',
#   'customer',
#   'service',
#   'guaranteed',
#   'employment',
#   'year',
#   'time',
#   'college',
#   'may',
#   'may',
#   'offer',
#   'another',
#   'year',
#   'job',
#   'college',
#   'depending',
#   'performance'],
#  ['much',
#   'focus',
#   'confidentiality',
#   'severe',
#   'repercussion',
#   'effecting',
#   'lack',
#   'consistency',
#   'role',
#   'expected',
#   'often',
#   'much',
#   'ambiguity',
#   'often',
#   'managing',
#   'expectation',
#   'needy',
#   'customer'],
#  ['apple',
#   'working',
#   'enhanced',
#   'compensation',
#   'employee',
#   'something',
#   'much',
#   'needed',
#   'prominent',
#   'con',
#   'extent',
#   'employee',
#   'benefit'],
#  ['working',
#   'department',
#   'e g',
#   'window',
#   'office',
#   'exchange',
#   'etc',
#   'absolute',
#   'nightmare',
#   'cross',
#   'department',
#   'coordination',
#   'engineering',
#   'meeting',
#   'tend',
#   'end',
#   'rage',
#   'tear',
#   'near',
#   'bloodshed',
#   'bench',
#   'hipo',
#   'lab',
#   'status',
#   'way',
#   'compensation',
#   'truly',
#   'competitive',
#   'top',
#   'tier',
#   'company',
#   'like',
#   'google',
#   'facebook'],
#  ['company',
#   'b',
#   'revenue',
#   'system',
#   'process',
#   'extremely',
#   'sub par',
#   'translates',
#   'lot',
#   'work',
#   'people',
#   'handled',
#   'software',
#   'cronyism',
#   'rampant',
#   'political',
#   'backstabbing',
#   'positioning',
#   'fact',
#   'everyday',
#   'life',
#   'greediness',
#   'permeates',
#   'poison',
#   'already',
#   'ugly',
#   'culture',
#   'employee',
#   'encouraged',
#   'expected',
#   'believe',
#   'amazon',
#   'much',
#   'era',
#   'sears',
#   'roebuck',
#   'human',
#   'component',
#   'management',
#   'lost',
#   'people',
#   'management',
#   'skill',
#   'developed',
#   'like',
#   'company',
#   'worked',
#   'resulting',
#   'lot',
#   'lot',
#   'people',
#   'manager',
#   'even',
#   'charge',
#   'deciding',
#   'dinner',
#   'decision making',
#   'centralized',
#   'team',
#   'senior',
#   'leadership',
#   'team',
#   'meet',
#   'bezos',
#   'mean',
#   'getting',
#   'approval',
#   'delegated',
#   'manager',
#   'place',
#   'worked',
#   'simple',
#   'thing',
#   'take',
#   'way',
#   'long',
#   'impairs',
#   'business',
#   'creates',
#   'apathy',
#   'among',
#   'employee'],
#  ['lack', 'people', 'skill', 'management'],
#  ['always',
#   'foot',
#   'never',
#   'slow',
#   'time',
#   'customer',
#   'always',
#   'hurry',
#   'get',
#   'crowded',
#   'store'],
#  ['high turnover',
#   'rate',
#   'wait',
#   'year',
#   'stock vest',
#   'hr',
#   'seems',
#   'trigger',
#   'happy',
#   'fire',
#   'associate',
#   'looking',
#   'help'],
#  ['people',
#   'play',
#   'hide',
#   'seek',
#   'hide',
#   'avoid',
#   'work',
#   'seek',
#   'new',
#   'team',
#   'current',
#   'one',
#   'find'],
#  ['salary',
#   'little',
#   'people',
#   'work',
#   'technical',
#   'side',
#   'e g',
#   'sde',
#   'qaes',
#   'sdm',
#   'getting',
#   'paid',
#   'well'],
#  ['politics',
#   'politics',
#   'politics',
#   'easily',
#   'get',
#   'stabbed',
#   'someone',
#   'big',
#   'friendly',
#   'smile',
#   'lack',
#   'promotion',
#   'opportunity',
#   'like',
#   'hiring',
#   'senior',
#   'people',
#   'outside',
#   'unbalanced',
#   'power',
#   'pm',
#   'dev',
#   'tends',
#   'much',
#   'louder',
#   'voice',
#   'shipping',
#   'painfully',
#   'slow',
#   'even',
#   'best',
#   'idea',
#   'time',
#   'wash',
#   'away',
#   'get',
#   'pay',
#   'much',
#   'company',
#   'pay',
#   'rise',
#   'barely',
#   'matching',
#   'inflation'],
#  ['frustrating', 'corporate', 'culture', 'lot', 'red tape'],
#  ['working', 'hour', 'le', 'break', 'time', 'bad', 'food'],
#  ['still',
#   'lingering',
#   'culture',
#   'complacency',
#   'actually',
#   'good',
#   'want',
#   'stable',
#   'job',
#   'support',
#   'family',
#   'want',
#   'really',
#   'make',
#   'big',
#   'impact',
#   'work',
#   'wait',
#   'year',
#   'feature',
#   'get',
#   'shipped'],
#  ['company',
#   'going',
#   'lot',
#   'change',
#   'retail',
#   'level',
#   'manager',
#   'know',
#   'handle',
#   'said',
#   'change',
#   'making',
#   'process',
#   'bringing',
#   'moral',
#   'employee',
#   'different',
#   'team',
#   'making',
#   'feel',
#   'unappreciated',
#   'undervalued',
#   'case',
#   'obvious',
#   'favorite',
#   'employee',
#   'promoting',
#   'without',
#   'allowing',
#   'experienced',
#   'co worker',
#   'interview'],
#  ['even',
#   'though',
#   'job',
#   'fairly',
#   'easy',
#   'requires',
#   'physicality',
#   'stand',
#   'hour',
#   'course',
#   'break',
#   'hour',
#   'work',
#   'first',
#   'break',
#   'minute',
#   'break',
#   'hour',
#   'lunch',
#   'time',
#   'minute',
#   'later',
#   'minute',
#   'break',
#   'given',
#   'well',
#   'downside',
#   'fulfillment center',
#   'enormous',
#   'minute',
#   'take',
#   'around',
#   'minute',
#   'running',
#   'fast',
#   'walking',
#   'get',
#   'canteen',
#   'locker',
#   'keep',
#   'personal',
#   'belonging',
#   'like',
#   'food',
#   'phone',
#   'wallet',
#   'taking',
#   'account',
#   'also',
#   'need',
#   'go',
#   'back',
#   'got',
#   'minute',
#   'take',
#   'bite',
#   'food',
#   'text',
#   'friend',
#   'family',
#   'sit',
#   'relax',
#   'another',
#   'thing',
#   'bother',
#   'known',
#   'colleague',
#   'music',
#   'bring',
#   'phone',
#   'earphone',
#   'speaker',
#   'time',
#   'go',
#   'really',
#   'slow',
#   'warehouse'],
#  ['many', 'team', 'uninteresting', 'project', 'impact', 'limited'],
#  ['corporate',
#   'secrecy',
#   'get',
#   'way',
#   'business',
#   'enough',
#   'communication',
#   'department',
#   'outside',
#   'retail'],
#  ['company',
#   'hire',
#   'worker',
#   'mass',
#   'quantity',
#   'earn',
#   'tax',
#   'credit',
#   'veteran',
#   'long',
#   'term',
#   'unemployed',
#   'person',
#   'government',
#   'assistance',
#   'telling',
#   'worker',
#   'work',
#   'month',
#   'year',
#   'possibility',
#   'permanent',
#   'position',
#   'laid',
#   'u',
#   'day',
#   'probation',
#   'period',
#   'law',
#   'telling',
#   'u',
#   'come',
#   'back',
#   'day',
#   'devestated',
#   'lost',
#   'government',
#   'benefit',
#   'taking',
#   'month',
#   'reregister',
#   'approval',
#   'found',
#   'amazon',
#   'profiting',
#   'tax',
#   'incentive',
#   'give',
#   'every',
#   'disabled',
#   'person',
#   'veteran',
#   'long',
#   'term',
#   'unemployed',
#   'person',
#   'govern',
#   'aid',
#   'hire',
#   'limit',
#   'explains',
#   'mass',
#   'hiring',
#   'lay offs',
#   'rehire',
#   'hiring',
#   'hiring',
#   'laying',
#   'rehiring',
#   'amazon',
#   'generates',
#   'steady',
#   'stream',
#   'government',
#   'incentive',
#   'problem',
#   'u',
#   'vulnerable',
#   'people',
#   'supposed',
#   'assisted',
#   'incentive',
#   'company',
#   'actually',
#   'taken',
#   'advantage',
#   'dream',
#   'getting',
#   'good',
#   'job',
#   'crushed',
#   'left',
#   'jobless',
#   'depressed',
#   'wishing',
#   'never',
#   'taken',
#   'job',
#   'could',
#   'continuing',
#   'look',
#   'work',
#   'instead',
#   'wasting',
#   'time',
#   'generating',
#   'income',
#   'man',
#   'worth',
#   'billion dollar',
#   'bezos'],
#  ['many', 'reorgs', 'cost', 'customer', 'satisfaction'],
#  ['expectation',
#   'delivering',
#   'phenomenal',
#   'experience',
#   'providing',
#   'le',
#   'le',
#   'time',
#   'work',
#   'customer',
#   'pay',
#   'gotten',
#   'lower',
#   'lower',
#   'apple',
#   'growth',
#   'increased',
#   'past',
#   'year'],
#  ['short break'],
#  ['le', 'scope', 'growth', 'lateral', 'movement'],
#  ['work',
#   'life balance',
#   'almost',
#   'non existent',
#   'feel',
#   'organisation',
#   'purely',
#   'scorecard',
#   'driven',
#   'nothing',
#   'else',
#   'matter',
#   'apart',
#   'metric'],
#  ['hard',
#   'stay',
#   'employed',
#   'strict',
#   'number',
#   'quality',
#   'working',
#   'fast',
#   'making',
#   'mistake',
#   'go',
#   'hand',
#   'hand',
#   'make',
#   'especially',
#   'hard',
#   'meet',
#   'quota',
#   'set',
#   'everyone',
#   'people',
#   'get',
#   'written',
#   'constantly',
#   'meeting',
#   'quota',
#   'third',
#   'write',
#   'let',
#   'go',
#   'thing',
#   'prevent',
#   'meeting',
#   'quota',
#   'sometimes',
#   'controlled',
#   'like',
#   'computer',
#   'problem',
#   'manager',
#   'might',
#   'still',
#   'write'],
#  ['extremely',
#   'high',
#   'expectation',
#   'frequent',
#   'change',
#   'isolating',
#   'difficult',
#   'manage'],
#  ['work',
#   'schedule',
#   'change',
#   'weekly',
#   'inhibiting',
#   'even',
#   'average',
#   'work',
#   'life balance'],
#  ['bad', 'service', 'payment'],
#  ['like',
#   'team',
#   'manager',
#   'heard',
#   'story',
#   'team',
#   'micromanaging',
#   'expectation',
#   'putting',
#   'long',
#   'hour',
#   'slave',
#   'driving'],
#  ['screw'],
#  ['work', 'life balance', 'vendor', 'suck', 'static', 'career', 'development'],
#  ['pick',
#   'wrong',
#   'product',
#   'team',
#   'compete',
#   'marketplace',
#   'screwed',
#   'multiple',
#   'orgs',
#   'co worker',
#   'fighting',
#   'survival',
#   'make',
#   'believe',
#   'busy',
#   'work',
#   'politics',
#   'frustration',
#   'lack',
#   'business',
#   'progress'],
#  ['cut throat', 'competition', 'development', 'opportunity', 'better'],
#  ['start', 'seasonal', 'benefit', 'unless', 'hired', 'seasonal'],
#  ['mass',
#   'hire',
#   'super',
#   'high',
#   'turn',
#   'work',
#   'employee',
#   'bone',
#   'stupid',
#   'competition',
#   'bag',
#   'skittle',
#   'stuff',
#   'return',
#   'get',
#   'employee',
#   'working',
#   'bag'],
#  ['average',
#   'salary',
#   'growing',
#   'per',
#   'company',
#   'growth',
#   'year',
#   'people',
#   'feel',
#   'demoted',
#   'due',
#   'weird',
#   'salary',
#   'packaging',
#   'model'],
#  ['much', 'politics', 'fighting', 'org', 'peek', 'senior', 'level'],
#  ['work', 'home', 'opportunity'],
#  ['work',
#   'life balance',
#   'consideration',
#   'management',
#   'either',
#   'put',
#   'limit',
#   'squeezed',
#   'free',
#   'useful',
#   'training',
#   'service',
#   'performance evaluation',
#   'impartial',
#   'unfair',
#   'bonus',
#   'extra',
#   'effort',
#   'put'],
#  ['told',
#   'would',
#   'occassional',
#   'night',
#   'occasional',
#   'weekend',
#   'trip',
#   'seattle',
#   'paid',
#   'every',
#   'year',
#   'trip',
#   'seattle',
#   'am',
#   'sunday',
#   'wednesday',
#   'night',
#   'shift',
#   'hour',
#   'day',
#   'sometimes',
#   'make',
#   'salary',
#   'divide',
#   'hourly wage',
#   'le',
#   'associate',
#   'peak',
#   'feel',
#   'taken',
#   'advantage',
#   'mom',
#   'got',
#   'sick',
#   'move',
#   'back',
#   'home',
#   'unable',
#   'transfer',
#   'told',
#   'would',
#   'forgive',
#   'starting',
#   'bonus',
#   'relocation',
#   'payback',
#   'almost',
#   'year',
#   'working',
#   'get',
#   'call',
#   'want',
#   'almost',
#   'back',
#   'take',
#   'legal',
#   'action',
#   'month',
#   'later',
#   'force',
#   'pay',
#   'back',
#   'company',
#   'care',
#   'people',
#   'expects',
#   'enforce',
#   'dumb',
#   'rule',
#   'person',
#   'team',
#   'become',
#   'like',
#   'robot',
#   'ridiculous',
#   'hour',
#   'working',
#   'holiday',
#   'starting',
#   'bonus',
#   'relocation',
#   'repaid',
#   'leave',
#   'year',
#   'almost',
#   'one',
#   'make',
#   'lost',
#   'manager',
#   'month',
#   'building'],
#  ['delicious', 'food', 'result', 'gaining', 'weight'],
#  ['much', 'scope', 'growth', 'testing'],
#  ['probably',
#   'ever',
#   'much',
#   'development',
#   'slc',
#   'c',
#   'site',
#   'take',
#   'job',
#   'would',
#   'plan',
#   'short term',
#   'get',
#   'burnt',
#   'senior',
#   'leadership',
#   'political',
#   'slc',
#   'site',
#   'claim',
#   'try',
#   'stick',
#   'close',
#   'corporate',
#   'culture',
#   'possible',
#   'regretfully',
#   'true',
#   'say',
#   'push',
#   'transparent',
#   'feedback',
#   'ultimately',
#   'feedback',
#   'used',
#   'weapon',
#   'get',
#   'rid',
#   'people',
#   'jiving',
#   'select',
#   'senior',
#   'leader',
#   'looking',
#   'work',
#   'stability',
#   'probably',
#   'place'],
#  ['want', 'busy', 'life', 'might', 'good', 'place'],
#  ['tough',
#   'condition',
#   'difficult',
#   'target',
#   'pressured',
#   'overview',
#   'try',
#   'force',
#   'overtime',
#   'ridiculously',
#   'short break'],
#  ['internal',
#   'customer',
#   'matter',
#   'growth',
#   'advancement',
#   'opportunity',
#   'us',
#   'employment',
#   'threat',
#   'risk',
#   'employee',
#   'one',
#   'lead',
#   'manage',
#   'without',
#   'influence'],
#  ['shift',
#   'work',
#   'sometimes',
#   'feel',
#   'like',
#   'number',
#   'correcting',
#   'lot',
#   'mistake',
#   'made',
#   'outsourced',
#   'support',
#   'manilla',
#   'india'],
#  ['downside', 'fulfillment', 'associate', 'get', 'put', 'job'],
#  ['lot', 'con', 'mention', 'relocate', 'position'],
#  ['fraction',
#   'large',
#   'number',
#   'production',
#   'report',
#   'wonder',
#   'manager',
#   'even',
#   'know',
#   'first',
#   'name',
#   'working',
#   'week'],
#  ['company', 'located', 'end', 'f', 'block', 'sec', 'noida'],
#  ['burn', 'employee', 'employee', 'perk', 'career', 'development'],
#  ['sometimes', 'wait', 'decision', 'since', 'big', 'company'],
#  ['part',
#   'time',
#   'hour',
#   'always',
#   'consistent',
#   'especially',
#   'slow',
#   'time',
#   'like',
#   'talking',
#   'people',
#   'job',
#   'able',
#   'build',
#   'rapport'],
#  ['let',
#   'microsoft',
#   'brand name',
#   'give',
#   'illusion',
#   'great',
#   'place',
#   'work',
#   'people',
#   'type',
#   'steroid',
#   'highly',
#   'competitive',
#   'point',
#   'want',
#   'bring',
#   'stab',
#   'back',
#   'employee',
#   'especially',
#   'target',
#   'new',
#   'hire',
#   'want',
#   'new',
#   'people',
#   'joining',
#   'club',
#   'many',
#   'clique',
#   'passive aggressive',
#   'back',
#   'stabber',
#   'catch',
#   'guard',
#   'toxic',
#   'environment',
#   'driven',
#   'robotic',
#   'manager',
#   'system',
#   'reward',
#   'individual',
#   'detriment',
#   'team',
#   'overall',
#   'subsidiary',
#   'canadian',
#   'leadership',
#   'team',
#   'revolving door',
#   'mostly',
#   'person',
#   'career',
#   'hopping',
#   'u',
#   'really',
#   'care',
#   'canadian',
#   'employee',
#   'feel',
#   'heart',
#   'attack',
#   'soon',
#   'stay',
#   'much',
#   'longer',
#   'known',
#   'toxic',
#   'environment',
#   'would',
#   'never',
#   'worked',
#   'planning',
#   'leave',
#   'soon',
#   'sake',
#   'mental health',
#   'physical',
#   'well',
#   'thing',
#   'matter',
#   'work',
#   'employee',
#   'life',
#   'meeting',
#   'scheduled',
#   'regular basis',
#   'saturday sunday',
#   'top',
#   'working',
#   'midnight',
#   'week',
#   'done',
#   'best',
#   'committed',
#   'role',
#   'organization',
#   'point',
#   'price',
#   'high',
#   'pay',
#   'stay'],
#  ['recent',
#   'large',
#   'scale',
#   'hiring',
#   'brought',
#   'mediocre',
#   'engineer',
#   'company',
#   'bad',
#   'onboarding',
#   'experience',
#   'amazon',
#   'relies',
#   'team',
#   'onboard',
#   'team',
#   'plan',
#   'get',
#   'trouble',
#   'see',
#   'top notch',
#   'developer',
#   'may',
#   'struggle',
#   'job',
#   'people',
#   'high',
#   'expectation',
#   'one',
#   'gon na',
#   'tell',
#   'good',
#   'job',
#   'free',
#   'lunch'],
#  ['keeping',
#   'pace',
#   'sometimes',
#   'hard',
#   'keeping',
#   'overview',
#   'thing',
#   'happen',
#   'love',
#   'internal',
#   'group',
#   'responsive',
#   'people',
#   'help',
#   'least',
#   'help',
#   'speed',
#   'thing',
#   'matter',
#   'job'],
#  ['performance',
#   'review',
#   'system',
#   'nightmare',
#   'bane',
#   'every',
#   'employee',
#   'nobody',
#   'really',
#   'impression',
#   'ballmer',
#   'immediate',
#   'report',
#   'real',
#   'strategy',
#   'internal',
#   'politics',
#   'different',
#   'among',
#   'various',
#   'division',
#   'bad',
#   'would',
#   'recommend',
#   'avoiding',
#   'work',
#   'online',
#   'service',
#   'division',
#   'cost'],
#  ['long',
#   'hour',
#   'manager',
#   'play',
#   'favourite',
#   'employee',
#   'favourite',
#   'get',
#   'much',
#   'support',
#   'last',
#   'long',
#   'manager',
#   'also',
#   'dish',
#   'ton',
#   'criticism',
#   'even',
#   'true',
#   'yet',
#   'little',
#   'actively',
#   'help',
#   'employee',
#   'improve',
#   'performance',
#   'employee',
#   'happily',
#   'throw bus',
#   'steal',
#   'sale',
#   'training',
#   'poor',
#   'store',
#   'joke',
#   'higher',
#   'get',
#   'le'],
#  ['challenge', 'great', 'tiring', 'feel', 'recognized', 'satisfied', 'impact'],
#  ['struggle', 'analytics', 'likely', 'struggle', 'amazon'],
#  ['advancement',
#   'opportunity',
#   'call',
#   'tedious',
#   'schedule',
#   'picked',
#   'company',
#   'summer',
#   'winter'],
#  ['salary',
#   'growth',
#   'somewhat',
#   'linear',
#   'axis',
#   'start',
#   'weight',
#   'young',
#   'company',
#   'easy',
#   'performance',
#   'clump',
#   'together',
#   'expectation',
#   'rating',
#   'really',
#   'make',
#   'difficult',
#   'stand'],
#  ['people', 'mean', 'sometimes'],
#  ['get',
#   'old',
#   'hard',
#   'one',
#   'stay',
#   'still',
#   'standing',
#   'one',
#   'spot',
#   'whole',
#   'day',
#   'get',
#   'tiring',
#   'people',
#   'like',
#   'move',
#   'around'],
#  ['commute',
#   'parking',
#   'situation',
#   'outside',
#   'job',
#   'phenomenal',
#   'amazing',
#   'company',
#   'grow'],
#  ['people',
#   'say',
#   'facebook',
#   'le',
#   'politics',
#   'feel',
#   'usually',
#   'come',
#   'group',
#   'people',
#   'joining',
#   'team',
#   'company',
#   'around',
#   'time',
#   'culture',
#   'encourages',
#   'transparency',
#   'smooth',
#   'talker',
#   'avoid',
#   'giving',
#   'harsh',
#   'feedback',
#   'could',
#   'become',
#   'problem',
#   'review'],
#  ['night', 'shift', 'con'],
#  ['pay',
#   'working',
#   'freezer',
#   'keep',
#   'good',
#   'manager',
#   'give',
#   'raise',
#   'many',
#   'worked',
#   'yr',
#   'without',
#   'raise',
#   'loyal',
#   'hard',
#   'working',
#   'amazon',
#   'make',
#   'way',
#   'much',
#   'money',
#   'treat',
#   'employee',
#   'like'],
#  ['never',
#   'grow',
#   'college',
#   'salary',
#   'bracket',
#   'hired',
#   'college',
#   'get',
#   'actual',
#   'competitive',
#   'pay',
#   'quit',
#   'come',
#   'back',
#   'sometimes',
#   'manager',
#   'intense',
#   'forget',
#   'internal',
#   'customer',
#   'aka',
#   'direct report'],
#  ['great',
#   'respect',
#   'satya',
#   'culture',
#   'shift',
#   'initiated',
#   'unfortunately',
#   'mediocrity',
#   'seems',
#   'settled',
#   'middle',
#   'manager',
#   'level',
#   'least',
#   'area',
#   'company',
#   'bad',
#   'technology',
#   'strategy',
#   'decision',
#   'made',
#   'name',
#   'preserving',
#   'fiefdom',
#   'charter',
#   'political',
#   'fighting',
#   'territory',
#   'lead',
#   'stealing',
#   'credit',
#   'minion',
#   'work',
#   'blaming',
#   'others',
#   'failure',
#   'responsibility',
#   'usually',
#   'behind',
#   'back',
#   'lack',
#   'leadership',
#   'zero',
#   'integrity',
#   'lead',
#   'development',
#   'manager',
#   'level',
#   'perhaps',
#   'one',
#   'really',
#   'dysfunctional',
#   'team',
#   'amongst',
#   'many',
#   'year',
#   'software',
#   'professional',
#   'literally',
#   'worst',
#   'experience',
#   'horrid',
#   'disconnected',
#   'power',
#   'hungry',
#   'leadership',
#   'use',
#   'term',
#   'loosely',
#   'ever',
#   'seen'],
#  ['mba',
#   'parasitic',
#   'leach',
#   'crushing',
#   'culture',
#   'long',
#   'term',
#   'vision'],
#  ['lack', 'agility', 'product', 'development', 'process'],
#  ['long', 'term', 'employee', 'set', 'way', 'thing', 'past'],
#  ['culture',
#   'amazon',
#   'abhorrent',
#   'everything',
#   'service',
#   'bottom line',
#   'frugality',
#   'literally',
#   'one',
#   'core',
#   'tenant',
#   'company',
#   'used',
#   'justify',
#   'everything',
#   'fact',
#   'provide',
#   'doctor note',
#   'get',
#   'ergonomic',
#   'desk',
#   'fact',
#   'benefit',
#   'holiday',
#   'extremely',
#   'weak',
#   'latest',
#   'fiasco',
#   'amazon',
#   'actually',
#   'violating',
#   'osha',
#   'requirement',
#   'number',
#   'available',
#   'bathroom',
#   'office',
#   'space',
#   'insanely',
#   'overpopulated',
#   'inquiry',
#   'matter',
#   'ignored',
#   'amazon',
#   'even',
#   'pretend',
#   'care',
#   'employee',
#   'company',
#   'chew',
#   'spit',
#   'replaced',
#   'next',
#   'college graduate',
#   'go',
#   'wringer',
#   'essentially',
#   'everyone',
#   'company',
#   'oncall',
#   'rotation',
#   'prepared',
#   'oncall',
#   'even',
#   'oncall',
#   'become',
#   'one',
#   'senior',
#   'member',
#   'team',
#   'due',
#   'amazon',
#   'legendary',
#   'attrition',
#   'rate',
#   'amazon',
#   'decent',
#   'place',
#   'develop',
#   'skill',
#   'almost',
#   'every',
#   'group',
#   'fast',
#   'track',
#   'burned',
#   'run',
#   'ragged',
#   'management'],
#  ['like',
#   'many',
#   'large',
#   'company',
#   'difficult',
#   'get',
#   'thing',
#   'done',
#   'quickly',
#   'everyone',
#   'subscribed',
#   'customer',
#   'obsessed',
#   'mentality',
#   'yet'],
#  ['culture',
#   'secrecy',
#   'great',
#   'realize',
#   'nobody',
#   'amazon',
#   'ever',
#   'care',
#   'anything',
#   'order',
#   'horrible',
#   'need',
#   'deal',
#   'organization',
#   'within',
#   'company',
#   'even',
#   'product',
#   'unit',
#   'advancing',
#   'qae',
#   'qae',
#   'difficult',
#   'advancing',
#   'qae',
#   'principal',
#   'qae',
#   'forget'],
#  ['poor', 'wage', 'staff', 'hirable', 'street'],
#  ['culture',
#   'everyone',
#   'realize',
#   'culture',
#   'fit',
#   'value',
#   'best',
#   'everyone',
#   'determine',
#   'early'],
#  ['management',
#   'terrible',
#   'listen',
#   'suggestion',
#   'obvious',
#   'know',
#   'idea',
#   'micro manage',
#   'everything',
#   'turn',
#   'making',
#   'worker',
#   'nervous'],
#  ['demanding', 'low', 'salary', 'regular', 'training', 'improve', 'outlook'],
#  ['work',
#   'wear',
#   'body',
#   'fast',
#   'good',
#   'medical',
#   'tjrn',
#   'ratw',
#   'super',
#   'high',
#   'pacify',
#   'comany',
#   'picnic',
#   'year',
#   'eealy',
#   'sont',
#   'care',
#   'u',
#   'really',
#   'look',
#   'whats',
#   'going',
#   'inside',
#   'nothing',
#   'modern',
#   'day',
#   'plantation',
#   'shape',
#   'building',
#   'high',
#   'risk',
#   'pregnancy',
#   'lost',
#   'tenure',
#   'even',
#   'though',
#   'year',
#   'going',
#   'treat',
#   'like',
#   'week',
#   'took',
#   'position',
#   'reason',
#   'still',
#   'work',
#   'search',
#   'new',
#   'job'],
#  ['need', 'par', 'term', 'payroll'],
#  ['depending',
#   'market',
#   'manager',
#   'disposition',
#   'hit',
#   'sale',
#   'appointment',
#   'goal',
#   'could',
#   'asked',
#   'work',
#   'hour',
#   'day',
#   'come',
#   'back',
#   'bright',
#   'early',
#   'next',
#   'morning',
#   'work',
#   'retail',
#   'chance',
#   'getting',
#   'corporate',
#   'working',
#   'part',
#   'time',
#   'mean',
#   'working',
#   'hour',
#   'yeah',
#   'math'],
#  ['inflexible', 'scheduling', 'work', 'around'],
#  ['since',
#   'get',
#   'near',
#   'total',
#   'autonomy',
#   'figuring',
#   'challenging',
#   'consider',
#   'option',
#   'carefully',
#   'also',
#   'easy',
#   'get',
#   'bit',
#   'imposter',
#   'syndrome',
#   'since',
#   'working',
#   'top',
#   'name',
#   'industry'],
#  ['little', 'work', 'life balance'],
#  ['focus',
#   'becomes',
#   'narrow',
#   'get',
#   'insulated',
#   'world',
#   'thereby',
#   'become',
#   'obsolete',
#   'real',
#   'world',
#   'much',
#   'politics',
#   'microsoft',
#   'get',
#   'work',
#   'people',
#   'people',
#   'coal',
#   'mine',
#   'suck',
#   'life',
#   'get',
#   'jerk',
#   'lead',
#   'stuck',
#   'end',
#   'career',
#   'microsoft'],
#  ['company', 'used', 'filled', 'smartest', 'people', 'world', 'much'],
#  ['soul',
#   'gone',
#   'coconut',
#   'oil',
#   'smelling',
#   'hold',
#   'core',
#   'tried',
#   'resisting',
#   'slippery'],
#  ['serious', 'quality', 'productivity', 'working', 'alway', 'worry', 'rate'],
#  ['many', 'horrible', 'manager', 'focused', 'politics', 'self'],
#  ['con',
#   'microsoft',
#   'politics',
#   'top',
#   'heavy',
#   'company',
#   'bureaucracy',
#   'review',
#   'system',
#   'unfair'],
#  ['hard', 'go', 'higher', 'sometimes', 'poor', 'leadership'],
#  ['big', 'tough', 'feel', 'like', 'make', 'material', 'contribution'],
#  ['generally',
#   'security',
#   'officer',
#   'first',
#   'people',
#   'visitor',
#   'employee',
#   'come',
#   'contact',
#   'organization',
#   'serve',
#   'protect',
#   'organization',
#   'help',
#   'need',
#   'assistance',
#   'since',
#   'security',
#   'officer',
#   'often',
#   'first',
#   'contact',
#   'also',
#   'serve',
#   'provide',
#   'first',
#   'impression',
#   'security',
#   'department',
#   'organization',
#   'whole'],
#  ['political',
#   'power',
#   'issue',
#   'promotion',
#   'confusion',
#   'lack',
#   'real',
#   'genuine',
#   'caring',
#   'support',
#   'anything',
#   'work'],
#  ['work', 'life balance', 'challenging'],
#  ['already',
#   'big',
#   'difficult',
#   'contribute',
#   'large',
#   'amount',
#   'lower',
#   'level',
#   'person',
#   'vacation',
#   'day',
#   'took',
#   'step',
#   'back',
#   'first',
#   'year',
#   'afterwards',
#   'better'],
#  ['none', 'aware'],
#  ['room', 'growth', 'unattianable', 'target'],
#  ['retail', 'environment', 'le', 'ideal', 'hour'],
#  ['low',
#   'pay',
#   'benefit',
#   'promised',
#   'micromanaged',
#   'pushed',
#   'work',
#   'beyond',
#   'physical',
#   'ability'],
#  ['lowlights',
#   'pressure',
#   'stakeholder',
#   'make',
#   'profit',
#   'go',
#   'people',
#   'msit',
#   'constant',
#   'pressure',
#   'change',
#   'articulated',
#   'vision',
#   'cause',
#   'constant',
#   'reorg',
#   'churn',
#   'org',
#   'tweaking',
#   'role',
#   'change',
#   'change',
#   'people',
#   'main',
#   'asset',
#   'pion',
#   'move',
#   'around',
#   'still',
#   'vision',
#   'future',
#   'cloud',
#   'first',
#   'mobile',
#   'first',
#   'large',
#   'vague',
#   'mean',
#   'everything',
#   'nothing',
#   'basically',
#   'mean',
#   'go',
#   'market',
#   'go',
#   'instead',
#   'think',
#   'going',
#   'want',
#   'offer'],
#  ['best', 'schedule', 'get', 'chaotic', 'time'],
#  ['mid',
#   'level',
#   'management',
#   'weak',
#   'lack',
#   'vision',
#   'decision making',
#   'skill'],
#  ['redmond centric',
# ...
#   'get',
#   'written',
#   'fired'],
#  ['flat', 'structure', 'minimum'],
#  ['move',
#   'fast',
#   'time',
#   'exhausting',
#   'honest',
#   'way',
#   'rather',
#   'constantly',
#   'busy',
#   'nothing',
#   'consider',
#   'job',
#   'amazon',
#   'challenge'],
#  ['inflexible',
#   'hour',
#   'inflexible',
#   'pay',
#   'benefit',
#   'seasonal',
#   'complicated',
#   'time',
#   'keeping',
#   'system',
#   'training',
#   'short',
#   'self',
#   'guided',
#   'difficult',
#   'gather',
#   'concept',
#   'thrown',
#   'phone',
#   'feeling',
#   'unprepared',
#   'stressed'],
#  ['bad', 'cant', 'say', 'much'],
#  ['everyone',
#   'new',
#   'sometimes',
#   'tough',
#   'get',
#   'trained',
#   'kinda',
#   'sorry',
#   'picked',
#   'schedule',
#   'let',
#   'change'],
#  ['complicated', 'technical', 'set'],
#  ['time',
#   'progress',
#   'unrealistic expectation',
#   'performance',
#   'made',
#   'priority',
#   'placed',
#   'self',
#   'promotion',
#   'actual',
#   'deliverable',
#   'stack ranking',
#   'still',
#   'alive',
#   'well',
#   'recognition',
#   'team',
#   'work'],
#  ['con', 'love', 'place'],
#  ['company',
#   'continuously',
#   'set',
#   'unrealistic',
#   'unattainable',
#   'goal',
#   'associate',
#   'almost',
#   'would',
#   'prefer',
#   'machine',
#   'verse',
#   'human being',
#   'foot',
#   'hour',
#   'day',
#   'strenuous',
#   'body'],
#  ['full',
#   'mean',
#   'manager',
#   'immoral',
#   'thing',
#   'ethic',
#   'thing',
#   'know',
#   'billing',
#   'resource',
#   'hr',
#   'billing',
#   'thing',
#   'matter',
#   'get',
#   'low',
#   'rating',
#   'next',
#   'year',
#   'get',
#   'fired',
#   'developer',
#   'may',
#   'go',
#   'testing',
#   'growth',
#   'depends',
#   'visibility',
#   'talent'],
#  ['negative'],
#  ['hard',
#   'let',
#   'work',
#   'death',
#   'technically',
#   'amazon',
#   'generally',
#   'require',
#   'overwork',
#   'certainly',
#   'set',
#   'environment',
#   'encourages'],
#  ['horrible',
#   'health',
#   'benefit',
#   'adecco',
#   'sick',
#   'day',
#   'vacation',
#   'day',
#   'long',
#   'period',
#   'away',
#   'home',
#   'single',
#   'man',
#   'job'],
#  ['store',
#   'leadership',
#   'one',
#   'store',
#   'understand',
#   'care',
#   'understand',
#   'bb',
#   'sale',
#   'rather',
#   'meeting',
#   'halfway',
#   'retail',
#   'business',
#   'team',
#   'asked',
#   'change',
#   'adapt',
#   'way',
#   'retail',
#   'environment',
#   'normally',
#   'would',
#   'issue',
#   'extremely',
#   'high',
#   'sale',
#   'goal',
#   'rewarded',
#   'much',
#   'pat back',
#   'rather',
#   'good',
#   'terrible',
#   'xyz'],
#  ['lot',
#   'people',
#   'love',
#   'work',
#   'hard',
#   'get',
#   'rewarded',
#   'perk',
#   'company',
#   'size',
#   'espp',
#   'discount',
#   'hardware',
#   'item',
#   'pace',
#   'work',
#   'constant',
#   'heavy',
#   'truly',
#   'happy',
#   'work',
#   'culture',
#   'bring'],
#  ['microsoft',
#   'need',
#   'continue',
#   'transform',
#   'become',
#   'customer',
#   'centric',
#   'move',
#   'away',
#   'old',
#   'way',
#   'thinking',
#   'thing'],
#  ['sometimes', 'frustrating', 'tiny', 'fish', 'ocean'],
#  ['begin',
#   'gon na',
#   'start',
#   'rambling',
#   'first',
#   'hour',
#   'awful',
#   'hour',
#   'shift',
#   'four',
#   'day',
#   'row',
#   'really',
#   'wear',
#   'away',
#   'tolerance',
#   'warehouse',
#   'work',
#   'first',
#   'think',
#   'would',
#   'bad',
#   'monotony',
#   'job',
#   'really',
#   'start',
#   'eat',
#   'happiness',
#   'personally',
#   'live',
#   'minute',
#   'away',
#   'building',
#   'total',
#   'dedicate',
#   'hour',
#   'towards',
#   'amazon',
#   'daily',
#   'add',
#   'commute',
#   'time',
#   'includes',
#   'leaving',
#   'extra',
#   'early',
#   'get',
#   'food',
#   'manage',
#   'get',
#   'hour',
#   'sleep',
#   'hour',
#   'every',
#   'day',
#   'fun',
#   'wind',
#   'exhausted',
#   'sleep',
#   'extra',
#   'time',
#   'free',
#   'time',
#   'even',
#   'worse',
#   'add',
#   'extra',
#   'hour',
#   'every',
#   'day',
#   'extra',
#   'day',
#   'schedule',
#   'peak season',
#   'many',
#   'people',
#   'building',
#   'bound',
#   'get',
#   'mixed',
#   'opinion',
#   'good',
#   'bad',
#   'overall',
#   'culture',
#   'great',
#   'since',
#   'everyone',
#   'usually',
#   'complaining',
#   'job',
#   'management',
#   'worst',
#   'could',
#   'much',
#   'better',
#   'often',
#   'minor',
#   'gripe',
#   'among',
#   'employee',
#   'daily',
#   'job',
#   'stower',
#   'worst',
#   'aspect',
#   'whole',
#   'job',
#   'job',
#   'take',
#   'item',
#   'cart',
#   'stow',
#   'cubby',
#   'hole',
#   'hour',
#   'day',
#   'something',
#   'next',
#   'try',
#   'picking',
#   'placing',
#   'somewhere else',
#   'putting',
#   'back',
#   'found',
#   'repeat',
#   'hour',
#   'top',
#   'management',
#   'disappointed',
#   'achieve',
#   'certain',
#   'rate',
#   'per',
#   'hour',
#   'even',
#   'take',
#   'disciplinary action',
#   'eventually',
#   'moved',
#   'problem solver',
#   'stimulating',
#   'position',
#   'since',
#   'used',
#   'laptop',
#   'fix',
#   'issue',
#   'item',
#   'must',
#   'stowed',
#   'satisfying',
#   'job',
#   'management',
#   'ended',
#   'screwing',
#   'u',
#   'position',
#   'hiring',
#   'many',
#   'picking',
#   'favorite',
#   'went',
#   'problem',
#   'solving',
#   'almost',
#   'every',
#   'day',
#   'getting',
#   'twice',
#   'every',
#   'two',
#   'week',
#   'sometimes',
#   'even',
#   'le',
#   'additionally',
#   'problem',
#   'solving',
#   'position',
#   'tier',
#   'salary',
#   'within',
#   'fulfillment center',
#   'robbinsville',
#   'location',
#   'considers',
#   'tier',
#   'many',
#   'issue',
#   'employee',
#   'place',
#   'like',
#   'mentioned',
#   'beginning',
#   'bad',
#   'place',
#   'looking',
#   'go',
#   'elsewhere',
#   'within',
#   'month',
#   'otherwise',
#   'bother',
#   'place',
#   'barely',
#   'keep',
#   'employee',
#   'year'],
#  ['zero',
#   'career progression',
#   'unless',
#   'happy',
#   'spend',
#   'minimum',
#   'year',
#   'role',
#   'management',
#   'recruiting',
#   'really',
#   'poor',
#   'demotivates',
#   'everyone',
#   'make',
#   'feel',
#   'supported',
#   'many',
#   'manager',
#   'promoted',
#   'tenure',
#   'alone',
#   'awful',
#   'people',
#   'manager'],
#  ['employee',
#   'evaluated',
#   'human',
#   'evaluated',
#   'computer',
#   'meet',
#   'computer',
#   'standard',
#   'terminated',
#   'matter',
#   'hard',
#   'worker',
#   'hard',
#   'try',
#   'care',
#   'amazon',
#   'policy'],
#  ['con'],
#  ['huge', 'organization', 'hence', 'le', 'recognition', 'individual'],
#  ['really', 'bad', 'management'],
#  ['terrible',
#   'pay',
#   'forced',
#   'work',
#   'overtime',
#   'business',
#   'need',
#   'require',
#   'terrible',
#   'schedule',
#   'benefit',
#   'little',
#   'support',
#   'peer',
#   'management',
#   'training',
#   'effective',
#   'cover',
#   'nearly',
#   'enough',
#   'dealing',
#   'worst',
#   'customer',
#   'day',
#   'made',
#   'entitled',
#   'amazon',
#   'policy',
#   'work',
#   'life balance',
#   'business',
#   'need',
#   'phrase',
#   'grow',
#   'immensely',
#   'dislike',
#   'trained',
#   'phone',
#   'support',
#   'forced',
#   'start',
#   'taking',
#   'e mail',
#   'chat',
#   'training',
#   'forced',
#   'take',
#   'live',
#   'chat',
#   'training',
#   'business',
#   'need',
#   'also',
#   'required',
#   'work',
#   'hour',
#   'week',
#   'needed',
#   'matter',
#   'still',
#   'school',
#   'need',
#   'work',
#   'hour',
#   'week',
#   'full',
#   'time',
#   'student'],
#  ['everything', 'else', 'need', 'good', 'health', 'plan'],
#  ['found',
#   'company',
#   'know',
#   'address',
#   'politics',
#   'associated',
#   'conflict',
#   'collaboration',
#   'properly',
#   'especially',
#   'manager',
#   'result',
#   'find',
#   'situation',
#   'simply',
#   'resolve',
#   'political',
#   'issue',
#   'management',
#   'anything',
#   'becomes',
#   'matter',
#   'time',
#   'get',
#   'control',
#   'dysfunction',
#   'set',
#   'impact',
#   'delivery',
#   'project'],
#  ['training',
#   'team',
#   'poor',
#   'control',
#   'system',
#   'jd',
#   'nothing',
#   'like',
#   'actual',
#   'role'],
#  ['much', 'work', 'food', 'good', 'life', 'ease', 'challenge'],
#  ['bureaucracy', 'slow', 'career progression', 'company', 'way', 'big'],
#  ['alot',
#   'work',
#   'speaking',
#   'customer',
#   'back',
#   'back',
#   'answering',
#   'chat',
#   'email',
#   'time'],
#  ['lack',
#   'work',
#   'space',
#   'demanding',
#   'multiple',
#   'change',
#   'happen',
#   'moment',
#   'distinctive',
#   'difference',
#   'contractor',
#   'ftes'],
#  ['customer',
#   'rating',
#   'taken',
#   'seriously',
#   'great',
#   'impact',
#   'growth',
#   'special',
#   'discount',
#   'amazon',
#   'product',
#   'retail',
#   'prime'],
#  ['nothing', 'bad', 'say', 'company'],
#  ['slow',
#   'cycle',
#   'non',
#   'meritocratic',
#   'incentive',
#   'work',
#   'harder',
#   'waste',
#   'time',
#   'irrelevant',
#   'bureaucracy'],
#  ['training',
#   'hr',
#   'wk',
#   'week',
#   'difficult',
#   'handle',
#   'possible',
#   'student'],
#  ['remember'],
#  ['stack ranking', 'con', 'gone', 'con'],
#  ['idea'],
#  ['dry',
#   'scrappy',
#   'boring',
#   'corporate',
#   'project',
#   'ux',
#   'essentially',
#   'considered',
#   'ui',
#   'many',
#   'department',
#   'amazon',
#   'emphasis',
#   'getting',
#   'thing',
#   'done',
#   'fast',
#   'rather',
#   'well',
#   'general',
#   'people',
#   'want',
#   'bond',
#   'individualistic',
#   'culture',
#   'much',
#   'diversity',
#   'tool',
#   'use',
#   'internal',
#   'tool',
#   'useful',
#   'next',
#   'job'],
#  ['far', 'satisfied', 'apple', 'offered'],
#  ['true',
#   'hrbp',
#   'role',
#   'glorified',
#   'administrator',
#   'although',
#   'hour',
#   'contract',
#   'looked',
#   'attempt',
#   'leave',
#   'time',
#   'massive',
#   'blame',
#   'culture'],
#  ['larger', 'company', 'talk', 'talk', 'customer', 'focused', 'walk', 'walk'],
#  ['every',
#   'retail',
#   'job',
#   'crazy',
#   'customer',
#   'apple',
#   'get',
#   'great',
#   'taste',
#   'un',
#   'human',
#   'people',
#   'fail',
#   'notice',
#   'entering',
#   'store',
#   'revolve',
#   'around'],
#  ['specifically',
#   'alexa',
#   'shopping',
#   'org',
#   'amazon',
#   'great',
#   'company',
#   'peculiar',
#   'culture',
#   'amazing',
#   'alexa',
#   'shopping',
#   'org',
#   'top',
#   'top',
#   'position',
#   'make',
#   'decision',
#   'bunch',
#   'leadership',
#   'working',
#   'together',
#   'previous',
#   'venture',
#   'failed',
#   'amazon',
#   'constitute',
#   'elite',
#   'group',
#   'people',
#   'make',
#   'decision',
#   'alexa',
#   'shopping',
#   'product',
#   'manager',
#   'control',
#   'organization',
#   'developer',
#   'matter',
#   'decision',
#   'made',
#   'without',
#   'technical',
#   'input',
#   'engineer',
#   'management',
#   'want',
#   'week',
#   'feature',
#   'hard',
#   'building',
#   'something',
#   'novel',
#   'new',
#   'ground',
#   'also',
#   'good',
#   'project',
#   'take',
#   'longer',
#   'week',
#   'get',
#   'discarded',
#   'even',
#   'huge',
#   'long',
#   'term',
#   'potential',
#   'basically',
#   'leadership',
#   'focused',
#   'short term',
#   'growth',
#   'short term',
#   'number',
#   'incentive',
#   'people',
#   'shop',
#   'giving',
#   'away',
#   'free',
#   'money',
#   'making',
#   'experience',
#   'great',
#   'alexa',
#   'shopping',
#   'never',
#   'inspiring',
#   'sucessful',
#   'much',
#   'politics',
#   'promotion',
#   'oligarchy',
#   'l',
#   'sr',
#   'devs',
#   'keep',
#   'discus',
#   'big',
#   'idea',
#   'spend',
#   'week',
#   'arguing',
#   'never',
#   'make',
#   'decision',
#   'move',
#   'forward',
#   'anything',
#   'also',
#   'everyone',
#   'complicated',
#   'thing',
#   'order',
#   'get',
#   'promoted',
#   'devs',
#   'scared',
#   'change',
#   'trying',
#   'new',
#   'thing',
#   'join',
#   'promised',
#   'work',
#   'alexa',
#   'natural',
#   'language',
#   'machine',
#   'learning',
#   'truth',
#   'little',
#   'little',
#   'integration',
#   'retail',
#   'system',
#   'checkout',
#   'order',
#   'history',
#   'search',
#   'work',
#   'interesting',
#   'technical',
#   'side',
#   'even',
#   'though',
#   'new',
#   'code'],
#  ['bad', 'bonus', 'pay', 'social', 'life', 'heavy', 'politics'],
#  ['le', 'facility', 'work', 'load', 'high', 'sometimes'],
#  ['see',
#   'con',
#   'something',
#   'warn',
#   'people',
#   'first',
#   'come',
#   'expected',
#   'work',
#   'sometimes',
#   'really',
#   'hard',
#   'fc',
#   'job',
#   'physical',
#   'dog eat',
#   'dog',
#   'world'],
#  ['work',
#   'life balance',
#   'poor',
#   'unfortunately',
#   'people',
#   'get',
#   'promoted',
#   'people',
#   'put',
#   'job',
#   'first',
#   'great',
#   'place',
#   'work',
#   'single',
#   'people',
#   'family',
#   'want',
#   'one'],
#  ['long', 'hour', 'time', 'cant', 'balance', 'work', 'personal', 'life'],
#  ['underestimate',
#   'much',
#   'repetitive',
#   'work',
#   'need',
#   'every',
#   'manpower',
#   'sort',
#   'box',
#   'wrap',
#   'pallet',
#   'transport',
#   'box',
#   'truck',
#   'thing',
#   'whole',
#   'shift',
#   'unless',
#   'manager',
#   'tell',
#   'person',
#   'want',
#   'something',
#   'differently',
#   'every',
#   'day',
#   'le',
#   'likely'],
#  ['work',
#   'life balance',
#   'focus',
#   'area',
#   'company',
#   'almost impossible',
#   'maintain',
#   'workweek',
#   'le',
#   'hour',
#   'regarded',
#   'hard',
#   'working',
#   'employee',
#   'nighttime',
#   'work',
#   'norm',
#   'late',
#   'stay',
#   'still',
#   'show',
#   'work',
#   'morning',
#   'tough',
#   'review',
#   'system',
#   'everyone',
#   'smart',
#   'start',
#   'playing',
#   'game',
#   'get',
#   'ahead',
#   'people',
#   'get',
#   'unfair',
#   'review',
#   'managing',
#   'spend',
#   'significant',
#   'amount',
#   'time',
#   'office',
#   'politics',
#   'random',
#   'firedrills',
#   'culture',
#   'planful',
#   'almost',
#   'penalized',
#   'plan',
#   'stick',
#   'end',
#   'spending',
#   'time',
#   'proactive',
#   'planful',
#   'getting',
#   'benefit'],
#  ['reorgs', 'get', 'rearranged', 'moved', 'around'],
#  ['limited',
#   'amount',
#   'con',
#   'came',
#   'apple',
#   'always',
#   'impressive',
#   'brand',
#   'however',
#   'staff',
#   'good'],
#  ['like', 'manager', 'rude', 'top', 'communication'],
#  ['many',
#   'old school',
#   'mentality',
#   'customer',
#   'focused',
#   'environment',
#   'house',
#   'always',
#   'win',
#   'quota',
#   'consistently',
#   'late',
#   'fiscal',
#   'year',
#   'setting'],
#  ['large', 'people', 'gotten', 'googley', 'starting', 'feel', 'corporate'],
#  ['stressful', 'job', 'constant', 'pressure', 'perfect', 'challenging', 'job'],
#  ['salary', 'location', 'lack', 'advancement', 'opportunity'],
#  ['nothing', 'much', 'improve', 'benefit'],
#  ['slow',
#   'promotion',
#   'rate',
#   'unless',
#   'rockstar',
#   'performer',
#   'avg',
#   'year',
#   'management',
#   'experience',
#   'become',
#   'finance',
#   'director'],
#  ['real',
#   'issue',
#   'lack',
#   'mobility',
#   'company',
#   'many',
#   'opportunity',
#   'experience',
#   'work',
#   'outside',
#   'current',
#   'position',
#   'far',
#   'actually',
#   'gaining',
#   'position',
#   'process',
#   'slim'],
#  ['call centre',
#   'environment',
#   'lot',
#   'pressure',
#   'perform',
#   'well',
#   'difficult',
#   'reach',
#   'target',
#   'tough',
#   'job',
#   'especially',
#   'sale',
#   'good',
#   'training',
#   'program'],
#  ['far', 'live', 'business', 'huge', 'cant', 'get', 'meet', 'everyone'],
#  ['hard',
#   'live',
#   'salary',
#   'relation',
#   'cost',
#   'management',
#   'care',
#   'number',
#   'incentive',
#   'place',
#   'work',
#   'harder',
#   'place',
#   'lot',
#   'people',
#   'break',
#   'loose'],
#  ['promote',
#   'within',
#   'oriented',
#   'pay',
#   'scale',
#   'customer',
#   'centric',
#   'mean',
#   'associate',
#   'second'],
#  ['need',
#   'comfortable',
#   'dealing',
#   'ambiguity',
#   'team',
#   'well',
#   'run',
#   'others',
#   'dysfunctional'],
#  ['call center',
#   'type',
#   'select',
#   'shift',
#   'time',
#   'policy',
#   'first',
#   'arrived',
#   'first',
#   'served'],
#  ['sometimes',
#   'thing',
#   'move',
#   'fast',
#   'hard',
#   'keep',
#   'also',
#   'fun',
#   'salary',
#   'benefit',
#   'probably',
#   'good',
#   'google',
#   'facebook'],
#  ['low',
#   'pay',
#   'least',
#   'tier',
#   'merit',
#   'system',
#   'many',
#   'manager',
#   'straight college',
#   'without',
#   'clue',
#   'little',
#   'realistic',
#   'room',
#   'advancement',
#   'without',
#   'yr',
#   'degree'],
#  ['period',
#   'worked',
#   'microsoft',
#   'changed',
#   'nimble',
#   'high',
#   'growth',
#   'company',
#   'bureaucratic',
#   'slow',
#   'growth',
#   'organization',
#   'teamwork',
#   'within',
#   'team',
#   'good',
#   'collaboration',
#   'across',
#   'team',
#   'poor',
#   'people',
#   'simply',
#   'busy',
#   'meeting',
#   'performance',
#   'goal',
#   'team',
#   'project',
#   'spend',
#   'much',
#   'time',
#   'work',
#   'team'],
#  ['frugality',
#   'leadership',
#   'principal',
#   'sometimes',
#   'amazon',
#   'take',
#   'far',
#   'get',
#   'merchandise',
#   'amazon com',
#   'sold',
#   'shipped',
#   'capped',
#   'year',
#   'free',
#   'prime',
#   'there',
#   'disparity',
#   'amongst',
#   'team',
#   'since',
#   'team',
#   'get',
#   'thing',
#   'others',
#   'know',
#   'one',
#   'team',
#   'get',
#   'free food',
#   'friday',
#   'mine',
#   'never',
#   'team',
#   'high',
#   'operational',
#   'work',
#   'prioritization',
#   'always',
#   'delivering',
#   'new',
#   'feature',
#   'fixing',
#   'old',
#   'one'],
#  ['past',
#   'year',
#   'struggled',
#   'stay',
#   'relevant',
#   'certain',
#   'industry',
#   'definitely',
#   'turned',
#   'corner'],
#  ...]

# %%
id2word = corpora.Dictionary(tokens)
dictionary = id2word
dictionary = dictionary.filter_extremes(no_above=0.80)

texts = tokens
corpus = [id2word.doc2bow(text) for text in texts]
ldamallet = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=2, id2word=id2word, iterations=100)

coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=texts, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()

def compute_coherence_values(dictionary, corpus, texts, limit=8, start=2, step=1):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=id2word, alpha=.91)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts, start=4, limit=8, step=2)

max_y = max(coherence_values)  # Find the maximum y value
max_x = coherence_values.index(max(coherence_values))  # Find the x value corresponding to the maximum y value
#xmax = x[numpy.argmax(y)]

optimal_model = model_list[coherence_values.index(max(coherence_values))]
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(optimal_model, corpus, id2word, R=7)
vis
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5     -0.073293  0.061074       1        1  20.721704
# 0     -0.166666 -0.057152       2        1  18.121813
# 2      0.006013  0.064576       3        1  16.933903
# 3      0.134706 -0.059097       4        1  15.875390
# 1      0.089560  0.032728       5        1  15.059514
# 4      0.009681 -0.042129       6        1  13.287669, topic_info=     Category          Freq            Term         Total  loglift  logprob
# 168   Default  12959.000000            work  12959.000000   7.0000   7.0000
# 201   Default   4228.000000            hour   4228.000000   6.0000   6.0000
# 260   Default   3106.000000             day   3106.000000   5.0000   5.0000
# 920   Default   1730.000000           apple   1730.000000   4.0000   4.0000
# 332   Default   6836.000000            time   6836.000000   3.0000   3.0000
# 22    Default   6811.000000         company   6811.000000   2.0000   2.0000
# 40    Default   6585.000000             get   6585.000000   1.0000   1.0000
# 4321   Topic1     42.122051         picture     43.056625   1.5520  -8.0198
# 4731   Topic1     50.518547      automation     51.770512   1.5495  -7.8381
# 5061   Topic1     34.120888           shame     35.013039   1.5482  -8.2305
# 5190   Topic1     66.947083           stats     68.761261   1.5473  -7.5565
# 5556   Topic1     28.207796         segment     29.204721   1.5393  -8.4208
# 4737   Topic1     23.527857     questioning     24.380362   1.5384  -8.6022
# 5005   Topic1     29.449244       brilliant     30.556015   1.5371  -8.3777
# 3363   Topic1     60.731255              qa     63.079479   1.5361  -7.6540
# 4148   Topic1     36.615871        new york     38.004490   1.5368  -8.1599
# 2748   Topic1     78.233437         netflix     82.214691   1.5244  -7.4007
# 3614   Topic1     83.416451         article     89.773170   1.5005  -7.3366
# 2276   Topic1     76.220543       principle     82.092926   1.4998  -7.4268
# 929    Topic1    710.935181          google    931.671936   1.3036  -5.1938
# 2413   Topic1    134.534012            fear    156.537766   1.4225  -6.8586
# 142    Topic1   1400.428589         culture   2338.462646   1.0613  -4.5159
# 61     Topic1    487.010773          others    714.277771   1.1910  -5.5721
# 186    Topic1    350.148651            seen    489.004395   1.2400  -5.9021
# 163    Topic1   1418.948120          amazon   2763.491211   0.9074  -4.5027
# 275    Topic1    549.716309           group    947.402039   1.0297  -5.4510
# 183    Topic1   2492.249268          people   6783.902832   0.5726  -3.9395
# 59     Topic1   1062.859619             one   2998.058594   0.5370  -4.7917
# 22     Topic1   1596.049805         company   6811.157227   0.1230  -4.3851
# 166    Topic1   1274.101196            team   4667.245605   0.2757  -4.6104
# ...       ...           ...             ...           ...      ...      ...
# 40     Topic5   2709.158447             get   6585.112305   1.0050  -3.5369
# 227    Topic5   1385.538696            hard   2811.480469   1.1855  -4.2074
# 332    Topic5   1806.505737            time   6836.155273   0.5623  -3.9421
# 166    Topic5   1389.095947            team   4667.245605   0.6812  -4.2048
# 168    Topic5   2004.611572            work  12959.902344   0.0268  -3.8380
# 46     Topic5   1036.430176             job   4158.801758   0.5037  -4.4977
# 684    Topic5    998.462646            like   3659.017090   0.5944  -4.5350
# 6200   Topic6     26.313511       retaining     27.224520   1.9843  -8.0460
# 6155   Topic6     25.325766          danger     26.239305   1.9829  -8.0843
# 444    Topic6     25.114029          raiser     26.043139   1.9820  -8.0926
# 1691   Topic6     59.319752     cost living     61.570705   1.9811  -7.2331
# 5590   Topic6     23.690285            camp     24.767059   1.9739  -8.1510
# 5861   Topic6     20.464466         ethical     21.491362   1.9694  -8.2974
# 5961   Topic6     27.365398       inventory     28.757189   1.9687  -8.0068
# 701    Topic6     26.337866            skin     27.812237   1.9639  -8.0451
# 3810   Topic6     34.440784         cutting     36.932220   1.9485  -7.7768
# 363    Topic6    658.027100         benefit    945.797241   1.6556  -4.8268
# 432    Topic6    105.171051      overworked    126.508842   1.8336  -6.6605
# 5161   Topic6     48.897366    stock option     55.049103   1.8998  -7.4263
# 356    Topic6    398.184875       associate    595.846558   1.6153  -5.3292
# 706    Topic6     74.544815  unprofessional     88.819435   1.8431  -7.0047
# 199    Topic6   1034.866333            high   1815.245117   1.4564  -4.3740
# 231    Topic6    609.308411          salary    990.779907   1.5322  -4.9037
# 127    Topic6    658.454041             low   1108.957153   1.4971  -4.8262
# 137    Topic6   1390.176514             lot   3913.807861   0.9833  -4.0789
# 51     Topic6   1702.508423      management   6129.582520   0.7373  -3.8762
# 415    Topic6   1463.869019         manager   5821.286621   0.6379  -4.0272
# 168    Topic6   2113.814697            work  12959.902344   0.2050  -3.6598
# 332    Topic6   1246.455322            time   6836.155273   0.3164  -4.1880
# 143    Topic6    909.251343        employee   4982.178223   0.3173  -4.5035
#
# [148 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 163       1  0.513481      amazon
# 163       2  0.013751      amazon
# 163       3  0.035462      amazon
# 163       4  0.112539      amazon
# 163       5  0.130994      amazon
# 163       6  0.193596      amazon
# 920       1  0.030621       apple
# 920       2  0.011555       apple
# 920       3  0.931913       apple
# 920       4  0.015599       apple
# 920       5  0.004622       apple
# 920       6  0.005778       apple
# 3614      1  0.924552     article
# 3614      2  0.011139     article
# 3614      3  0.011139     article
# 3614      4  0.033418     article
# 3614      6  0.011139     article
# 356       1  0.016783   associate
# 356       2  0.010070   associate
# 356       3  0.015105   associate
# 356       4  0.181255   associate
# 356       5  0.109088   associate
# 356       6  0.667957   associate
# 4731      1  0.985117  automation
# 4731      2  0.019316  automation
# 363       1  0.046522     benefit
# 363       2  0.046522     benefit
# 363       3  0.084585     benefit
# 363       4  0.103616     benefit
# 363       5  0.022203     benefit
# ...     ...       ...         ...
# 793       5  0.036689     weekend
# 793       6  0.019310     weekend
# 168       1  0.112501        work
# 168       2  0.054553        work
# 168       3  0.082562        work
# 168       4  0.432565        work
# 168       5  0.154708        work
# 168       6  0.163119        work
# 120       1  0.043670           ’
# 120       2  0.037432           ’
# 120       3  0.810323           ’
# 120       4  0.060306           ’
# 120       5  0.031886           ’
# 120       6  0.015943           ’
# 2252      1  0.011013           “
# 2252      2  0.007342           “
# 2252      3  0.958170           “
# 2252      4  0.011013           “
# 2252      5  0.007342           “
# 2252      6  0.003671           “
# 2253      1  0.011324           ”
# 2253      2  0.007549           ”
# 2253      3  0.954972           ”
# 2253      4  0.011324           ”
# 2253      5  0.007549           ”
# 2253      6  0.003775           ”
# 3182      1  0.010361           •
# 3182      2  0.020722           •
# 3182      3  0.010361           •
# 3182      4  0.953219           •
#
# [525 rows x 3 columns], R=7, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 1, 3, 4, 2, 5])

# %%
pyLDAvis.save_html(vis, 'pyLDAvis1.html')
# Out:
# /Users/theresasporn/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
