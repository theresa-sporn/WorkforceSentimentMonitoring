# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../raw_data/500_amzn.csv')
df
# Out:
#      pg_num                                                url  \
# 0      50.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# 1      50.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# 2      50.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# 3      50.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# 4      50.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# ..      ...                                                ...
# 495    61.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# 496    61.0  https://www.glassdoor.com/Reviews/Amazon-com-R...
# 497     NaN                                                NaN
# 498     NaN                                                NaN
# 499     NaN                                                NaN
#
#                                                   pros  \
# 0    You're surrounded by smart people and the proj...
# 1    Brand name is great. Have yet to meet somebody...
# ...

# %%
df = df.rename(columns={'pros':'positives', 'cons':'negatives'})
df = df[['positives', 'negatives']]
df.isnull().sum()
df.shape
# Out:
# (500, 2)

# %%
df = df.dropna()
df.shape
# Out:
# (496, 2)

# %%
text_columns = ["positives", "negatives"]
df
# Out:
#                                              positives  \
# 0    You're surrounded by smart people and the proj...
# 1    Brand name is great. Have yet to meet somebody...
# 2    Good money.Interaction with some great minds i...
# 3           nice pay and overtime and different shifts
# 4            Opportunity for those not afraid to work!
# ..                                                 ...
# 492  Good hours, nice pay and lots of people to mee...
# 493  great entry level job for pay and benefits. Le...
# 494  Good pay, good benefits. You get to work with ...
# 495  Compensation is great. Learning on and designi...
# 496                                   Seattle downtown
#
#                                              negatives
# 0    Internal tools proliferation has created a mes...
# 1    not the most stimulating work. Good brand name...
# 2    No proper growth plan for employees.Difficult ...
# 3                        didn't last quite long enough
# ...
